# %%
import requests
from bs4 import BeautifulSoup

# %%
# %pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\ralexander\appdata\local\programs\python\python312\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ralexander\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (2.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Function to scrape links from a webpage
def scrape_links(url):
    # Send a GET request to the URL
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code != 200:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
        return []
    
    # Parse the page content
    page_content = response.content
    soup = BeautifulSoup(page_content, 'html.parser')
    
    # Find all 'a' tags (which define hyperlinks)
    links = soup.find_all('a')
    table_rows = soup.find_all('tr')
    # Extract href and text of each link
    link_info = [{'href': link.get('href'), 'text': link.get_text()} for link in links if link.get('href')]
    song_links = {}
    #so i want to loop through all links that start with /track and text is not empty
    for links in link_info:
        song_title = str(links['text'])
        link = str(links['href'])
        if link.startswith('/track/') and len(song_title) > 0:
            song_links[song_title] = link

    # Find all 'td' tags
    #table_data = [td.get_text() for td in soup.find_all('td')]
    table_data = []
    for tr in table_rows:
        row_data = {}
        tds = tr.find_all('td')
        for td in tds:
            class_name = td.get('class')
            if class_name:
                # Join the list of class names to form a single string for the dictionary key
                class_name = ' '.join(class_name)
                row_data[class_name] = td.get_text()
        if row_data:
            table_data.append(row_data)

    #replace the table_link with the actual table link
    for i in range(len(table_data)): #their indexes match
        table_data[i]['table_link'] = (song_links[table_data[i]['table_name']])
    
    # Extract href attribute of each link
    #urls = [link.get('href') for link in links if link.get('href')]

    return table_data

# %%
# Main block to execute the function
# URL of the webpage to scrape
url = 'https://songdata.io/playlist/37i9dQZF1DX4JAvHpjipBk'

# Get the list of links
td = scrape_links(url)

# %%
print(td)
# Out:
# [{'table_play': '1', 'table_img': '', 'table_name': 'What Was That', 'table_artist': 'Lorde', 'table_data': '2025-04-24', 'table_key': 'C Major', 'table_camelot': '8B', 'table_bpm': '168', 'table_energy': '6', 'table_link': '/track/2jNyiavSywmA472t2m6ZBz/What-Was-That-by-Lorde'}, {'table_play': '2', 'table_img': '', 'table_name': 'Mystical Magical', 'table_artist': 'Benson Boone', 'table_data': '2025-04-24', 'table_key': 'B Major', 'table_camelot': '1B', 'table_bpm': '120', 'table_energy': '7', 'table_link': '/track/221eHga9f9Ne4f8D7WVgPT/Mystical-Magical-by-Benson-Boone'}, {'table_play': '3', 'table_img': '', 'table_name': 'Is This Really Love?', 'table_artist': 'd4vd', 'table_data': '2025-04-25', 'table_key': 'A♭ Major', 'table_camelot': '4B', 'table_bpm': '160', 'table_energy': '7', 'table_link': '/track/0h2vooD5PFOykbPon6ShIZ/Is-This-Really-Love-by-d4vd'}, {'table_play': '4', 'table_img': '', 'table_name': 'Money On Money (feat. Future)', 'table_artist': 'Young Thug, Future', 'table_data': '2025-04-25', 'table_key': 'B♭ Minor', 'table_camelot': '3A', 'table_bpm': '120', 'table_energy': '7', 'table_link': '/track/5eW508Gq23QlXHowyzW39m/Money-On-Money-feat-Future-by-Young-Thug-Future'}, {'table_play': '5', 'table_img': '', 'table_name': 'ILYSMIH', 'table_artist': 'Kali Uchis', 'table_data': '2025-04-25', 'table_key': 'C Major', 'table_camelot': '8B', 'table_bpm': '126', 'table_energy': '7', 'table_link': '/track/3WvPycGo4WJEEGYP429aap/ILYSMIH-by-Kali-Uchis'}, {'table_play': '6', 'table_img': '', 'table_name': 'Amen', 'table_artist': 'Shaboozey, Jelly Roll', 'table_data': '2025-04-25', 'table_key': 'A♭ Major', 'table_camelot': '4B', 'table_bpm': '81', 'table_energy': '5', 'table_link': '/track/2iSfSJrho5XkU2NmAnZ9ZV/Amen-by-Shaboozey-Jelly-Roll'}, {'table_play': '7', 'table_img': '', 'table_name': 'At The Beach, In Every Life', 'table_artist': 'Gigi Perez', 'table_data': '2025-04-25', 'table_key': 'D♭ Major', 'table_camelot': '3B', 'table_bpm': '84', 'table_energy': '4', 'table_link': '/track/5LfgzPHvka22FdRAxOme6m/At-The-Beach-In-Every-Life-by-Gigi-Perez'}, {'table_play': '8', 'table_img': '', 'table_name': 'Whenever', 'table_artist': 'Megan Thee Stallion', 'table_data': '2025-04-25', 'table_key': 'B♭ Minor', 'table_camelot': '3A', 'table_bpm': '120', 'table_energy': '7', 'table_link': '/track/4oVUfLx1BVgXbPXc0MlPkr/Whenever-by-Megan-Thee-Stallion'}, {'table_play': '9', 'table_img': '', 'table_name': 'Down to be wrong', 'table_artist': 'HAIM', 'table_data': '2025-04-24', 'table_key': 'C Major', 'table_camelot': '8B', 'table_bpm': '165', 'table_energy': '7', 'table_link': '/track/2d18juMmmN1KwjFtfEj0FP/Down-to-be-wrong-by-HAIM'}, {'table_play': '10', 'table_img': '', 'table_name': 'Brunette', 'table_artist': 'Tucker Wetmore', 'table_data': '2025-04-25', 'table_key': 'F♯ Major', 'table_camelot': '2B', 'table_bpm': '115', 'table_energy': '7', 'table_link': '/track/21T9HvQ0KUWFDum6P1Qc7i/Brunette-by-Tucker-Wetmore'}, {'table_play': '11', 'table_img': '', 'table_name': 'PIDA LO QUE QUIERA MAMI - A COLORS SHOW', 'table_artist': 'Feid, COLORS', 'table_data': '2025-04-21', 'table_key': 'D♭ Minor', 'table_camelot': '12A', 'table_bpm': '110', 'table_energy': '4', 'table_link': '/track/0PAqSz4d5lJfAscDDmIxzX/PIDA-LO-QUE-QUIERA-MAMI-A-COLORS-SHOW-by-Feid-COLORS'}, {'table_play': '12', 'table_img': '', 'table_name': 'On Sight', 'table_artist': 'Coco Jones', 'table_data': '2025-04-25', 'table_key': 'F♯ Minor', 'table_camelot': '11A', 'table_bpm': '90', 'table_energy': '5', 'table_link': '/track/0Tdpdo2ZD1CefcFTTbm0xx/On-Sight-by-Coco-Jones'}, {'table_play': '13', 'table_img': '', 'table_name': 'Carousel', 'table_artist': 'Samia', 'table_data': '2025-04-22', 'table_key': 'F♯ Major', 'table_camelot': '2B', 'table_bpm': '80', 'table_energy': '4', 'table_link': '/track/6xErF43Ru9Y0r21iHWaj0J/Carousel-by-Samia'}, {'table_play': '14', 'table_img': '', 'table_name': 'Stateside', 'table_artist': 'PinkPantheress', 'table_data': '2025-04-25', 'tabl ...

# %%
for row in td:
    print(row['table_name'])
#so this only has the first page. The scraper took the links for the second page too.
# Out:
# What Was That
# Mystical Magical
# Is This Really Love?
# Money On Money (feat. Future)
# ILYSMIH
# Amen
# At The Beach, In Every Life
# Whenever
# Down to be wrong
# Brunette
# PIDA LO QUE QUIERA MAMI - A COLORS SHOW
# On Sight
# Carousel
# Stateside
# Nostalgia
# Peacefield - Single Version
# BAD BITCHES!
# Gripper (feat. T-Pain)
# Pack It Up
# Damocles
# My First Heartbreak
# Learn The Hard Way
# Unshatter
# T.H.
# Poplife
# Tell Me Where U Go
# AMISTAD
# Gimme Dat (feat. Wizkid)
# Rich Guys (Feat. Babyfxce E)
# What Da Fuk
# Pretty Ugly
# I could
# buzzkill
# Alē
# Let Me Be Wrong
# Sungazing - Electronic Mix
# WASSUP
# IMMA RIDE 4 YOU
# Dead Body
# What I Used To Get Into
# Darkness Always Wins
# I Don't Know Why (I Just Do)
# Hitch Hiking
# Dreamin
# No Enemies (feat. Namasenda)
# Roar of the Lion (The Lion's Pit)
# Phone Ring (with Benny The Butcher and Maxo Kream)
# MONDAY
# Heart By Heart
# Act Right
# Lovesick Lullaby
# On One
# Bullet
# Air (feat. Julia Michaels)
# Same Shit
# Ya Fue
# Fleeting
# SINCERITY
# Spring
# pretty years
# Footprints
# G.I.R.L.
# Get Started
# Love to Death
# Dopamine and Jesus
# Sober
# Bad Apple
# BRAINDEAD
# square one
# Luna
# You4Me
# V.I.S.
# Sister
# Tears Dry Tonight
# Just Around the Corner
# Waterboy
# how u been?
# Concrete Cowboy
# There's A Part I Can't Get Back
# Pink Elephant
# Point and Shoot
# IF KARMA DOESN’T GET YOU (I WILL)
# LOOK @ GOD (feat. LaRussell)
# No Secrets
# Dream A Little Dream
# Ego
# Hot Fun
# Country in the Clouds
# 77 - feat. Avril Lavigne
# U Need 2 Leave
# Found Love
# Consider Him - Live
# Karma
# Questions
# Nina
# In This Mess
# GPS
# I Don´t Feel
# How To Get Her
# Speed Dating

# %%
def scrape_descriptions(song):
    #Scrapes the descriptions from an array of dictionaries with the link to those descriptions and returns the modified dictionary with an added column 
    #containing the descriptions
    #given: table_link contains the link to scrape
    # Send a GET request to the URL
    if 'table_descr' not in song.keys():
        url = 'https://songdata.io' + str(song['table_link'])
        response = requests.get(url)
        
        # Check if the request was successful
        if response.status_code != 200:
            print(f"Failed to retrieve the page. Status code: {response.status_code}")
            return []
        #print(url)
        # Parse the page content
        page_content = response.content
        soup = BeautifulSoup(page_content, 'html.parser')

        paragraphs = soup.find_all('p')
        #print(paragraphs)
        # Extract the text of each paragraph
        descriptions = [p.get_text() for p in paragraphs][0]
        song['table_descr'] = descriptions
    return song

# %%
scrape_descriptions(td[0])
# Out:
# {'table_play': '1',
#  'table_img': '',
#  'table_name': 'What Was That',
#  'table_artist': 'Lorde',
#  'table_data': '2025-04-24',
#  'table_key': 'C Major',
#  'table_camelot': '8B',
#  'table_bpm': '168',
#  'table_energy': '6',
#  'table_link': '/track/2jNyiavSywmA472t2m6ZBz/What-Was-That-by-Lorde',
#  'table_descr': '"What Was That" by Lorde had its release date on April 24, 2025. The duration of This song is about 3 minutes long, at 3:29. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Since What Was That only contains only one song in the album, we like to consider this song as a single. Based on our data, New Zealand was the country where this track was produced or recorded. The popularity of What Was That is currently pretty popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '}

# %%
for song in td:
    scrape_descriptions(song) #do this for all songs

td
# Out:
# [{'table_play': '1',
#   'table_img': '',
#   'table_name': 'What Was That',
#   'table_artist': 'Lorde',
#   'table_data': '2025-04-24',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '168',
#   'table_energy': '6',
#   'table_link': '/track/2jNyiavSywmA472t2m6ZBz/What-Was-That-by-Lorde',
#   'table_descr': '"What Was That" by Lorde had its release date on April 24, 2025. The duration of This song is about 3 minutes long, at 3:29. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Since What Was That only contains only one song in the album, we like to consider this song as a single. Based on our data, New Zealand was the country where this track was produced or recorded. The popularity of What Was That is currently pretty popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_play': '2',
#   'table_img': '',
#   'table_name': 'Mystical Magical',
#   'table_artist': 'Benson Boone',
#   'table_data': '2025-04-24',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '120',
#   'table_energy': '7',
#   'table_link': '/track/221eHga9f9Ne4f8D7WVgPT/Mystical-Magical-by-Benson-Boone',
#   'table_descr': 'On April 24, 2025, the song "Mystical Magical" was released by Benson Boone. The duration of This song is about two minutes long, specifically at 2:45. This song does not appear to have any foul language. Mystical Magical\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in Mystical Magical and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. Based on our statistics, Mystical Magical\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '3',
#   'table_img': '',
#   'table_name': 'Is This Really Love?',
#   'table_artist': 'd4vd',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '160',
#   'table_energy': '7',
#   'table_link': '/track/0h2vooD5PFOykbPon6ShIZ/Is-This-Really-Love-by-d4vd',
#   'table_descr': 'd4vd\'s \' "Is This Really Love?" was released on its scheduled release date, April 25, 2025. The duration of This song is about 3 minutes long, at 3:15. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. This song is part of WITHERED by d4vd. The song\'s track number on the album is #9 out of 15 tracks. Based on our data, United States was the country where this track was produced or recorded. The popularity of Is This Really Love? is currently unknown right now. Based on the vibe, this track doesn\'t seem to be that danceable, however its valence properties can make this some somewhat danceable. '},
#  {'table_play': '4',
#   'table_img': '',
#   'table_name': 'Money On Money (feat. Future)',
#   'table_artist': 'Young Thug, Future',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '120',
#   'table_energy': '7',
#   'table_link': '/track/5eW508Gq23QlXHowyzW39m/Money-On-Money-feat-Future-by-Young-Thug-Future',
#   'table_descr': '"Money On Money (feat. Future)" by Young Thug, Future had its release date on April 25, 2025. Money On Money (feat. Future) is explicit and may not be suitable for children. With the duration being about 3:56, this song is close to the average duration of a typical track. Because this song is the only song in Money On Money (feat. Future) and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. Based on our statistics, Money On Money (feat. Future)\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_play': '5',
#   'table_img': '',
#   'table_name': 'ILYSMIH',
#   'table_artist': 'Kali Uchis',
#   'table_data': '2025-04-25',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '126',
#   'table_energy': '7',
#   'table_link': '/track/3WvPycGo4WJEEGYP429aap/ILYSMIH-by-Kali-Uchis',
#   'table_descr': 'Kali Uchis\'s \' "ILYSMIH" was released on its scheduled release date, April 25, 2025. With this song being around four minutes long, at 3:33, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The track order of this song in Kali Uchis\'s "ILYSMIH" album is number 1 out of 2. On top of that, United States appears to be the country where this track was created. Based on our statistics, ILYSMIH\'s popularity is unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '6',
#   'table_img': '',
#   'table_name': 'Amen',
#   'table_artist': 'Shaboozey, Jelly Roll',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '81',
#   'table_energy': '5',
#   'table_link': '/track/2iSfSJrho5XkU2NmAnZ9ZV/Amen-by-Shaboozey-Jelly-Roll',
#   'table_descr': "Shaboozey, Jelly Roll's 'Amen' had a release date set for April 25, 2025. The duration of This song is about 3 minutes long, at 3:17. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. This song is part of Where I've Been, Isn't Where I'm Going: The Complete Edition by Shaboozey. The song's track number on the album is #13 out of 18 tracks. Based on our data, United States was the country where this track was produced or recorded. Amen is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '7',
#   'table_img': '',
#   'table_name': 'At The Beach, In Every Life',
#   'table_artist': 'Gigi Perez',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '84',
#   'table_energy': '4',
#   'table_link': '/track/5LfgzPHvka22FdRAxOme6m/At-The-Beach-In-Every-Life-by-Gigi-Perez',
#   'table_descr': 'Gigi Perez\'s \'At The Beach, In Every Life\' had a release date set for April 25, 2025. With this song being around four minutes long, at 3:57, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The song is number 12 out of 12 in At The Beach, In Every Life by Gigi Perez. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. At The Beach, In Every Life is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_play': '8',
#   'table_img': '',
#   'table_name': 'Whenever',
#   'table_artist': 'Megan Thee Stallion',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '120',
#   'table_energy': '7',
#   'table_link': '/track/4oVUfLx1BVgXbPXc0MlPkr/Whenever-by-Megan-Thee-Stallion',
#   'table_descr': '"Whenever" by Megan Thee Stallion had its release date on April 25, 2025. Whenever is 2 minutes and 45 seconds long and may contain bad words that may be unsuitable for children. Since Whenever only contains only one song in the album, we like to consider this song as a single. Based on our data, United States was the country where this track was produced or recorded. Based on our statistics, Whenever\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_play': '9',
#   'table_img': '',
#   'table_name': 'Down to be wrong',
#   'table_artist': 'HAIM',
#   'table_data': '2025-04-24',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '165',
#   'table_energy': '7',
#   'table_link': '/track/2d18juMmmN1KwjFtfEj0FP/Down-to-be-wrong-by-HAIM',
#   'table_descr': 'HAIM\'s \' "Down to be wrong" was released on its scheduled release date, April 24, 2025. With this song being around four minutes long, at 4:09, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The song is number 1 out of 3 in Down to be wrong by HAIM. Going off of the ISRC code of this track, we detected that the origin of this track is from United Kingdom. The popularity of Down to be wrong is currently unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '10',
#   'table_img': '',
#   'table_name': 'Brunette',
#   'table_artist': 'Tucker Wetmore',
#   'table_data': '2025-04-25',
#   'table_key': 'F♯ Major',
#   'table_camelot': '2B',
#   'table_bpm': '115',
#   'table_energy': '7',
#   'table_link': '/track/21T9HvQ0KUWFDum6P1Qc7i/Brunette-by-Tucker-Wetmore',
#   'table_descr': 'Tucker Wetmore\'s \' "Brunette" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:19. This song does not appear to have any foul language. Brunette\'s duration is considered a little bit shorter than the average duration of a typical track. This song is part of What Not To by Tucker Wetmore. The song\'s track number on the album is #6 out of 19 tracks. Based on our data, United States was the country where this track was produced or recorded. In terms of popularity, Brunette is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '11',
#   'table_img': '',
#   'table_name': 'PIDA LO QUE QUIERA MAMI - A COLORS SHOW',
#   'table_artist': 'Feid, COLORS',
#   'table_data': '2025-04-21',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '110',
#   'table_energy': '4',
#   'table_link': '/track/0PAqSz4d5lJfAscDDmIxzX/PIDA-LO-QUE-QUIERA-MAMI-A-COLORS-SHOW-by-Feid-COLORS',
#   'table_descr': 'Feid, COLORS\'s \' "PIDA LO QUE QUIERA MAMI - A COLORS SHOW" was released on its scheduled release date, April 21, 2025. The duration of This song is about 3 minutes long, at 3:27. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Since PIDA LO QUE QUIERA MAMI - A COLORS SHOW only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. In terms of popularity, PIDA LO QUE QUIERA MAMI - A COLORS SHOW is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '12',
#   'table_img': '',
#   'table_name': 'On Sight',
#   'table_artist': 'Coco Jones',
#   'table_data': '2025-04-25',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '90',
#   'table_energy': '5',
#   'table_link': '/track/0Tdpdo2ZD1CefcFTTbm0xx/On-Sight-by-Coco-Jones',
#   'table_descr': "Coco Jones's 'On Sight' had a release date set for April 25, 2025. On Sight is explicit and may not be suitable for children. With the duration being about 4:27, this song is close to the average duration of a typical track. This song is part of Why Not More? by Coco Jones. The song's track number on the album is #3 out of 14 tracks. Based on our data, United States was the country where this track was produced or recorded. In terms of popularity, On Sight is currently unknown. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. "},
#  {'table_play': '13',
#   'table_img': '',
#   'table_name': 'Carousel',
#   'table_artist': 'Samia',
#   'table_data': '2025-04-22',
#   'table_key': 'F♯ Major',
#   'table_camelot': '2B',
#   'table_bpm': '80',
#   'table_energy': '4',
#   'table_link': '/track/6xErF43Ru9Y0r21iHWaj0J/Carousel-by-Samia',
#   'table_descr': '"Carousel" by Samia had its release date on April 22, 2025. The duration of This song is about 3 minutes long, at 3:27. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. The song is number 1 out of 5 in Carousel by Samia. Carousel is unknown right now. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_play': '14',
#   'table_img': '',
#   'table_name': 'Stateside',
#   'table_artist': 'PinkPantheress',
#   'table_data': '2025-04-25',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '123',
#   'table_energy': '9',
#   'table_link': '/track/7Fr2Q6q3rAxFUcMkuvVrXO/Stateside-by-PinkPantheress',
#   'table_descr': 'PinkPantheress\'s \' "Stateside" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:48. This song does not appear to have any foul language. Stateside\'s duration is considered a little bit shorter than the average duration of a typical track. There are a total of 2 in the song\'s album "Stateside". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United Kingdom. Based on our statistics, Stateside\'s popularity is unknown right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_play': '15',
#   'table_img': '',
#   'table_name': 'Nostalgia',
#   'table_artist': 'Sammy Virji, Issey Cross',
#   'table_data': '2025-04-25',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '132',
#   'table_energy': '6',
#   'table_link': '/track/5D5uC8J6xBkGN66eLnqdvG/Nostalgia-by-Sammy-Virji-Issey-Cross',
#   'table_descr': '"Nostalgia" by Sammy Virji, Issey Cross had its release date on April 25, 2025. With this song being around four minutes long, at 3:30, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Nostalgia and no other songs are present in the album, we classify this track as a single. Furthermore, we believe that the track originated from United Kingdom. Based on our statistics, Nostalgia\'s popularity is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_play': '16',
#   'table_img': '',
#   'table_name': 'Peacefield - Single Version',
#   'table_artist': 'Ghost',
#   'table_data': '2025-04-22',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '103',
#   'table_energy': '9',
#   'table_link': '/track/6j9GJGI7sogofbagE6za5E/Peacefield-Single-Version-by-Ghost',
#   'table_descr': 'Ghost\'s \' "Peacefield - Single Version" was released on its scheduled release date, April 22, 2025. With this song being about 5 minutes long, at This song is fairly a long song compared to the average song length. This song does not have an "Explicit" tag, making it safe for all ages. There are a total of 2 in the song\'s album "Peacefield". In this album, this song\'s track order is #2. Furthermore, we believe that the track originated from United States. In terms of popularity, Peacefield - Single Version is currently unknown. The overall mood can be danceable to some, especially with it\'s high amount of postive energy. '},
#  {'table_play': '17',
#   'table_img': '',
#   'table_name': 'BAD BITCHES!',
#   'table_artist': 'DESTIN CONRAD, Kehlani',
#   'table_data': '2025-04-25',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '87',
#   'table_energy': '4',
#   'table_link': '/track/5ld2rB0d5nG8RTQRRmkxNa/BAD-BITCHES-by-DESTIN-CONRAD-Kehlani',
#   'table_descr': 'DESTIN CONRAD, Kehlani\'s \' "BAD BITCHES!" was released on its scheduled release date, April 25, 2025. BAD BITCHES! is explicit and may not be suitable for children. With the duration being about 3:45, this song is close to the average duration of a typical track. The track order of this song in DESTIN CONRAD\'s "LOVE ON DIGITAL" album is number 4 out of 15. On top of that, United States appears to be the country where this track was created. BAD BITCHES! is unknown right now. Based on the vibe, this track doesn\'t seem to be that danceable, however its valence properties can make this some somewhat danceable. '},
#  {'table_play': '18',
#   'table_img': '',
#   'table_name': 'Gripper (feat. T-Pain)',
#   'table_artist': 'Flo Milli, T-Pain',
#   'table_data': '2025-04-25',
#   'table_key': 'C Minor',
#   'table_camelot': '5A',
#   'table_bpm': '133',
#   'table_energy': '6',
#   'table_link': '/track/0OBXjsLYqftAOhCMEcAeAs/Gripper-feat-T-Pain-by-Flo-Milli-T-Pain',
#   'table_descr': 'Flo Milli, T-Pain\'s \' "Gripper (feat. T-Pain)" was released on its scheduled release date, April 25, 2025. Gripper (feat. T-Pain) is 2 minutes and 52 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in Gripper (feat. T-Pain) and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. Based on our statistics, Gripper (feat. T-Pain)\'s popularity is unknown right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_play': '19',
#   'table_img': '',
#   'table_name': 'Pack It Up',
#   'table_artist': 'ian',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '134',
#   'table_energy': '5',
#   'table_link': '/track/0ZvlEr2LkJUO6eYMVi74Io/Pack-It-Up-by-ian',
#   'table_descr': 'ian\'s \' "Pack It Up" was released on its scheduled release date, April 25, 2025. For a fairly short song, this song is "Pack It Up" is considered an explicit song with a duration of 1:54. Since Pack It Up only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. Based on our statistics, Pack It Up\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '20',
#   'table_img': '',
#   'table_name': 'Damocles',
#   'table_artist': 'Sleep Token',
#   'table_data': '2025-04-25',
#   'table_key': 'F♯ Major',
#   'table_camelot': '2B',
#   'table_bpm': '156',
#   'table_energy': '6',
#   'table_link': '/track/1ulH5PIntNj0ro2K69W4Fx/Damocles-by-Sleep-Token',
#   'table_descr': 'Sleep Token\'s \'Damocles\' had a release date set for April 25, 2025. With this song being around four minutes long, at 4:24, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Damocles and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, Damocles\'s popularity is fairly popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_play': '21',
#   'table_img': '',
#   'table_name': 'My First Heartbreak',
#   'table_artist': 'Myles Smith',
#   'table_data': '2025-04-25',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '82',
#   'table_energy': '5',
#   'table_link': '/track/5gbUP33wFJPawjY5DxR3OA/My-First-Heartbreak-by-Myles-Smith',
#   'table_descr': "Myles Smith's 'My First Heartbreak' had a release date set for April 25, 2025. The duration of This song is about 3 minutes long, at 3:26. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in My First Heartbreak and no other songs are present in the album, we classify this track as a single. On top of that, United Kingdom appears to be the country where this track was created. My First Heartbreak is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. "},
#  {'table_play': '22',
#   'table_img': '',
#   'table_name': 'Learn The Hard Way',
#   'table_artist': 'Jordan Davis',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '77',
#   'table_energy': '9',
#   'table_link': '/track/3xB2R2tf0T2TXaB4AWoPjT/Learn-The-Hard-Way-by-Jordan-Davis',
#   'table_descr': 'On April 25, 2025, the song "Learn The Hard Way" was released by Jordan Davis. The duration of This song is about two minutes long, specifically at 2:48. This song does not appear to have any foul language. Learn The Hard Way\'s duration is considered a little bit shorter than the average duration of a typical track. The track order of this song in Jordan Davis\'s "Learn The Hard Way" album is number 1 out of 3. On top of that, United States appears to be the country where this track was created. Learn The Hard Way is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '23',
#   'table_img': '',
#   'table_name': 'Unshatter',
#   'table_artist': 'Linkin Park',
#   'table_data': '2025-04-25',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '107',
#   'table_energy': '9',
#   'table_link': '/track/0D7RVmTlKkmRchqKA4zJht/Unshatter-by-Linkin-Park',
#   'table_descr': 'Linkin Park\'s \' "Unshatter" was released on its scheduled release date, April 25, 2025. The duration of This song is about 3 minutes long, at 3:16. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. There are a total of 2 in the song\'s album "Unshatter". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United States. In terms of popularity, Unshatter is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '24',
#   'table_img': '',
#   'table_name': 'T.H.',
#   'table_artist': 'SAULT',
#   'table_data': '2025-04-18',
#   'table_key': 'E♭ Minor',
#   'table_camelot': '2A',
#   'table_bpm': '134',
#   'table_energy': '6',
#   'table_link': '/track/7Cj2Buxud8yjgRCdRW6VUs/TH-by-SAULT',
#   'table_descr': 'SAULT\'s \' "T.H." was released on its scheduled release date, April 18, 2025. With this song being about 5 minutes long, at This song is fairly a long song compared to the average song length. This song does not have an "Explicit" tag, making it safe for all ages. There is only one song in 10, so we believe that "T.H." is a single. Based on our statistics, T.H.\'s popularity is below average in popularity right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '25',
#   'table_img': '',
#   'table_name': 'Poplife',
#   'table_artist': 'umru, underscores',
#   'table_data': '2025-04-24',
#   'table_key': 'A Minor',
#   'table_camelot': '8A',
#   'table_bpm': '142',
#   'table_energy': '8',
#   'table_link': '/track/2cClnOEBnNJWxbLuTFVIgK/Poplife-by-umru-underscores',
#   'table_descr': 'umru, underscores\'s \' "Poplife" was released on its scheduled release date, April 24, 2025. The duration of This song is about two minutes long, specifically at 2:43. This song does not appear to have any foul language. Poplife\'s duration is considered a little bit shorter than the average duration of a typical track. Since Poplife only contains only one song in the album, we like to consider this song as a single. Based on our statistics, Poplife\'s popularity is average in popularity right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '26',
#   'table_img': '',
#   'table_name': 'Tell Me Where U Go',
#   'table_artist': 'Clean Bandit, Tiësto, Leony',
#   'table_data': '2025-04-25',
#   'table_key': 'G Minor',
#   'table_camelot': '6A',
#   'table_bpm': '142',
#   'table_energy': '8',
#   'table_link': '/track/4NuksWELZ9lBY9aazhZG16/Tell-Me-Where-U-Go-by-Clean-Bandit-Tisto-Leony',
#   'table_descr': "Clean Bandit, Tiësto, Leony's 'Tell Me Where U Go' had a release date set for April 25, 2025. Tell Me Where U Go is considered explicit and may contain foul language. This song is about 3 minutes and 2 seconds, which is about the average length of a typical song. Since Tell Me Where U Go only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United Kingdom. Based on our statistics, Tell Me Where U Go's popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '27',
#   'table_img': '',
#   'table_name': 'AMISTAD',
#   'table_artist': 'Blessd, Ovy On The Drums',
#   'table_data': '2025-04-24',
#   'table_key': 'F Major',
#   'table_camelot': '7B',
#   'table_bpm': '170',
#   'table_energy': '6',
#   'table_link': '/track/1TzQqJ4hme55ZKnM86Xyw0/AMISTAD-by-Blessd-Ovy-On-The-Drums',
#   'table_descr': 'Blessd, Ovy On The Drums\'s \' "AMISTAD" was released on its scheduled release date, April 24, 2025. AMISTAD is 2 minutes and 57 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in AMISTAD and no other songs are present in the album, we classify this track as a single. The popularity of AMISTAD is currently unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '28',
#   'table_img': '',
#   'table_name': 'Gimme Dat (feat. Wizkid)',
#   'table_artist': 'Ayra Starr, Wizkid',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Major',
#   'table_camelot': '6B',
#   'table_bpm': '95',
#   'table_energy': '8',
#   'table_link': '/track/1k51Q6GFWBbsaWlBB2gnzo/Gimme-Dat-feat-Wizkid-by-Ayra-Starr-Wizkid',
#   'table_descr': 'Ayra Starr, Wizkid\'s \' "Gimme Dat (feat. Wizkid)" was released on its scheduled release date, April 25, 2025. With this song being around four minutes long, at 3:45, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Gimme Dat and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. In terms of popularity, Gimme Dat (feat. Wizkid) is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '29',
#   'table_img': '',
#   'table_name': 'Rich Guys (Feat. Babyfxce E)',
#   'table_artist': 'BabyChiefDoit, Babyfxce E',
#   'table_data': '2025-04-23',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '157',
#   'table_energy': '5',
#   'table_link': '/track/7a1Iw4S1eNozL4C4gv5xSg/Rich-Guys-Feat-Babyfxce-E-by-BabyChiefDoit-Babyfxce-E',
#   'table_descr': '"Rich Guys (Feat. Babyfxce E)" by BabyChiefDoit, Babyfxce E had its release date on April 23, 2025. Rich Guys (Feat. Babyfxce E) is 2 minutes and 58 seconds long and may contain bad words that may be unsuitable for children. This song is part of ZOO LIFE by BabyChiefDoit. The song\'s track number on the album is #2 out of 13 tracks. Based on our statistics, Rich Guys (Feat. Babyfxce E)\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_play': '30',
#   'table_img': '',
#   'table_name': 'What Da Fuk',
#   'table_artist': 'PLUTO',
#   'table_data': '2025-04-24',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '156',
#   'table_energy': '8',
#   'table_link': '/track/46e5RkqWEBRLebmdCK9t7o/What-Da-Fuk-by-PLUTO',
#   'table_descr': "PLUTO's 'What Da Fuk' had a release date set for April 24, 2025. What Da Fuk is 2 minutes and 36 seconds long and may contain bad words that may be unsuitable for children. This song is part of What Da Fuk by PLUTO. The song's track number on the album is #1 out of 2 tracks. Based on our data, United States was the country where this track was produced or recorded. Based on our statistics, What Da Fuk's popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '31',
#   'table_img': '',
#   'table_name': 'Pretty Ugly',
#   'table_artist': 'Zara Larsson',
#   'table_data': '2025-04-25',
#   'table_key': 'C Minor',
#   'table_camelot': '5A',
#   'table_bpm': '111',
#   'table_energy': '7',
#   'table_link': '/track/0lWcOHxfnxj1GlVr4zpnyD/Pretty-Ugly-by-Zara-Larsson',
#   'table_descr': 'Zara Larsson\'s \' "Pretty Ugly" was released on its scheduled release date, April 25, 2025. Pretty Ugly is 2 minutes and 38 seconds long and may contain bad words that may be unsuitable for children. Since Pretty Ugly only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. In terms of popularity, Pretty Ugly is currently unknown. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_play': '32',
#   'table_img': '',
#   'table_name': 'I could',
#   'table_artist': 'Fine',
#   'table_data': '2025-04-23',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '147',
#   'table_energy': '6',
#   'table_link': '/track/5EmtveGyjsE023P8atahBQ/I-could-by-Fine',
#   'table_descr': 'Fine\'s \' "I could" was released on its scheduled release date, April 23, 2025. The duration of This song is about two minutes long, specifically at 2:36. This song does not appear to have any foul language. I could\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in I could and no other songs are present in the album, we classify this track as a single. On top of that, France appears to be the country where this track was created. Based on our statistics, I could\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '33',
#   'table_img': '',
#   'table_name': 'buzzkill',
#   'table_artist': 'Lyn Lapid',
#   'table_data': '2025-04-25',
#   'table_key': 'D Major',
#   'table_camelot': '10B',
#   'table_bpm': '144',
#   'table_energy': '7',
#   'table_link': '/track/1xo0olV5DcTUQX9cpoUv5m/buzzkill-by-Lyn-Lapid',
#   'table_descr': 'Lyn Lapid\'s \' "buzzkill" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:35. This song does not appear to have any foul language. buzzkill\'s duration is considered a little bit shorter than the average duration of a typical track. The song is number 1 out of 12 in BUZZKILL by Lyn Lapid. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, buzzkill\'s popularity is unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '34',
#   'table_img': '',
#   'table_name': 'Alē',
#   'table_artist': 'Chezile',
#   'table_data': '2025-04-25',
#   'table_key': 'G Minor',
#   'table_camelot': '6A',
#   'table_bpm': '89',
#   'table_energy': '6',
#   'table_link': '/track/5xkWnuF0eA5ODVKiTJaQXZ/Al-by-Chezile',
#   'table_descr': "Chezile's 'Alē' had a release date set for April 25, 2025. The duration of This song is about two minutes long, specifically at 2:51. This song does not appear to have any foul language. Alē's duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in Alē and no other songs are present in the album, we classify this track as a single. Alē is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '35',
#   'table_img': '',
#   'table_name': 'Let Me Be Wrong',
#   'table_artist': 'Jensen McRae',
#   'table_data': '2025-04-25',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '203',
#   'table_energy': '5',
#   'table_link': '/track/7iueQDyeYZRXZc4DYYAwDw/Let-Me-Be-Wrong-by-Jensen-McRae',
#   'table_descr': 'Jensen McRae\'s \' "Let Me Be Wrong" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:36. This song does not appear to have any foul language. Let Me Be Wrong\'s duration is considered a little bit shorter than the average duration of a typical track. The track order of this song in Jensen McRae\'s "I Don\'t Know How But They Found Me!" album is number 5 out of 11. On top of that, United States appears to be the country where this track was created. The popularity of Let Me Be Wrong is currently unknown right now. Based on the vibe, this track doesn\'t seem to be that danceable, however its valence properties can make this some somewhat danceable. '},
#  {'table_play': '36',
#   'table_img': '',
#   'table_name': 'Sungazing - Electronic Mix',
#   'table_artist': 'Michael Bibi, Alexa Sunshine Rose',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '130',
#   'table_energy': '8',
#   'table_link': '/track/0H72o8QdyYc57jNkvYwfAX/Sungazing-Electronic-Mix-by-Michael-Bibi-Alexa-Sunshine-Rose',
#   'table_descr': 'Michael Bibi, Alexa Sunshine Rose\'s \' "Sungazing - Electronic Mix" was released on its scheduled release date, April 25, 2025. With this song being around four minutes long, at 4:07, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Since Sungazing (Electronic Mix) only contains only one song in the album, we like to consider this song as a single. Based on our statistics, Sungazing - Electronic Mix\'s popularity is unknown right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_play': '37',
#   'table_img': '',
#   'table_name': 'WASSUP',
#   'table_artist': 'Young Miko',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '145',
#   'table_energy': '7',
#   'table_link': '/track/32SJM4tQyJHsB8rgVtZURn/WASSUP-by-Young-Miko',
#   'table_descr': 'Young Miko\'s \' "WASSUP" was released on its scheduled release date, April 25, 2025. WASSUP is 2 minutes and 42 seconds long and may contain bad words that may be unsuitable for children. Since WASSUP only contains only one song in the album, we like to consider this song as a single. Based on our statistics, WASSUP\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '38',
#   'table_img': '',
#   'table_name': 'IMMA RIDE 4 YOU',
#   'table_artist': '$NOT',
#   'table_data': '2025-04-20',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '139',
#   'table_energy': '5',
#   'table_link': '/track/1JPKeahg89aOPJYGa0JDFC/IMMA-RIDE-4-YOU-by-NOT',
#   'table_descr': '$NOT\'s \' "IMMA RIDE 4 YOU" was released on its scheduled release date, April 20, 2025. IMMA RIDE 4 YOU is 2 minutes and 26 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in IMMA RIDE 4 YOU and no other songs are present in the album, we classify this track as a single. Based on our statistics, IMMA RIDE 4 YOU\'s popularity is average in popularity right now. The overall mood can be danceable to some, especially with it\'s high amount of postive energy. '},
#  {'table_play': '39',
#   'table_img': '',
#   'table_name': 'Dead Body',
#   'table_artist': 'MAF Teeski, Skrilla',
#   'table_data': '2025-04-23',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '88',
#   'table_energy': '5',
#   'table_link': '/track/7yT8OCnOJ9oFajVE6RVPm4/Dead-Body-by-MAF-Teeski-Skrilla',
#   'table_descr': "MAF Teeski, Skrilla's 'Dead Body' had a release date set for April 23, 2025. Dead Body is 2 minutes and 42 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in Dead Body and no other songs are present in the album, we classify this track as a single. Dead Body is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. "},
#  {'table_play': '40',
#   'table_img': '',
#   'table_name': 'What I Used To Get Into',
#   'table_artist': 'Roy Woods',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '84',
#   'table_energy': '6',
#   'table_link': '/track/4GEAQAtCQ50j0lZP9k4SMT/What-I-Used-To-Get-Into-by-Roy-Woods',
#   'table_descr': 'Roy Woods\'s \' "What I Used To Get Into" was released on its scheduled release date, April 25, 2025. What I Used To Get Into is considered explicit and may contain foul language. This song is about 3 minutes and 12 seconds, which is about the average length of a typical song. The song is number 5 out of 9 in Dark Nights by Roy Woods. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. What I Used To Get Into is unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '41',
#   'table_img': '',
#   'table_name': 'Darkness Always Wins',
#   'table_artist': 'Halestorm',
#   'table_data': '2025-04-22',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '170',
#   'table_energy': '6',
#   'table_link': '/track/7wBKXbleeJQuQDnfKlOOGe/Darkness-Always-Wins-by-Halestorm',
#   'table_descr': '"Darkness Always Wins" by Halestorm had its release date on April 22, 2025. With this song being about 5 minutes long, at This song is fairly a long song compared to the average song length. This song does not have an "Explicit" tag, making it safe for all ages. Because this song is the only song in Darkness Always Wins and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. The popularity of Darkness Always Wins is currently unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_play': '42',
#   'table_img': '',
#   'table_name': "I Don't Know Why (I Just Do)",
#   'table_artist': 'Jeff Goldblum & The Mildred Snitzer Orchestra, Ariana Grande',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '95',
#   'table_energy': '4',
#   'table_link': '/track/0WiIGxBzkA2SvE8clbz3X0/I-Dont-Know-Why-I-Just-Do-by-Jeff-Goldblum-The-Mildred-Snitzer-Orchest',
#   'table_descr': '"I Don\'t Know Why (I Just Do)" by Jeff Goldblum & The Mildred Snitzer Orchestra, Ariana Grande had its release date on April 25, 2025. With this song being around four minutes long, at 3:44, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. There are a total of 9 in the song\'s album "Still Blooming". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United Kingdom. In terms of popularity, I Don\'t Know Why (I Just Do) is currently unknown. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_play': '43',
#   'table_img': '',
#   'table_name': 'Hitch Hiking',
#   'table_artist': 'Jenna Raine',
#   'table_data': '2025-04-25',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '170',
#   'table_energy': '6',
#   'table_link': '/track/5nkg0pxD5dN91JBzlvI90W/Hitch-Hiking-by-Jenna-Raine',
#   'table_descr': 'Jenna Raine\'s \' "Hitch Hiking" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:50. This song does not appear to have any foul language. Hitch Hiking\'s duration is considered a little bit shorter than the average duration of a typical track. There are a total of 6 in the song\'s album "Only Started Growing". In this album, this song\'s track order is #3. Furthermore, we believe that the track originated from United States. The popularity of Hitch Hiking is currently unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '44',
#   'table_img': '',
#   'table_name': 'Dreamin',
#   'table_artist': 'BRONCHO',
#   'table_data': '2025-04-25',
#   'table_key': 'F Major',
#   'table_camelot': '7B',
#   'table_bpm': '110',
#   'table_energy': '3',
#   'table_link': '/track/4cYvM8q9V6HTEayIBHuP1W/Dreamin-by-BRONCHO',
#   'table_descr': 'BRONCHO\'s \' "Dreamin" was released on its scheduled release date, April 25, 2025. The duration of This song is about 3 minutes long, at 3:26. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. There are a total of 12 in the song\'s album "Natural Pleasure". In this album, this song\'s track order is #12. Furthermore, we believe that the track originated from Turks and Caicos Islands. In terms of popularity, Dreamin is currently unknown. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_play': '45',
#   'table_img': '',
#   'table_name': 'No Enemies (feat. Namasenda)',
#   'table_artist': 'Sebastian Ingrosso, Steve Angello, Namasenda',
#   'table_data': '2025-04-24',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '134',
#   'table_energy': '6',
#   'table_link': '/track/55gp7v87CYS1lxWQ5ho5nK/No-Enemies-feat-Namasenda-by-Sebastian-Ingrosso-Steve-Angello-Namasend',
#   'table_descr': "Sebastian Ingrosso, Steve Angello, Namasenda's 'No Enemies (feat. Namasenda)' had a release date set for April 24, 2025. The duration of This song is about two minutes long, specifically at 2:40. This song does not appear to have any foul language. No Enemies (feat. Namasenda)'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in No Enemies (feat. Namasenda) and no other songs are present in the album, we classify this track as a single. Furthermore, we believe that the track originated from United States. Based on our statistics, No Enemies (feat. Namasenda)'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '46',
#   'table_img': '',
#   'table_name': "Roar of the Lion (The Lion's Pit)",
#   'table_artist': 'Wu-Tang Clan, U-God, Kool G Rap, RZA',
#   'table_data': '2025-04-25',
#   'table_key': 'B Minor',
#   'table_camelot': '10A',
#   'table_bpm': '90',
#   'table_energy': '4',
#   'table_link': '/track/6xX6NoYPtEgDWA95cIqUK8/Roar-of-the-Lion-The-Lions-Pit-by-Wu-Tang-Clan-U-God-Kool-G-Rap-RZA',
#   'table_descr': "Wu-Tang Clan, U-God, Kool G Rap, RZA's 'Roar of the Lion (The Lion's Pit)' had a release date set for April 25, 2025. Roar of the Lion (The Lion's Pit) is explicit and may not be suitable for children. With the duration being about 4:09, this song is close to the average duration of a typical track. The song is number 3 out of 12 in Black Samson, the Bastard Swordsman by Wu-Tang Clan, Mathematics. Going off of the ISRC code of this track, we detected that the origin of this track is from Switzerland. In terms of popularity, Roar of the Lion (The Lion's Pit) is currently unknown. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '47',
#   'table_img': '',
#   'table_name': 'Phone Ring (with Benny The Butcher and Maxo Kream)',
#   'table_artist': 'Anwar Carrots, Benny The Butcher, Maxo Kream',
#   'table_data': '2025-04-22',
#   'table_key': 'E Minor',
#   'table_camelot': '9A',
#   'table_bpm': '180',
#   'table_energy': '8',
#   'table_link': '/track/0ypqbEoW7tEKMCwZnSq079/Phone-Ring-with-Benny-The-Butcher-and-Maxo-Kream-by-Anwar-Carrots-Benn',
#   'table_descr': "Anwar Carrots, Benny The Butcher, Maxo Kream's 'Phone Ring (with Benny The Butcher and Maxo Kream)' had a release date set for April 22, 2025. Phone Ring (with Benny The Butcher and Maxo Kream) is 2 minutes and 31 seconds long and may contain bad words that may be unsuitable for children. Since Phone Ring only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. The popularity of Phone Ring (with Benny The Butcher and Maxo Kream) is currently not that popular right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '48',
#   'table_img': '',
#   'table_name': 'MONDAY',
#   'table_artist': 'Quadeca',
#   'table_data': '2025-04-22',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '153',
#   'table_energy': '8',
#   'table_link': '/track/13VNbW9gblZQVVM2a7ZQf5/MONDAY-by-Quadeca',
#   'table_descr': 'Quadeca\'s \'MONDAY\' had a release date set for April 22, 2025. With this song being around four minutes long, at 4:03, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The track order of this song in Quadeca\'s "MONDAY" album is number 1 out of 2. Based on our statistics, MONDAY\'s popularity is average in popularity right now. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_play': '49',
#   'table_img': '',
#   'table_name': 'Heart By Heart',
#   'table_artist': 'Joe Jonas',
#   'table_data': '2025-04-25',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '148',
#   'table_energy': '8',
#   'table_link': '/track/6NUoW7RwcO1jcrSvJ2V6od/Heart-By-Heart-by-Joe-Jonas',
# ...
#  {'table_play': '85',
#   'table_img': '',
#   'table_name': 'Dream A Little Dream',
#   'table_artist': 'Armin van Buuren, Sam Gray',
#   'table_data': '2025-04-25',
#   'table_key': 'E♭ Major',
#   'table_camelot': '5B',
#   'table_bpm': '126',
#   'table_energy': '7',
#   'table_link': '/track/3QLYpJeGjyLMIDj7roEphJ/Dream-A-Little-Dream-by-Armin-van-Buuren-Sam-Gray',
#   'table_descr': 'Armin van Buuren, Sam Gray\'s \' "Dream A Little Dream" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:56. This song does not appear to have any foul language. Dream A Little Dream\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in Dream A Little Dream and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from Netherlands. Based on our statistics, Dream A Little Dream\'s popularity is unknown right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_play': '86',
#   'table_img': '',
#   'table_name': 'Ego',
#   'table_artist': 'Elita',
#   'table_data': '2025-04-24',
#   'table_key': 'A Minor',
#   'table_camelot': '8A',
#   'table_bpm': '150',
#   'table_energy': '8',
#   'table_link': '/track/4RG4FZ5YYzzFYTeNvDyowd/Ego-by-Elita',
#   'table_descr': 'Elita\'s \' "Ego" was released on its scheduled release date, April 24, 2025. Ego is 2 minutes and 59 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in Ego and no other songs are present in the album, we classify this track as a single. Based on our statistics, Ego\'s popularity is unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '87',
#   'table_img': '',
#   'table_name': 'Hot Fun',
#   'table_artist': 'The Hellp',
#   'table_data': '2025-04-24',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '130',
#   'table_energy': '10',
#   'table_link': '/track/2E3p2VCXYQMgxtwDt9dLDO/Hot-Fun-by-The-Hellp',
#   'table_descr': 'The Hellp\'s \' "Hot Fun" was released on its scheduled release date, April 24, 2025. The duration of This song is about 3 minutes long, at 3:14. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in Hot Fun and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. Based on our statistics, Hot Fun\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '88',
#   'table_img': '',
#   'table_name': 'Country in the Clouds',
#   'table_artist': 'Dylan Marlowe, Conner Smith',
#   'table_data': '2025-04-25',
#   'table_key': 'A Major',
#   'table_camelot': '11B',
#   'table_bpm': '196',
#   'table_energy': '8',
#   'table_link': '/track/7FjO69pOVGMhZMEeMsPWkT/Country-in-the-Clouds-by-Dylan-Marlowe-Conner-Smith',
#   'table_descr': 'Dylan Marlowe, Conner Smith\'s \'Country in the Clouds\' had a release date set for April 25, 2025. With this song being around four minutes long, at 3:36, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Country in the Clouds and no other songs are present in the album, we classify this track as a single. The popularity of Country in the Clouds is currently unknown right now. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_play': '89',
#   'table_img': '',
#   'table_name': '77 - feat. Avril Lavigne',
#   'table_artist': 'Billy Idol, Avril Lavigne',
#   'table_data': '2025-04-22',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '166',
#   'table_energy': '9',
#   'table_link': '/track/6cEG5stzTtXrrCLgWKYV6j/77-feat-Avril-Lavigne-by-Billy-Idol-Avril-Lavigne',
#   'table_descr': 'Billy Idol, Avril Lavigne\'s \' "77 - feat. Avril Lavigne" was released on its scheduled release date, April 22, 2025. The duration of This song is about two minutes long, specifically at 2:53. This song does not appear to have any foul language. 77 - feat. Avril Lavigne\'s duration is considered a little bit shorter than the average duration of a typical track. There is only one song in 77 (feat. Avril Lavigne), so we believe that "77 - feat. Avril Lavigne" is a single. The popularity of 77 - feat. Avril Lavigne is currently unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '90',
#   'table_img': '',
#   'table_name': 'U Need 2 Leave',
#   'table_artist': 'Belly Gang Kushington',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '135',
#   'table_energy': '5',
#   'table_link': '/track/1qIaEYGRacHs4VHBocGBx8/U-Need-2-Leave-by-Belly-Gang-Kushington',
#   'table_descr': 'Belly Gang Kushington\'s \'U Need 2 Leave\' had a release date set for April 25, 2025. For a fairly short song, this song is "U Need 2 Leave" is considered an explicit song with a duration of 1:46. There are a total of 14 in the song\'s album "THE STREETS IS YOURS". In this album, this song\'s track order is #8. Based on our statistics, U Need 2 Leave\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_play': '91',
#   'table_img': '',
#   'table_name': 'Found Love',
#   'table_artist': 'Francis Mercier, Von Boch',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '122',
#   'table_energy': '10',
#   'table_link': '/track/1mO3hOEayERMNUGIpAwImF/Found-Love-by-Francis-Mercier-Von-Boch',
#   'table_descr': '"Found Love" by Francis Mercier, Von Boch had its release date on April 25, 2025. The duration of This song is about 3 minutes long, at 3:20. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in Found Love and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, Found Love\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_play': '92',
#   'table_img': '',
#   'table_name': 'Consider Him - Live',
#   'table_artist': 'UPPERROOM, Abbie Gamboa',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '138',
#   'table_energy': '8',
#   'table_link': '/track/0yqqeDcVDTvVHi1Vp0pz2G/Consider-Him-Live-by-UPPERROOM-Abbie-Gamboa',
#   'table_descr': 'UPPERROOM, Abbie Gamboa\'s \'Consider Him - Live\' had a release date set for April 25, 2025. This song is about six minutes long, preciously at 5:32, making this song fairly long compared to other songs. There is only one song in 1350 (Live), so we believe that "Consider Him - Live" is a single. Based on our statistics, Consider Him - Live\'s popularity is unknown right now. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_play': '93',
#   'table_img': '',
#   'table_name': 'Karma',
#   'table_artist': '2BYG',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '206',
#   'table_energy': '8',
#   'table_link': '/track/7DceR0WNzszl53i1b43HPp/Karma-by-2BYG',
#   'table_descr': '2BYG\'s \' "Karma" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:40. This song does not appear to have any foul language. Karma\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in Karma and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. The popularity of Karma is currently unknown right now. The overall mood can be danceable to some, especially with it\'s high amount of postive energy. '},
#  {'table_play': '94',
#   'table_img': '',
#   'table_name': 'Questions',
#   'table_artist': 'Bells Larsen',
#   'table_data': '2025-04-22',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '119',
#   'table_energy': '0',
#   'table_link': '/track/7GHms8hXY5JGws8Fq43pEl/Questions-by-Bells-Larsen',
#   'table_descr': '"Questions" by Bells Larsen had its release date on April 22, 2025. With this song being around four minutes long, at 4:25, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. There are a total of 4 in the song\'s album "Questions". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United States. In terms of popularity, Questions is currently unknown. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_play': '95',
#   'table_img': '',
#   'table_name': 'Nina',
#   'table_artist': 'Cold Court',
#   'table_data': '2025-04-25',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '145',
#   'table_energy': '9',
#   'table_link': '/track/7b69iiHJHiZG3xebISnGlt/Nina-by-Cold-Court',
#   'table_descr': 'Cold Court\'s \' "Nina" was released on its scheduled release date, April 25, 2025. The duration of This song is about 3 minutes long, at 3:27. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in Nina and no other songs are present in the album, we classify this track as a single. Based on our statistics, Nina\'s popularity is unknown right now. The overall mood can be danceable to some, especially with it\'s high amount of postive energy. '},
#  {'table_play': '96',
#   'table_img': '',
#   'table_name': 'In This Mess',
#   'table_artist': 'Say Sue Me',
#   'table_data': '2025-04-22',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '103',
#   'table_energy': '5',
#   'table_link': '/track/5OjGj4GGm0RssCpjUQpcNA/In-This-Mess-by-Say-Sue-Me',
#   'table_descr': 'Say Sue Me\'s \'In This Mess\' had a release date set for April 22, 2025. Since This song is still less than 10 minute long, it is still considered a pretty long duration song compared to the average song length. This song does not appear to be explicit due to the lack of the "E" tag. Because this song is the only song in In This Mess and no other songs are present in the album, we classify this track as a single. On top of that, United Kingdom appears to be the country where this track was created. In terms of popularity, In This Mess is currently not that popular. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_play': '97',
#   'table_img': '',
#   'table_name': 'GPS',
#   'table_artist': 'DFZM, Jombriel, Jowell & Randy',
#   'table_data': '2025-04-24',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '119',
#   'table_energy': '5',
#   'table_link': '/track/4ayXvu5SyyKs16XyExkEjA/GPS-by-DFZM-Jombriel-Jowell-Randy',
#   'table_descr': 'On April 24, 2025, the song "GPS" was released by DFZM, Jombriel, Jowell & Randy. GPS is explicit and may not be suitable for children. With the duration being about 3:51, this song is close to the average duration of a typical track. Because this song is the only song in GPS and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. In terms of popularity, GPS is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '98',
#   'table_img': '',
#   'table_name': 'I Don´t Feel',
#   'table_artist': 'Aggy Ally',
#   'table_data': '2025-04-25',
#   'table_key': 'A Minor',
#   'table_camelot': '8A',
#   'table_bpm': '86',
#   'table_energy': '4',
#   'table_link': '/track/3wqEwrMnhMUboJRVx0cknF/I-Dont-Feel-by-Aggy-Ally',
#   'table_descr': "Aggy Ally's 'I Don´t Feel' had a release date set for April 25, 2025. The duration of This song is about 3 minutes long, at 3:28. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in I Don´t Feel and no other songs are present in the album, we classify this track as a single. On top of that, Sweden appears to be the country where this track was created. I Don´t Feel is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. "},
#  {'table_play': '99',
#   'table_img': '',
#   'table_name': 'How To Get Her',
#   'table_artist': 'John Morgan',
#   'table_data': '2025-04-25',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '102',
#   'table_energy': '8',
#   'table_link': '/track/2gyS1NY8ThGPxgQE08U6ea/How-To-Get-Her-by-John-Morgan',
#   'table_descr': 'John Morgan\'s \'How To Get Her\' had a release date set for April 25, 2025. With this song being about 5 minutes long, at This song is fairly a long song compared to the average song length. This song does not have an "Explicit" tag, making it safe for all ages. The song is number 12 out of 12 in Carolina Blue by John Morgan. In terms of popularity, How To Get Her is currently unknown. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_play': '100',
#   'table_img': '',
#   'table_name': 'Speed Dating',
#   'table_artist': 'DJ Sugarush, Jai Piccone, Hotel Rubio',
#   'table_data': '2025-04-25',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '145',
#   'table_energy': '9',
#   'table_link': '/track/5j2sGJpwHBdSOiTBFG9cX0/Speed-Dating-by-DJ-Sugarush-Jai-Piccone-Hotel-Rubio',
#   'table_descr': "DJ Sugarush, Jai Piccone, Hotel Rubio's 'Speed Dating' had a release date set for April 25, 2025. The duration of This song is about two minutes long, specifically at 2:47. This song does not appear to have any foul language. Speed Dating's duration is considered a little bit shorter than the average duration of a typical track. Since Speed Dating only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from France. Based on our statistics, Speed Dating's popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "}]

# %%
td
# Out:
# [{'table_play': '1',
#   'table_img': '',
#   'table_name': 'What Was That',
#   'table_artist': 'Lorde',
#   'table_data': '2025-04-24',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '168',
#   'table_energy': '6',
#   'table_link': '/track/2jNyiavSywmA472t2m6ZBz/What-Was-That-by-Lorde',
#   'table_descr': '"What Was That" by Lorde had its release date on April 24, 2025. The duration of This song is about 3 minutes long, at 3:29. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Since What Was That only contains only one song in the album, we like to consider this song as a single. Based on our data, New Zealand was the country where this track was produced or recorded. The popularity of What Was That is currently pretty popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_play': '2',
#   'table_img': '',
#   'table_name': 'Mystical Magical',
#   'table_artist': 'Benson Boone',
#   'table_data': '2025-04-24',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '120',
#   'table_energy': '7',
#   'table_link': '/track/221eHga9f9Ne4f8D7WVgPT/Mystical-Magical-by-Benson-Boone',
#   'table_descr': 'On April 24, 2025, the song "Mystical Magical" was released by Benson Boone. The duration of This song is about two minutes long, specifically at 2:45. This song does not appear to have any foul language. Mystical Magical\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in Mystical Magical and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. Based on our statistics, Mystical Magical\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '3',
#   'table_img': '',
#   'table_name': 'Is This Really Love?',
#   'table_artist': 'd4vd',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '160',
#   'table_energy': '7',
#   'table_link': '/track/0h2vooD5PFOykbPon6ShIZ/Is-This-Really-Love-by-d4vd',
#   'table_descr': 'd4vd\'s \' "Is This Really Love?" was released on its scheduled release date, April 25, 2025. The duration of This song is about 3 minutes long, at 3:15. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. This song is part of WITHERED by d4vd. The song\'s track number on the album is #9 out of 15 tracks. Based on our data, United States was the country where this track was produced or recorded. The popularity of Is This Really Love? is currently unknown right now. Based on the vibe, this track doesn\'t seem to be that danceable, however its valence properties can make this some somewhat danceable. '},
#  {'table_play': '4',
#   'table_img': '',
#   'table_name': 'Money On Money (feat. Future)',
#   'table_artist': 'Young Thug, Future',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '120',
#   'table_energy': '7',
#   'table_link': '/track/5eW508Gq23QlXHowyzW39m/Money-On-Money-feat-Future-by-Young-Thug-Future',
#   'table_descr': '"Money On Money (feat. Future)" by Young Thug, Future had its release date on April 25, 2025. Money On Money (feat. Future) is explicit and may not be suitable for children. With the duration being about 3:56, this song is close to the average duration of a typical track. Because this song is the only song in Money On Money (feat. Future) and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. Based on our statistics, Money On Money (feat. Future)\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_play': '5',
#   'table_img': '',
#   'table_name': 'ILYSMIH',
#   'table_artist': 'Kali Uchis',
#   'table_data': '2025-04-25',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '126',
#   'table_energy': '7',
#   'table_link': '/track/3WvPycGo4WJEEGYP429aap/ILYSMIH-by-Kali-Uchis',
#   'table_descr': 'Kali Uchis\'s \' "ILYSMIH" was released on its scheduled release date, April 25, 2025. With this song being around four minutes long, at 3:33, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The track order of this song in Kali Uchis\'s "ILYSMIH" album is number 1 out of 2. On top of that, United States appears to be the country where this track was created. Based on our statistics, ILYSMIH\'s popularity is unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '6',
#   'table_img': '',
#   'table_name': 'Amen',
#   'table_artist': 'Shaboozey, Jelly Roll',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '81',
#   'table_energy': '5',
#   'table_link': '/track/2iSfSJrho5XkU2NmAnZ9ZV/Amen-by-Shaboozey-Jelly-Roll',
#   'table_descr': "Shaboozey, Jelly Roll's 'Amen' had a release date set for April 25, 2025. The duration of This song is about 3 minutes long, at 3:17. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. This song is part of Where I've Been, Isn't Where I'm Going: The Complete Edition by Shaboozey. The song's track number on the album is #13 out of 18 tracks. Based on our data, United States was the country where this track was produced or recorded. Amen is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '7',
#   'table_img': '',
#   'table_name': 'At The Beach, In Every Life',
#   'table_artist': 'Gigi Perez',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '84',
#   'table_energy': '4',
#   'table_link': '/track/5LfgzPHvka22FdRAxOme6m/At-The-Beach-In-Every-Life-by-Gigi-Perez',
#   'table_descr': 'Gigi Perez\'s \'At The Beach, In Every Life\' had a release date set for April 25, 2025. With this song being around four minutes long, at 3:57, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The song is number 12 out of 12 in At The Beach, In Every Life by Gigi Perez. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. At The Beach, In Every Life is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_play': '8',
#   'table_img': '',
#   'table_name': 'Whenever',
#   'table_artist': 'Megan Thee Stallion',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '120',
#   'table_energy': '7',
#   'table_link': '/track/4oVUfLx1BVgXbPXc0MlPkr/Whenever-by-Megan-Thee-Stallion',
#   'table_descr': '"Whenever" by Megan Thee Stallion had its release date on April 25, 2025. Whenever is 2 minutes and 45 seconds long and may contain bad words that may be unsuitable for children. Since Whenever only contains only one song in the album, we like to consider this song as a single. Based on our data, United States was the country where this track was produced or recorded. Based on our statistics, Whenever\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_play': '9',
#   'table_img': '',
#   'table_name': 'Down to be wrong',
#   'table_artist': 'HAIM',
#   'table_data': '2025-04-24',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '165',
#   'table_energy': '7',
#   'table_link': '/track/2d18juMmmN1KwjFtfEj0FP/Down-to-be-wrong-by-HAIM',
#   'table_descr': 'HAIM\'s \' "Down to be wrong" was released on its scheduled release date, April 24, 2025. With this song being around four minutes long, at 4:09, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The song is number 1 out of 3 in Down to be wrong by HAIM. Going off of the ISRC code of this track, we detected that the origin of this track is from United Kingdom. The popularity of Down to be wrong is currently unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '10',
#   'table_img': '',
#   'table_name': 'Brunette',
#   'table_artist': 'Tucker Wetmore',
#   'table_data': '2025-04-25',
#   'table_key': 'F♯ Major',
#   'table_camelot': '2B',
#   'table_bpm': '115',
#   'table_energy': '7',
#   'table_link': '/track/21T9HvQ0KUWFDum6P1Qc7i/Brunette-by-Tucker-Wetmore',
#   'table_descr': 'Tucker Wetmore\'s \' "Brunette" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:19. This song does not appear to have any foul language. Brunette\'s duration is considered a little bit shorter than the average duration of a typical track. This song is part of What Not To by Tucker Wetmore. The song\'s track number on the album is #6 out of 19 tracks. Based on our data, United States was the country where this track was produced or recorded. In terms of popularity, Brunette is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '11',
#   'table_img': '',
#   'table_name': 'PIDA LO QUE QUIERA MAMI - A COLORS SHOW',
#   'table_artist': 'Feid, COLORS',
#   'table_data': '2025-04-21',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '110',
#   'table_energy': '4',
#   'table_link': '/track/0PAqSz4d5lJfAscDDmIxzX/PIDA-LO-QUE-QUIERA-MAMI-A-COLORS-SHOW-by-Feid-COLORS',
#   'table_descr': 'Feid, COLORS\'s \' "PIDA LO QUE QUIERA MAMI - A COLORS SHOW" was released on its scheduled release date, April 21, 2025. The duration of This song is about 3 minutes long, at 3:27. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Since PIDA LO QUE QUIERA MAMI - A COLORS SHOW only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. In terms of popularity, PIDA LO QUE QUIERA MAMI - A COLORS SHOW is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '12',
#   'table_img': '',
#   'table_name': 'On Sight',
#   'table_artist': 'Coco Jones',
#   'table_data': '2025-04-25',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '90',
#   'table_energy': '5',
#   'table_link': '/track/0Tdpdo2ZD1CefcFTTbm0xx/On-Sight-by-Coco-Jones',
#   'table_descr': "Coco Jones's 'On Sight' had a release date set for April 25, 2025. On Sight is explicit and may not be suitable for children. With the duration being about 4:27, this song is close to the average duration of a typical track. This song is part of Why Not More? by Coco Jones. The song's track number on the album is #3 out of 14 tracks. Based on our data, United States was the country where this track was produced or recorded. In terms of popularity, On Sight is currently unknown. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. "},
#  {'table_play': '13',
#   'table_img': '',
#   'table_name': 'Carousel',
#   'table_artist': 'Samia',
#   'table_data': '2025-04-22',
#   'table_key': 'F♯ Major',
#   'table_camelot': '2B',
#   'table_bpm': '80',
#   'table_energy': '4',
#   'table_link': '/track/6xErF43Ru9Y0r21iHWaj0J/Carousel-by-Samia',
#   'table_descr': '"Carousel" by Samia had its release date on April 22, 2025. The duration of This song is about 3 minutes long, at 3:27. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. The song is number 1 out of 5 in Carousel by Samia. Carousel is unknown right now. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_play': '14',
#   'table_img': '',
#   'table_name': 'Stateside',
#   'table_artist': 'PinkPantheress',
#   'table_data': '2025-04-25',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '123',
#   'table_energy': '9',
#   'table_link': '/track/7Fr2Q6q3rAxFUcMkuvVrXO/Stateside-by-PinkPantheress',
#   'table_descr': 'PinkPantheress\'s \' "Stateside" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:48. This song does not appear to have any foul language. Stateside\'s duration is considered a little bit shorter than the average duration of a typical track. There are a total of 2 in the song\'s album "Stateside". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United Kingdom. Based on our statistics, Stateside\'s popularity is unknown right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_play': '15',
#   'table_img': '',
#   'table_name': 'Nostalgia',
#   'table_artist': 'Sammy Virji, Issey Cross',
#   'table_data': '2025-04-25',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '132',
#   'table_energy': '6',
#   'table_link': '/track/5D5uC8J6xBkGN66eLnqdvG/Nostalgia-by-Sammy-Virji-Issey-Cross',
#   'table_descr': '"Nostalgia" by Sammy Virji, Issey Cross had its release date on April 25, 2025. With this song being around four minutes long, at 3:30, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Nostalgia and no other songs are present in the album, we classify this track as a single. Furthermore, we believe that the track originated from United Kingdom. Based on our statistics, Nostalgia\'s popularity is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_play': '16',
#   'table_img': '',
#   'table_name': 'Peacefield - Single Version',
#   'table_artist': 'Ghost',
#   'table_data': '2025-04-22',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '103',
#   'table_energy': '9',
#   'table_link': '/track/6j9GJGI7sogofbagE6za5E/Peacefield-Single-Version-by-Ghost',
#   'table_descr': 'Ghost\'s \' "Peacefield - Single Version" was released on its scheduled release date, April 22, 2025. With this song being about 5 minutes long, at This song is fairly a long song compared to the average song length. This song does not have an "Explicit" tag, making it safe for all ages. There are a total of 2 in the song\'s album "Peacefield". In this album, this song\'s track order is #2. Furthermore, we believe that the track originated from United States. In terms of popularity, Peacefield - Single Version is currently unknown. The overall mood can be danceable to some, especially with it\'s high amount of postive energy. '},
#  {'table_play': '17',
#   'table_img': '',
#   'table_name': 'BAD BITCHES!',
#   'table_artist': 'DESTIN CONRAD, Kehlani',
#   'table_data': '2025-04-25',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '87',
#   'table_energy': '4',
#   'table_link': '/track/5ld2rB0d5nG8RTQRRmkxNa/BAD-BITCHES-by-DESTIN-CONRAD-Kehlani',
#   'table_descr': 'DESTIN CONRAD, Kehlani\'s \' "BAD BITCHES!" was released on its scheduled release date, April 25, 2025. BAD BITCHES! is explicit and may not be suitable for children. With the duration being about 3:45, this song is close to the average duration of a typical track. The track order of this song in DESTIN CONRAD\'s "LOVE ON DIGITAL" album is number 4 out of 15. On top of that, United States appears to be the country where this track was created. BAD BITCHES! is unknown right now. Based on the vibe, this track doesn\'t seem to be that danceable, however its valence properties can make this some somewhat danceable. '},
#  {'table_play': '18',
#   'table_img': '',
#   'table_name': 'Gripper (feat. T-Pain)',
#   'table_artist': 'Flo Milli, T-Pain',
#   'table_data': '2025-04-25',
#   'table_key': 'C Minor',
#   'table_camelot': '5A',
#   'table_bpm': '133',
#   'table_energy': '6',
#   'table_link': '/track/0OBXjsLYqftAOhCMEcAeAs/Gripper-feat-T-Pain-by-Flo-Milli-T-Pain',
#   'table_descr': 'Flo Milli, T-Pain\'s \' "Gripper (feat. T-Pain)" was released on its scheduled release date, April 25, 2025. Gripper (feat. T-Pain) is 2 minutes and 52 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in Gripper (feat. T-Pain) and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. Based on our statistics, Gripper (feat. T-Pain)\'s popularity is unknown right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_play': '19',
#   'table_img': '',
#   'table_name': 'Pack It Up',
#   'table_artist': 'ian',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '134',
#   'table_energy': '5',
#   'table_link': '/track/0ZvlEr2LkJUO6eYMVi74Io/Pack-It-Up-by-ian',
#   'table_descr': 'ian\'s \' "Pack It Up" was released on its scheduled release date, April 25, 2025. For a fairly short song, this song is "Pack It Up" is considered an explicit song with a duration of 1:54. Since Pack It Up only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. Based on our statistics, Pack It Up\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '20',
#   'table_img': '',
#   'table_name': 'Damocles',
#   'table_artist': 'Sleep Token',
#   'table_data': '2025-04-25',
#   'table_key': 'F♯ Major',
#   'table_camelot': '2B',
#   'table_bpm': '156',
#   'table_energy': '6',
#   'table_link': '/track/1ulH5PIntNj0ro2K69W4Fx/Damocles-by-Sleep-Token',
#   'table_descr': 'Sleep Token\'s \'Damocles\' had a release date set for April 25, 2025. With this song being around four minutes long, at 4:24, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Damocles and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, Damocles\'s popularity is fairly popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_play': '21',
#   'table_img': '',
#   'table_name': 'My First Heartbreak',
#   'table_artist': 'Myles Smith',
#   'table_data': '2025-04-25',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '82',
#   'table_energy': '5',
#   'table_link': '/track/5gbUP33wFJPawjY5DxR3OA/My-First-Heartbreak-by-Myles-Smith',
#   'table_descr': "Myles Smith's 'My First Heartbreak' had a release date set for April 25, 2025. The duration of This song is about 3 minutes long, at 3:26. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in My First Heartbreak and no other songs are present in the album, we classify this track as a single. On top of that, United Kingdom appears to be the country where this track was created. My First Heartbreak is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. "},
#  {'table_play': '22',
#   'table_img': '',
#   'table_name': 'Learn The Hard Way',
#   'table_artist': 'Jordan Davis',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '77',
#   'table_energy': '9',
#   'table_link': '/track/3xB2R2tf0T2TXaB4AWoPjT/Learn-The-Hard-Way-by-Jordan-Davis',
#   'table_descr': 'On April 25, 2025, the song "Learn The Hard Way" was released by Jordan Davis. The duration of This song is about two minutes long, specifically at 2:48. This song does not appear to have any foul language. Learn The Hard Way\'s duration is considered a little bit shorter than the average duration of a typical track. The track order of this song in Jordan Davis\'s "Learn The Hard Way" album is number 1 out of 3. On top of that, United States appears to be the country where this track was created. Learn The Hard Way is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '23',
#   'table_img': '',
#   'table_name': 'Unshatter',
#   'table_artist': 'Linkin Park',
#   'table_data': '2025-04-25',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '107',
#   'table_energy': '9',
#   'table_link': '/track/0D7RVmTlKkmRchqKA4zJht/Unshatter-by-Linkin-Park',
#   'table_descr': 'Linkin Park\'s \' "Unshatter" was released on its scheduled release date, April 25, 2025. The duration of This song is about 3 minutes long, at 3:16. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. There are a total of 2 in the song\'s album "Unshatter". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United States. In terms of popularity, Unshatter is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '24',
#   'table_img': '',
#   'table_name': 'T.H.',
#   'table_artist': 'SAULT',
#   'table_data': '2025-04-18',
#   'table_key': 'E♭ Minor',
#   'table_camelot': '2A',
#   'table_bpm': '134',
#   'table_energy': '6',
#   'table_link': '/track/7Cj2Buxud8yjgRCdRW6VUs/TH-by-SAULT',
#   'table_descr': 'SAULT\'s \' "T.H." was released on its scheduled release date, April 18, 2025. With this song being about 5 minutes long, at This song is fairly a long song compared to the average song length. This song does not have an "Explicit" tag, making it safe for all ages. There is only one song in 10, so we believe that "T.H." is a single. Based on our statistics, T.H.\'s popularity is below average in popularity right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '25',
#   'table_img': '',
#   'table_name': 'Poplife',
#   'table_artist': 'umru, underscores',
#   'table_data': '2025-04-24',
#   'table_key': 'A Minor',
#   'table_camelot': '8A',
#   'table_bpm': '142',
#   'table_energy': '8',
#   'table_link': '/track/2cClnOEBnNJWxbLuTFVIgK/Poplife-by-umru-underscores',
#   'table_descr': 'umru, underscores\'s \' "Poplife" was released on its scheduled release date, April 24, 2025. The duration of This song is about two minutes long, specifically at 2:43. This song does not appear to have any foul language. Poplife\'s duration is considered a little bit shorter than the average duration of a typical track. Since Poplife only contains only one song in the album, we like to consider this song as a single. Based on our statistics, Poplife\'s popularity is average in popularity right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '26',
#   'table_img': '',
#   'table_name': 'Tell Me Where U Go',
#   'table_artist': 'Clean Bandit, Tiësto, Leony',
#   'table_data': '2025-04-25',
#   'table_key': 'G Minor',
#   'table_camelot': '6A',
#   'table_bpm': '142',
#   'table_energy': '8',
#   'table_link': '/track/4NuksWELZ9lBY9aazhZG16/Tell-Me-Where-U-Go-by-Clean-Bandit-Tisto-Leony',
#   'table_descr': "Clean Bandit, Tiësto, Leony's 'Tell Me Where U Go' had a release date set for April 25, 2025. Tell Me Where U Go is considered explicit and may contain foul language. This song is about 3 minutes and 2 seconds, which is about the average length of a typical song. Since Tell Me Where U Go only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United Kingdom. Based on our statistics, Tell Me Where U Go's popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '27',
#   'table_img': '',
#   'table_name': 'AMISTAD',
#   'table_artist': 'Blessd, Ovy On The Drums',
#   'table_data': '2025-04-24',
#   'table_key': 'F Major',
#   'table_camelot': '7B',
#   'table_bpm': '170',
#   'table_energy': '6',
#   'table_link': '/track/1TzQqJ4hme55ZKnM86Xyw0/AMISTAD-by-Blessd-Ovy-On-The-Drums',
#   'table_descr': 'Blessd, Ovy On The Drums\'s \' "AMISTAD" was released on its scheduled release date, April 24, 2025. AMISTAD is 2 minutes and 57 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in AMISTAD and no other songs are present in the album, we classify this track as a single. The popularity of AMISTAD is currently unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '28',
#   'table_img': '',
#   'table_name': 'Gimme Dat (feat. Wizkid)',
#   'table_artist': 'Ayra Starr, Wizkid',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Major',
#   'table_camelot': '6B',
#   'table_bpm': '95',
#   'table_energy': '8',
#   'table_link': '/track/1k51Q6GFWBbsaWlBB2gnzo/Gimme-Dat-feat-Wizkid-by-Ayra-Starr-Wizkid',
#   'table_descr': 'Ayra Starr, Wizkid\'s \' "Gimme Dat (feat. Wizkid)" was released on its scheduled release date, April 25, 2025. With this song being around four minutes long, at 3:45, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Gimme Dat and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. In terms of popularity, Gimme Dat (feat. Wizkid) is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '29',
#   'table_img': '',
#   'table_name': 'Rich Guys (Feat. Babyfxce E)',
#   'table_artist': 'BabyChiefDoit, Babyfxce E',
#   'table_data': '2025-04-23',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '157',
#   'table_energy': '5',
#   'table_link': '/track/7a1Iw4S1eNozL4C4gv5xSg/Rich-Guys-Feat-Babyfxce-E-by-BabyChiefDoit-Babyfxce-E',
#   'table_descr': '"Rich Guys (Feat. Babyfxce E)" by BabyChiefDoit, Babyfxce E had its release date on April 23, 2025. Rich Guys (Feat. Babyfxce E) is 2 minutes and 58 seconds long and may contain bad words that may be unsuitable for children. This song is part of ZOO LIFE by BabyChiefDoit. The song\'s track number on the album is #2 out of 13 tracks. Based on our statistics, Rich Guys (Feat. Babyfxce E)\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_play': '30',
#   'table_img': '',
#   'table_name': 'What Da Fuk',
#   'table_artist': 'PLUTO',
#   'table_data': '2025-04-24',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '156',
#   'table_energy': '8',
#   'table_link': '/track/46e5RkqWEBRLebmdCK9t7o/What-Da-Fuk-by-PLUTO',
#   'table_descr': "PLUTO's 'What Da Fuk' had a release date set for April 24, 2025. What Da Fuk is 2 minutes and 36 seconds long and may contain bad words that may be unsuitable for children. This song is part of What Da Fuk by PLUTO. The song's track number on the album is #1 out of 2 tracks. Based on our data, United States was the country where this track was produced or recorded. Based on our statistics, What Da Fuk's popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '31',
#   'table_img': '',
#   'table_name': 'Pretty Ugly',
#   'table_artist': 'Zara Larsson',
#   'table_data': '2025-04-25',
#   'table_key': 'C Minor',
#   'table_camelot': '5A',
#   'table_bpm': '111',
#   'table_energy': '7',
#   'table_link': '/track/0lWcOHxfnxj1GlVr4zpnyD/Pretty-Ugly-by-Zara-Larsson',
#   'table_descr': 'Zara Larsson\'s \' "Pretty Ugly" was released on its scheduled release date, April 25, 2025. Pretty Ugly is 2 minutes and 38 seconds long and may contain bad words that may be unsuitable for children. Since Pretty Ugly only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. In terms of popularity, Pretty Ugly is currently unknown. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_play': '32',
#   'table_img': '',
#   'table_name': 'I could',
#   'table_artist': 'Fine',
#   'table_data': '2025-04-23',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '147',
#   'table_energy': '6',
#   'table_link': '/track/5EmtveGyjsE023P8atahBQ/I-could-by-Fine',
#   'table_descr': 'Fine\'s \' "I could" was released on its scheduled release date, April 23, 2025. The duration of This song is about two minutes long, specifically at 2:36. This song does not appear to have any foul language. I could\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in I could and no other songs are present in the album, we classify this track as a single. On top of that, France appears to be the country where this track was created. Based on our statistics, I could\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '33',
#   'table_img': '',
#   'table_name': 'buzzkill',
#   'table_artist': 'Lyn Lapid',
#   'table_data': '2025-04-25',
#   'table_key': 'D Major',
#   'table_camelot': '10B',
#   'table_bpm': '144',
#   'table_energy': '7',
#   'table_link': '/track/1xo0olV5DcTUQX9cpoUv5m/buzzkill-by-Lyn-Lapid',
#   'table_descr': 'Lyn Lapid\'s \' "buzzkill" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:35. This song does not appear to have any foul language. buzzkill\'s duration is considered a little bit shorter than the average duration of a typical track. The song is number 1 out of 12 in BUZZKILL by Lyn Lapid. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, buzzkill\'s popularity is unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '34',
#   'table_img': '',
#   'table_name': 'Alē',
#   'table_artist': 'Chezile',
#   'table_data': '2025-04-25',
#   'table_key': 'G Minor',
#   'table_camelot': '6A',
#   'table_bpm': '89',
#   'table_energy': '6',
#   'table_link': '/track/5xkWnuF0eA5ODVKiTJaQXZ/Al-by-Chezile',
#   'table_descr': "Chezile's 'Alē' had a release date set for April 25, 2025. The duration of This song is about two minutes long, specifically at 2:51. This song does not appear to have any foul language. Alē's duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in Alē and no other songs are present in the album, we classify this track as a single. Alē is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '35',
#   'table_img': '',
#   'table_name': 'Let Me Be Wrong',
#   'table_artist': 'Jensen McRae',
#   'table_data': '2025-04-25',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '203',
#   'table_energy': '5',
#   'table_link': '/track/7iueQDyeYZRXZc4DYYAwDw/Let-Me-Be-Wrong-by-Jensen-McRae',
#   'table_descr': 'Jensen McRae\'s \' "Let Me Be Wrong" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:36. This song does not appear to have any foul language. Let Me Be Wrong\'s duration is considered a little bit shorter than the average duration of a typical track. The track order of this song in Jensen McRae\'s "I Don\'t Know How But They Found Me!" album is number 5 out of 11. On top of that, United States appears to be the country where this track was created. The popularity of Let Me Be Wrong is currently unknown right now. Based on the vibe, this track doesn\'t seem to be that danceable, however its valence properties can make this some somewhat danceable. '},
#  {'table_play': '36',
#   'table_img': '',
#   'table_name': 'Sungazing - Electronic Mix',
#   'table_artist': 'Michael Bibi, Alexa Sunshine Rose',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '130',
#   'table_energy': '8',
#   'table_link': '/track/0H72o8QdyYc57jNkvYwfAX/Sungazing-Electronic-Mix-by-Michael-Bibi-Alexa-Sunshine-Rose',
#   'table_descr': 'Michael Bibi, Alexa Sunshine Rose\'s \' "Sungazing - Electronic Mix" was released on its scheduled release date, April 25, 2025. With this song being around four minutes long, at 4:07, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Since Sungazing (Electronic Mix) only contains only one song in the album, we like to consider this song as a single. Based on our statistics, Sungazing - Electronic Mix\'s popularity is unknown right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_play': '37',
#   'table_img': '',
#   'table_name': 'WASSUP',
#   'table_artist': 'Young Miko',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '145',
#   'table_energy': '7',
#   'table_link': '/track/32SJM4tQyJHsB8rgVtZURn/WASSUP-by-Young-Miko',
#   'table_descr': 'Young Miko\'s \' "WASSUP" was released on its scheduled release date, April 25, 2025. WASSUP is 2 minutes and 42 seconds long and may contain bad words that may be unsuitable for children. Since WASSUP only contains only one song in the album, we like to consider this song as a single. Based on our statistics, WASSUP\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '38',
#   'table_img': '',
#   'table_name': 'IMMA RIDE 4 YOU',
#   'table_artist': '$NOT',
#   'table_data': '2025-04-20',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '139',
#   'table_energy': '5',
#   'table_link': '/track/1JPKeahg89aOPJYGa0JDFC/IMMA-RIDE-4-YOU-by-NOT',
#   'table_descr': '$NOT\'s \' "IMMA RIDE 4 YOU" was released on its scheduled release date, April 20, 2025. IMMA RIDE 4 YOU is 2 minutes and 26 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in IMMA RIDE 4 YOU and no other songs are present in the album, we classify this track as a single. Based on our statistics, IMMA RIDE 4 YOU\'s popularity is average in popularity right now. The overall mood can be danceable to some, especially with it\'s high amount of postive energy. '},
#  {'table_play': '39',
#   'table_img': '',
#   'table_name': 'Dead Body',
#   'table_artist': 'MAF Teeski, Skrilla',
#   'table_data': '2025-04-23',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '88',
#   'table_energy': '5',
#   'table_link': '/track/7yT8OCnOJ9oFajVE6RVPm4/Dead-Body-by-MAF-Teeski-Skrilla',
#   'table_descr': "MAF Teeski, Skrilla's 'Dead Body' had a release date set for April 23, 2025. Dead Body is 2 minutes and 42 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in Dead Body and no other songs are present in the album, we classify this track as a single. Dead Body is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. "},
#  {'table_play': '40',
#   'table_img': '',
#   'table_name': 'What I Used To Get Into',
#   'table_artist': 'Roy Woods',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '84',
#   'table_energy': '6',
#   'table_link': '/track/4GEAQAtCQ50j0lZP9k4SMT/What-I-Used-To-Get-Into-by-Roy-Woods',
#   'table_descr': 'Roy Woods\'s \' "What I Used To Get Into" was released on its scheduled release date, April 25, 2025. What I Used To Get Into is considered explicit and may contain foul language. This song is about 3 minutes and 12 seconds, which is about the average length of a typical song. The song is number 5 out of 9 in Dark Nights by Roy Woods. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. What I Used To Get Into is unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '41',
#   'table_img': '',
#   'table_name': 'Darkness Always Wins',
#   'table_artist': 'Halestorm',
#   'table_data': '2025-04-22',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '170',
#   'table_energy': '6',
#   'table_link': '/track/7wBKXbleeJQuQDnfKlOOGe/Darkness-Always-Wins-by-Halestorm',
#   'table_descr': '"Darkness Always Wins" by Halestorm had its release date on April 22, 2025. With this song being about 5 minutes long, at This song is fairly a long song compared to the average song length. This song does not have an "Explicit" tag, making it safe for all ages. Because this song is the only song in Darkness Always Wins and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. The popularity of Darkness Always Wins is currently unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_play': '42',
#   'table_img': '',
#   'table_name': "I Don't Know Why (I Just Do)",
#   'table_artist': 'Jeff Goldblum & The Mildred Snitzer Orchestra, Ariana Grande',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '95',
#   'table_energy': '4',
#   'table_link': '/track/0WiIGxBzkA2SvE8clbz3X0/I-Dont-Know-Why-I-Just-Do-by-Jeff-Goldblum-The-Mildred-Snitzer-Orchest',
#   'table_descr': '"I Don\'t Know Why (I Just Do)" by Jeff Goldblum & The Mildred Snitzer Orchestra, Ariana Grande had its release date on April 25, 2025. With this song being around four minutes long, at 3:44, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. There are a total of 9 in the song\'s album "Still Blooming". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United Kingdom. In terms of popularity, I Don\'t Know Why (I Just Do) is currently unknown. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_play': '43',
#   'table_img': '',
#   'table_name': 'Hitch Hiking',
#   'table_artist': 'Jenna Raine',
#   'table_data': '2025-04-25',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '170',
#   'table_energy': '6',
#   'table_link': '/track/5nkg0pxD5dN91JBzlvI90W/Hitch-Hiking-by-Jenna-Raine',
#   'table_descr': 'Jenna Raine\'s \' "Hitch Hiking" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:50. This song does not appear to have any foul language. Hitch Hiking\'s duration is considered a little bit shorter than the average duration of a typical track. There are a total of 6 in the song\'s album "Only Started Growing". In this album, this song\'s track order is #3. Furthermore, we believe that the track originated from United States. The popularity of Hitch Hiking is currently unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '44',
#   'table_img': '',
#   'table_name': 'Dreamin',
#   'table_artist': 'BRONCHO',
#   'table_data': '2025-04-25',
#   'table_key': 'F Major',
#   'table_camelot': '7B',
#   'table_bpm': '110',
#   'table_energy': '3',
#   'table_link': '/track/4cYvM8q9V6HTEayIBHuP1W/Dreamin-by-BRONCHO',
#   'table_descr': 'BRONCHO\'s \' "Dreamin" was released on its scheduled release date, April 25, 2025. The duration of This song is about 3 minutes long, at 3:26. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. There are a total of 12 in the song\'s album "Natural Pleasure". In this album, this song\'s track order is #12. Furthermore, we believe that the track originated from Turks and Caicos Islands. In terms of popularity, Dreamin is currently unknown. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_play': '45',
#   'table_img': '',
#   'table_name': 'No Enemies (feat. Namasenda)',
#   'table_artist': 'Sebastian Ingrosso, Steve Angello, Namasenda',
#   'table_data': '2025-04-24',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '134',
#   'table_energy': '6',
#   'table_link': '/track/55gp7v87CYS1lxWQ5ho5nK/No-Enemies-feat-Namasenda-by-Sebastian-Ingrosso-Steve-Angello-Namasend',
#   'table_descr': "Sebastian Ingrosso, Steve Angello, Namasenda's 'No Enemies (feat. Namasenda)' had a release date set for April 24, 2025. The duration of This song is about two minutes long, specifically at 2:40. This song does not appear to have any foul language. No Enemies (feat. Namasenda)'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in No Enemies (feat. Namasenda) and no other songs are present in the album, we classify this track as a single. Furthermore, we believe that the track originated from United States. Based on our statistics, No Enemies (feat. Namasenda)'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '46',
#   'table_img': '',
#   'table_name': "Roar of the Lion (The Lion's Pit)",
#   'table_artist': 'Wu-Tang Clan, U-God, Kool G Rap, RZA',
#   'table_data': '2025-04-25',
#   'table_key': 'B Minor',
#   'table_camelot': '10A',
#   'table_bpm': '90',
#   'table_energy': '4',
#   'table_link': '/track/6xX6NoYPtEgDWA95cIqUK8/Roar-of-the-Lion-The-Lions-Pit-by-Wu-Tang-Clan-U-God-Kool-G-Rap-RZA',
#   'table_descr': "Wu-Tang Clan, U-God, Kool G Rap, RZA's 'Roar of the Lion (The Lion's Pit)' had a release date set for April 25, 2025. Roar of the Lion (The Lion's Pit) is explicit and may not be suitable for children. With the duration being about 4:09, this song is close to the average duration of a typical track. The song is number 3 out of 12 in Black Samson, the Bastard Swordsman by Wu-Tang Clan, Mathematics. Going off of the ISRC code of this track, we detected that the origin of this track is from Switzerland. In terms of popularity, Roar of the Lion (The Lion's Pit) is currently unknown. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '47',
#   'table_img': '',
#   'table_name': 'Phone Ring (with Benny The Butcher and Maxo Kream)',
#   'table_artist': 'Anwar Carrots, Benny The Butcher, Maxo Kream',
#   'table_data': '2025-04-22',
#   'table_key': 'E Minor',
#   'table_camelot': '9A',
#   'table_bpm': '180',
#   'table_energy': '8',
#   'table_link': '/track/0ypqbEoW7tEKMCwZnSq079/Phone-Ring-with-Benny-The-Butcher-and-Maxo-Kream-by-Anwar-Carrots-Benn',
#   'table_descr': "Anwar Carrots, Benny The Butcher, Maxo Kream's 'Phone Ring (with Benny The Butcher and Maxo Kream)' had a release date set for April 22, 2025. Phone Ring (with Benny The Butcher and Maxo Kream) is 2 minutes and 31 seconds long and may contain bad words that may be unsuitable for children. Since Phone Ring only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. The popularity of Phone Ring (with Benny The Butcher and Maxo Kream) is currently not that popular right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_play': '48',
#   'table_img': '',
#   'table_name': 'MONDAY',
#   'table_artist': 'Quadeca',
#   'table_data': '2025-04-22',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '153',
#   'table_energy': '8',
#   'table_link': '/track/13VNbW9gblZQVVM2a7ZQf5/MONDAY-by-Quadeca',
#   'table_descr': 'Quadeca\'s \'MONDAY\' had a release date set for April 22, 2025. With this song being around four minutes long, at 4:03, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The track order of this song in Quadeca\'s "MONDAY" album is number 1 out of 2. Based on our statistics, MONDAY\'s popularity is average in popularity right now. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_play': '49',
#   'table_img': '',
#   'table_name': 'Heart By Heart',
#   'table_artist': 'Joe Jonas',
#   'table_data': '2025-04-25',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '148',
#   'table_energy': '8',
#   'table_link': '/track/6NUoW7RwcO1jcrSvJ2V6od/Heart-By-Heart-by-Joe-Jonas',
# ...
#  {'table_play': '85',
#   'table_img': '',
#   'table_name': 'Dream A Little Dream',
#   'table_artist': 'Armin van Buuren, Sam Gray',
#   'table_data': '2025-04-25',
#   'table_key': 'E♭ Major',
#   'table_camelot': '5B',
#   'table_bpm': '126',
#   'table_energy': '7',
#   'table_link': '/track/3QLYpJeGjyLMIDj7roEphJ/Dream-A-Little-Dream-by-Armin-van-Buuren-Sam-Gray',
#   'table_descr': 'Armin van Buuren, Sam Gray\'s \' "Dream A Little Dream" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:56. This song does not appear to have any foul language. Dream A Little Dream\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in Dream A Little Dream and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from Netherlands. Based on our statistics, Dream A Little Dream\'s popularity is unknown right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_play': '86',
#   'table_img': '',
#   'table_name': 'Ego',
#   'table_artist': 'Elita',
#   'table_data': '2025-04-24',
#   'table_key': 'A Minor',
#   'table_camelot': '8A',
#   'table_bpm': '150',
#   'table_energy': '8',
#   'table_link': '/track/4RG4FZ5YYzzFYTeNvDyowd/Ego-by-Elita',
#   'table_descr': 'Elita\'s \' "Ego" was released on its scheduled release date, April 24, 2025. Ego is 2 minutes and 59 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in Ego and no other songs are present in the album, we classify this track as a single. Based on our statistics, Ego\'s popularity is unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '87',
#   'table_img': '',
#   'table_name': 'Hot Fun',
#   'table_artist': 'The Hellp',
#   'table_data': '2025-04-24',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '130',
#   'table_energy': '10',
#   'table_link': '/track/2E3p2VCXYQMgxtwDt9dLDO/Hot-Fun-by-The-Hellp',
#   'table_descr': 'The Hellp\'s \' "Hot Fun" was released on its scheduled release date, April 24, 2025. The duration of This song is about 3 minutes long, at 3:14. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in Hot Fun and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. Based on our statistics, Hot Fun\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '88',
#   'table_img': '',
#   'table_name': 'Country in the Clouds',
#   'table_artist': 'Dylan Marlowe, Conner Smith',
#   'table_data': '2025-04-25',
#   'table_key': 'A Major',
#   'table_camelot': '11B',
#   'table_bpm': '196',
#   'table_energy': '8',
#   'table_link': '/track/7FjO69pOVGMhZMEeMsPWkT/Country-in-the-Clouds-by-Dylan-Marlowe-Conner-Smith',
#   'table_descr': 'Dylan Marlowe, Conner Smith\'s \'Country in the Clouds\' had a release date set for April 25, 2025. With this song being around four minutes long, at 3:36, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Country in the Clouds and no other songs are present in the album, we classify this track as a single. The popularity of Country in the Clouds is currently unknown right now. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_play': '89',
#   'table_img': '',
#   'table_name': '77 - feat. Avril Lavigne',
#   'table_artist': 'Billy Idol, Avril Lavigne',
#   'table_data': '2025-04-22',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '166',
#   'table_energy': '9',
#   'table_link': '/track/6cEG5stzTtXrrCLgWKYV6j/77-feat-Avril-Lavigne-by-Billy-Idol-Avril-Lavigne',
#   'table_descr': 'Billy Idol, Avril Lavigne\'s \' "77 - feat. Avril Lavigne" was released on its scheduled release date, April 22, 2025. The duration of This song is about two minutes long, specifically at 2:53. This song does not appear to have any foul language. 77 - feat. Avril Lavigne\'s duration is considered a little bit shorter than the average duration of a typical track. There is only one song in 77 (feat. Avril Lavigne), so we believe that "77 - feat. Avril Lavigne" is a single. The popularity of 77 - feat. Avril Lavigne is currently unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_play': '90',
#   'table_img': '',
#   'table_name': 'U Need 2 Leave',
#   'table_artist': 'Belly Gang Kushington',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '135',
#   'table_energy': '5',
#   'table_link': '/track/1qIaEYGRacHs4VHBocGBx8/U-Need-2-Leave-by-Belly-Gang-Kushington',
#   'table_descr': 'Belly Gang Kushington\'s \'U Need 2 Leave\' had a release date set for April 25, 2025. For a fairly short song, this song is "U Need 2 Leave" is considered an explicit song with a duration of 1:46. There are a total of 14 in the song\'s album "THE STREETS IS YOURS". In this album, this song\'s track order is #8. Based on our statistics, U Need 2 Leave\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_play': '91',
#   'table_img': '',
#   'table_name': 'Found Love',
#   'table_artist': 'Francis Mercier, Von Boch',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '122',
#   'table_energy': '10',
#   'table_link': '/track/1mO3hOEayERMNUGIpAwImF/Found-Love-by-Francis-Mercier-Von-Boch',
#   'table_descr': '"Found Love" by Francis Mercier, Von Boch had its release date on April 25, 2025. The duration of This song is about 3 minutes long, at 3:20. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in Found Love and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, Found Love\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_play': '92',
#   'table_img': '',
#   'table_name': 'Consider Him - Live',
#   'table_artist': 'UPPERROOM, Abbie Gamboa',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '138',
#   'table_energy': '8',
#   'table_link': '/track/0yqqeDcVDTvVHi1Vp0pz2G/Consider-Him-Live-by-UPPERROOM-Abbie-Gamboa',
#   'table_descr': 'UPPERROOM, Abbie Gamboa\'s \'Consider Him - Live\' had a release date set for April 25, 2025. This song is about six minutes long, preciously at 5:32, making this song fairly long compared to other songs. There is only one song in 1350 (Live), so we believe that "Consider Him - Live" is a single. Based on our statistics, Consider Him - Live\'s popularity is unknown right now. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_play': '93',
#   'table_img': '',
#   'table_name': 'Karma',
#   'table_artist': '2BYG',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '206',
#   'table_energy': '8',
#   'table_link': '/track/7DceR0WNzszl53i1b43HPp/Karma-by-2BYG',
#   'table_descr': '2BYG\'s \' "Karma" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:40. This song does not appear to have any foul language. Karma\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in Karma and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. The popularity of Karma is currently unknown right now. The overall mood can be danceable to some, especially with it\'s high amount of postive energy. '},
#  {'table_play': '94',
#   'table_img': '',
#   'table_name': 'Questions',
#   'table_artist': 'Bells Larsen',
#   'table_data': '2025-04-22',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '119',
#   'table_energy': '0',
#   'table_link': '/track/7GHms8hXY5JGws8Fq43pEl/Questions-by-Bells-Larsen',
#   'table_descr': '"Questions" by Bells Larsen had its release date on April 22, 2025. With this song being around four minutes long, at 4:25, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. There are a total of 4 in the song\'s album "Questions". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United States. In terms of popularity, Questions is currently unknown. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_play': '95',
#   'table_img': '',
#   'table_name': 'Nina',
#   'table_artist': 'Cold Court',
#   'table_data': '2025-04-25',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '145',
#   'table_energy': '9',
#   'table_link': '/track/7b69iiHJHiZG3xebISnGlt/Nina-by-Cold-Court',
#   'table_descr': 'Cold Court\'s \' "Nina" was released on its scheduled release date, April 25, 2025. The duration of This song is about 3 minutes long, at 3:27. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in Nina and no other songs are present in the album, we classify this track as a single. Based on our statistics, Nina\'s popularity is unknown right now. The overall mood can be danceable to some, especially with it\'s high amount of postive energy. '},
#  {'table_play': '96',
#   'table_img': '',
#   'table_name': 'In This Mess',
#   'table_artist': 'Say Sue Me',
#   'table_data': '2025-04-22',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '103',
#   'table_energy': '5',
#   'table_link': '/track/5OjGj4GGm0RssCpjUQpcNA/In-This-Mess-by-Say-Sue-Me',
#   'table_descr': 'Say Sue Me\'s \'In This Mess\' had a release date set for April 22, 2025. Since This song is still less than 10 minute long, it is still considered a pretty long duration song compared to the average song length. This song does not appear to be explicit due to the lack of the "E" tag. Because this song is the only song in In This Mess and no other songs are present in the album, we classify this track as a single. On top of that, United Kingdom appears to be the country where this track was created. In terms of popularity, In This Mess is currently not that popular. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_play': '97',
#   'table_img': '',
#   'table_name': 'GPS',
#   'table_artist': 'DFZM, Jombriel, Jowell & Randy',
#   'table_data': '2025-04-24',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '119',
#   'table_energy': '5',
#   'table_link': '/track/4ayXvu5SyyKs16XyExkEjA/GPS-by-DFZM-Jombriel-Jowell-Randy',
#   'table_descr': 'On April 24, 2025, the song "GPS" was released by DFZM, Jombriel, Jowell & Randy. GPS is explicit and may not be suitable for children. With the duration being about 3:51, this song is close to the average duration of a typical track. Because this song is the only song in GPS and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. In terms of popularity, GPS is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_play': '98',
#   'table_img': '',
#   'table_name': 'I Don´t Feel',
#   'table_artist': 'Aggy Ally',
#   'table_data': '2025-04-25',
#   'table_key': 'A Minor',
#   'table_camelot': '8A',
#   'table_bpm': '86',
#   'table_energy': '4',
#   'table_link': '/track/3wqEwrMnhMUboJRVx0cknF/I-Dont-Feel-by-Aggy-Ally',
#   'table_descr': "Aggy Ally's 'I Don´t Feel' had a release date set for April 25, 2025. The duration of This song is about 3 minutes long, at 3:28. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in I Don´t Feel and no other songs are present in the album, we classify this track as a single. On top of that, Sweden appears to be the country where this track was created. I Don´t Feel is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. "},
#  {'table_play': '99',
#   'table_img': '',
#   'table_name': 'How To Get Her',
#   'table_artist': 'John Morgan',
#   'table_data': '2025-04-25',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '102',
#   'table_energy': '8',
#   'table_link': '/track/2gyS1NY8ThGPxgQE08U6ea/How-To-Get-Her-by-John-Morgan',
#   'table_descr': 'John Morgan\'s \'How To Get Her\' had a release date set for April 25, 2025. With this song being about 5 minutes long, at This song is fairly a long song compared to the average song length. This song does not have an "Explicit" tag, making it safe for all ages. The song is number 12 out of 12 in Carolina Blue by John Morgan. In terms of popularity, How To Get Her is currently unknown. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_play': '100',
#   'table_img': '',
#   'table_name': 'Speed Dating',
#   'table_artist': 'DJ Sugarush, Jai Piccone, Hotel Rubio',
#   'table_data': '2025-04-25',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '145',
#   'table_energy': '9',
#   'table_link': '/track/5j2sGJpwHBdSOiTBFG9cX0/Speed-Dating-by-DJ-Sugarush-Jai-Piccone-Hotel-Rubio',
#   'table_descr': "DJ Sugarush, Jai Piccone, Hotel Rubio's 'Speed Dating' had a release date set for April 25, 2025. The duration of This song is about two minutes long, specifically at 2:47. This song does not appear to have any foul language. Speed Dating's duration is considered a little bit shorter than the average duration of a typical track. Since Speed Dating only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from France. Based on our statistics, Speed Dating's popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "}]

# %%
#if we only want the collection of names and links and descriptions:
top_100 = scrape_links('https://songdata.io/charts/top-100')
print(top_100)
# Out:
# [{'table_play': '1', 'table_img': '', 'table_name': 'luther (with sza)', 'table_artist': 'Kendrick Lamar, SZA', 'table_key': 'D Major', 'table_camelot': '10B', 'table_bpm': '138', 'table_link': '/track/45J4avUb9Ni0bnETYaYFVJ/luther-with-sza-by-Kendrick-Lamar-SZA'}, {'table_play': '2', 'table_img': '', 'table_name': 'NOKIA', 'table_artist': 'Drake', 'table_key': 'F Major', 'table_camelot': '7B', 'table_bpm': '106', 'table_link': '/track/2u9S9JJ6hTZS3Vf22HOZKg/NOKIA-by-Drake'}, {'table_play': '3', 'table_img': '', 'table_name': 'Die With A Smile', 'table_artist': 'Lady Gaga, Bruno Mars', 'table_key': 'F♯ Minor', 'table_camelot': '11A', 'table_bpm': '158', 'table_link': '/track/2plbrEY59IikOBgBGLjaoe/Die-With-A-Smile-by-Lady-Gaga-Bruno-Mars'}, {'table_play': '4', 'table_img': '', 'table_name': 'All The Way (feat. Bailey Zimmerman)', 'table_artist': 'BigXthaPlug, Bailey Zimmerman', 'table_key': 'D♭ Minor', 'table_camelot': '12A', 'table_bpm': '135', 'table_link': '/track/73kIKvg65QWieOKXIwyLJP/All-The-Way-feat-Bailey-Zimmerman-by-BigXthaPlug-Bailey-Zimmerman'}, {'table_play': '5', 'table_img': '', 'table_name': 'Pink Pony Club', 'table_artist': 'Chappell Roan', 'table_key': 'D Major', 'table_camelot': '10B', 'table_bpm': '124', 'table_link': '/track/1k2pQc5i348DCHwbn5KTdc/Pink-Pony-Club-by-Chappell-Roan'}, {'table_play': '6', 'table_img': '', 'table_name': 'A Bar Song (Tipsy)', 'table_artist': 'Shaboozey', 'table_key': 'A Major', 'table_camelot': '11B', 'table_bpm': '81', 'table_link': '/track/2FQrifJ1N335Ljm3TjTVVf/A-Bar-Song-Tipsy-by-Shaboozey'}, {'table_play': '7', 'table_img': '', 'table_name': 'Ordinary', 'table_artist': 'Alex Warren', 'table_key': 'D Major', 'table_camelot': '10B', 'table_bpm': '112', 'table_link': '/track/6qqrTXSdwiJaq8SO0X2lSe/Ordinary-by-Alex-Warren'}, {'table_play': '8', 'table_img': '', 'table_name': 'Lose Control', 'table_artist': 'Teddy Swims', 'table_key': 'A Major', 'table_camelot': '11B', 'table_bpm': '160', 'table_link': '/track/6usohdchdzW9oML7VC4Uhk/Lose-Control-by-Teddy-Swims'}, {'table_play': '9', 'table_img': '', 'table_name': "I'm The Problem", 'table_artist': 'Morgan Wallen', 'table_key': 'D♭ Major', 'table_camelot': '3B', 'table_bpm': '117', 'table_link': '/track/3HlWVKwU0JqJXqJK9DWHnZ/Im-The-Problem-by-Morgan-Wallen'}, {'table_play': '10', 'table_img': '', 'table_name': 'Beautiful Things', 'table_artist': 'Benson Boone', 'table_key': 'E Major', 'table_camelot': '12B', 'table_bpm': '82', 'table_link': '/track/6tNQ70jh4OwmPGpYy6R2o9/Beautiful-Things-by-Benson-Boone'}, {'table_play': '11', 'table_img': '', 'table_name': 'BIRDS OF A FEATHER', 'table_artist': 'Billie Eilish', 'table_key': 'G Major', 'table_camelot': '9B', 'table_bpm': '110', 'table_link': '/track/6dOtVTDdiauQNBQEDOtlAB/BIRDS-OF-A-FEATHER-by-Billie-Eilish'}, {'table_play': '12', 'table_img': '', 'table_name': 'Just In Case', 'table_artist': 'Morgan Wallen', 'table_key': 'B♭ Major', 'table_camelot': '6B', 'table_bpm': '146', 'table_link': '/track/02Ya2Q08bBKFqUJvjmyRXK/Just-In-Case-by-Morgan-Wallen'}, {'table_play': '13', 'table_img': '', 'table_name': 'APT.', 'table_artist': 'ROSÉ, Bruno Mars', 'table_key': 'C Minor', 'table_camelot': '5A', 'table_bpm': '149', 'table_link': '/track/5vNRhkKd0yEAg8suGBpjeY/APT-by-ROS-Bruno-Mars'}, {'table_play': '14', 'table_img': '', 'table_name': 'Anxiety', 'table_artist': 'Doechii', 'table_key': 'C Major', 'table_camelot': '8B', 'table_bpm': '129', 'table_link': '/track/1musbempyJAw5gfSKZHXP9/Anxiety-by-Doechii'}, {'table_play': '15', 'table_img': '', 'table_name': 'That’s So True', 'table_artist': 'Gracie Abrams', 'table_key': 'C Major', 'table_camelot': '8B', 'table_bpm': '150', 'table_link': '/track/7ne4VBA60CxGM75vw0EYad/Thats-So-True-by-Gracie-Abrams'}, {'table_play': '16', 'table_img': '', 'table_name': 'Not Like Us', 'table_artist': 'Kendrick Lamar', 'table_key': 'D♭ Major', 'table_camelot': '3B', 'table_bpm': '101', 'table_link': '/track/6AI3ezQ4o3HUoP6Dhudph3/Not-Like-Us-by-Kendrick-L ...

# %%
for song in top_100:
    td.append(scrape_descriptions(song)) #do this for all songs and add it to the td list.

# %%
len(td)
# Out:
# 200

# %%
for row in td:
    row.pop('table_img',None)
    row.pop('table_play')
td
# Out:
# [{'table_name': 'What Was That',
#   'table_artist': 'Lorde',
#   'table_data': '2025-04-24',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '168',
#   'table_energy': '6',
#   'table_link': '/track/2jNyiavSywmA472t2m6ZBz/What-Was-That-by-Lorde',
#   'table_descr': '"What Was That" by Lorde had its release date on April 24, 2025. The duration of This song is about 3 minutes long, at 3:29. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Since What Was That only contains only one song in the album, we like to consider this song as a single. Based on our data, New Zealand was the country where this track was produced or recorded. The popularity of What Was That is currently pretty popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_name': 'Mystical Magical',
#   'table_artist': 'Benson Boone',
#   'table_data': '2025-04-24',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '120',
#   'table_energy': '7',
#   'table_link': '/track/221eHga9f9Ne4f8D7WVgPT/Mystical-Magical-by-Benson-Boone',
#   'table_descr': 'On April 24, 2025, the song "Mystical Magical" was released by Benson Boone. The duration of This song is about two minutes long, specifically at 2:45. This song does not appear to have any foul language. Mystical Magical\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in Mystical Magical and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. Based on our statistics, Mystical Magical\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Is This Really Love?',
#   'table_artist': 'd4vd',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '160',
#   'table_energy': '7',
#   'table_link': '/track/0h2vooD5PFOykbPon6ShIZ/Is-This-Really-Love-by-d4vd',
#   'table_descr': 'd4vd\'s \' "Is This Really Love?" was released on its scheduled release date, April 25, 2025. The duration of This song is about 3 minutes long, at 3:15. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. This song is part of WITHERED by d4vd. The song\'s track number on the album is #9 out of 15 tracks. Based on our data, United States was the country where this track was produced or recorded. The popularity of Is This Really Love? is currently unknown right now. Based on the vibe, this track doesn\'t seem to be that danceable, however its valence properties can make this some somewhat danceable. '},
#  {'table_name': 'Money On Money (feat. Future)',
#   'table_artist': 'Young Thug, Future',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '120',
#   'table_energy': '7',
#   'table_link': '/track/5eW508Gq23QlXHowyzW39m/Money-On-Money-feat-Future-by-Young-Thug-Future',
#   'table_descr': '"Money On Money (feat. Future)" by Young Thug, Future had its release date on April 25, 2025. Money On Money (feat. Future) is explicit and may not be suitable for children. With the duration being about 3:56, this song is close to the average duration of a typical track. Because this song is the only song in Money On Money (feat. Future) and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. Based on our statistics, Money On Money (feat. Future)\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'ILYSMIH',
#   'table_artist': 'Kali Uchis',
#   'table_data': '2025-04-25',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '126',
#   'table_energy': '7',
#   'table_link': '/track/3WvPycGo4WJEEGYP429aap/ILYSMIH-by-Kali-Uchis',
#   'table_descr': 'Kali Uchis\'s \' "ILYSMIH" was released on its scheduled release date, April 25, 2025. With this song being around four minutes long, at 3:33, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The track order of this song in Kali Uchis\'s "ILYSMIH" album is number 1 out of 2. On top of that, United States appears to be the country where this track was created. Based on our statistics, ILYSMIH\'s popularity is unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'Amen',
#   'table_artist': 'Shaboozey, Jelly Roll',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '81',
#   'table_energy': '5',
#   'table_link': '/track/2iSfSJrho5XkU2NmAnZ9ZV/Amen-by-Shaboozey-Jelly-Roll',
#   'table_descr': "Shaboozey, Jelly Roll's 'Amen' had a release date set for April 25, 2025. The duration of This song is about 3 minutes long, at 3:17. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. This song is part of Where I've Been, Isn't Where I'm Going: The Complete Edition by Shaboozey. The song's track number on the album is #13 out of 18 tracks. Based on our data, United States was the country where this track was produced or recorded. Amen is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_name': 'At The Beach, In Every Life',
#   'table_artist': 'Gigi Perez',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '84',
#   'table_energy': '4',
#   'table_link': '/track/5LfgzPHvka22FdRAxOme6m/At-The-Beach-In-Every-Life-by-Gigi-Perez',
#   'table_descr': 'Gigi Perez\'s \'At The Beach, In Every Life\' had a release date set for April 25, 2025. With this song being around four minutes long, at 3:57, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The song is number 12 out of 12 in At The Beach, In Every Life by Gigi Perez. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. At The Beach, In Every Life is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_name': 'Whenever',
#   'table_artist': 'Megan Thee Stallion',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '120',
#   'table_energy': '7',
#   'table_link': '/track/4oVUfLx1BVgXbPXc0MlPkr/Whenever-by-Megan-Thee-Stallion',
#   'table_descr': '"Whenever" by Megan Thee Stallion had its release date on April 25, 2025. Whenever is 2 minutes and 45 seconds long and may contain bad words that may be unsuitable for children. Since Whenever only contains only one song in the album, we like to consider this song as a single. Based on our data, United States was the country where this track was produced or recorded. Based on our statistics, Whenever\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'Down to be wrong',
#   'table_artist': 'HAIM',
#   'table_data': '2025-04-24',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '165',
#   'table_energy': '7',
#   'table_link': '/track/2d18juMmmN1KwjFtfEj0FP/Down-to-be-wrong-by-HAIM',
#   'table_descr': 'HAIM\'s \' "Down to be wrong" was released on its scheduled release date, April 24, 2025. With this song being around four minutes long, at 4:09, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The song is number 1 out of 3 in Down to be wrong by HAIM. Going off of the ISRC code of this track, we detected that the origin of this track is from United Kingdom. The popularity of Down to be wrong is currently unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'Brunette',
#   'table_artist': 'Tucker Wetmore',
#   'table_data': '2025-04-25',
#   'table_key': 'F♯ Major',
#   'table_camelot': '2B',
#   'table_bpm': '115',
#   'table_energy': '7',
#   'table_link': '/track/21T9HvQ0KUWFDum6P1Qc7i/Brunette-by-Tucker-Wetmore',
#   'table_descr': 'Tucker Wetmore\'s \' "Brunette" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:19. This song does not appear to have any foul language. Brunette\'s duration is considered a little bit shorter than the average duration of a typical track. This song is part of What Not To by Tucker Wetmore. The song\'s track number on the album is #6 out of 19 tracks. Based on our data, United States was the country where this track was produced or recorded. In terms of popularity, Brunette is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'PIDA LO QUE QUIERA MAMI - A COLORS SHOW',
#   'table_artist': 'Feid, COLORS',
#   'table_data': '2025-04-21',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '110',
#   'table_energy': '4',
#   'table_link': '/track/0PAqSz4d5lJfAscDDmIxzX/PIDA-LO-QUE-QUIERA-MAMI-A-COLORS-SHOW-by-Feid-COLORS',
#   'table_descr': 'Feid, COLORS\'s \' "PIDA LO QUE QUIERA MAMI - A COLORS SHOW" was released on its scheduled release date, April 21, 2025. The duration of This song is about 3 minutes long, at 3:27. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Since PIDA LO QUE QUIERA MAMI - A COLORS SHOW only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. In terms of popularity, PIDA LO QUE QUIERA MAMI - A COLORS SHOW is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'On Sight',
#   'table_artist': 'Coco Jones',
#   'table_data': '2025-04-25',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '90',
#   'table_energy': '5',
#   'table_link': '/track/0Tdpdo2ZD1CefcFTTbm0xx/On-Sight-by-Coco-Jones',
#   'table_descr': "Coco Jones's 'On Sight' had a release date set for April 25, 2025. On Sight is explicit and may not be suitable for children. With the duration being about 4:27, this song is close to the average duration of a typical track. This song is part of Why Not More? by Coco Jones. The song's track number on the album is #3 out of 14 tracks. Based on our data, United States was the country where this track was produced or recorded. In terms of popularity, On Sight is currently unknown. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. "},
#  {'table_name': 'Carousel',
#   'table_artist': 'Samia',
#   'table_data': '2025-04-22',
#   'table_key': 'F♯ Major',
#   'table_camelot': '2B',
#   'table_bpm': '80',
#   'table_energy': '4',
#   'table_link': '/track/6xErF43Ru9Y0r21iHWaj0J/Carousel-by-Samia',
#   'table_descr': '"Carousel" by Samia had its release date on April 22, 2025. The duration of This song is about 3 minutes long, at 3:27. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. The song is number 1 out of 5 in Carousel by Samia. Carousel is unknown right now. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_name': 'Stateside',
#   'table_artist': 'PinkPantheress',
#   'table_data': '2025-04-25',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '123',
#   'table_energy': '9',
#   'table_link': '/track/7Fr2Q6q3rAxFUcMkuvVrXO/Stateside-by-PinkPantheress',
#   'table_descr': 'PinkPantheress\'s \' "Stateside" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:48. This song does not appear to have any foul language. Stateside\'s duration is considered a little bit shorter than the average duration of a typical track. There are a total of 2 in the song\'s album "Stateside". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United Kingdom. Based on our statistics, Stateside\'s popularity is unknown right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Nostalgia',
#   'table_artist': 'Sammy Virji, Issey Cross',
#   'table_data': '2025-04-25',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '132',
#   'table_energy': '6',
#   'table_link': '/track/5D5uC8J6xBkGN66eLnqdvG/Nostalgia-by-Sammy-Virji-Issey-Cross',
#   'table_descr': '"Nostalgia" by Sammy Virji, Issey Cross had its release date on April 25, 2025. With this song being around four minutes long, at 3:30, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Nostalgia and no other songs are present in the album, we classify this track as a single. Furthermore, we believe that the track originated from United Kingdom. Based on our statistics, Nostalgia\'s popularity is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_name': 'Peacefield - Single Version',
#   'table_artist': 'Ghost',
#   'table_data': '2025-04-22',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '103',
#   'table_energy': '9',
#   'table_link': '/track/6j9GJGI7sogofbagE6za5E/Peacefield-Single-Version-by-Ghost',
#   'table_descr': 'Ghost\'s \' "Peacefield - Single Version" was released on its scheduled release date, April 22, 2025. With this song being about 5 minutes long, at This song is fairly a long song compared to the average song length. This song does not have an "Explicit" tag, making it safe for all ages. There are a total of 2 in the song\'s album "Peacefield". In this album, this song\'s track order is #2. Furthermore, we believe that the track originated from United States. In terms of popularity, Peacefield - Single Version is currently unknown. The overall mood can be danceable to some, especially with it\'s high amount of postive energy. '},
#  {'table_name': 'BAD BITCHES!',
#   'table_artist': 'DESTIN CONRAD, Kehlani',
#   'table_data': '2025-04-25',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '87',
#   'table_energy': '4',
#   'table_link': '/track/5ld2rB0d5nG8RTQRRmkxNa/BAD-BITCHES-by-DESTIN-CONRAD-Kehlani',
#   'table_descr': 'DESTIN CONRAD, Kehlani\'s \' "BAD BITCHES!" was released on its scheduled release date, April 25, 2025. BAD BITCHES! is explicit and may not be suitable for children. With the duration being about 3:45, this song is close to the average duration of a typical track. The track order of this song in DESTIN CONRAD\'s "LOVE ON DIGITAL" album is number 4 out of 15. On top of that, United States appears to be the country where this track was created. BAD BITCHES! is unknown right now. Based on the vibe, this track doesn\'t seem to be that danceable, however its valence properties can make this some somewhat danceable. '},
#  {'table_name': 'Gripper (feat. T-Pain)',
#   'table_artist': 'Flo Milli, T-Pain',
#   'table_data': '2025-04-25',
#   'table_key': 'C Minor',
#   'table_camelot': '5A',
#   'table_bpm': '133',
#   'table_energy': '6',
#   'table_link': '/track/0OBXjsLYqftAOhCMEcAeAs/Gripper-feat-T-Pain-by-Flo-Milli-T-Pain',
#   'table_descr': 'Flo Milli, T-Pain\'s \' "Gripper (feat. T-Pain)" was released on its scheduled release date, April 25, 2025. Gripper (feat. T-Pain) is 2 minutes and 52 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in Gripper (feat. T-Pain) and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. Based on our statistics, Gripper (feat. T-Pain)\'s popularity is unknown right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Pack It Up',
#   'table_artist': 'ian',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '134',
#   'table_energy': '5',
#   'table_link': '/track/0ZvlEr2LkJUO6eYMVi74Io/Pack-It-Up-by-ian',
#   'table_descr': 'ian\'s \' "Pack It Up" was released on its scheduled release date, April 25, 2025. For a fairly short song, this song is "Pack It Up" is considered an explicit song with a duration of 1:54. Since Pack It Up only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. Based on our statistics, Pack It Up\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Damocles',
#   'table_artist': 'Sleep Token',
#   'table_data': '2025-04-25',
#   'table_key': 'F♯ Major',
#   'table_camelot': '2B',
#   'table_bpm': '156',
#   'table_energy': '6',
#   'table_link': '/track/1ulH5PIntNj0ro2K69W4Fx/Damocles-by-Sleep-Token',
#   'table_descr': 'Sleep Token\'s \'Damocles\' had a release date set for April 25, 2025. With this song being around four minutes long, at 4:24, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Damocles and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, Damocles\'s popularity is fairly popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_name': 'My First Heartbreak',
#   'table_artist': 'Myles Smith',
#   'table_data': '2025-04-25',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '82',
#   'table_energy': '5',
#   'table_link': '/track/5gbUP33wFJPawjY5DxR3OA/My-First-Heartbreak-by-Myles-Smith',
#   'table_descr': "Myles Smith's 'My First Heartbreak' had a release date set for April 25, 2025. The duration of This song is about 3 minutes long, at 3:26. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in My First Heartbreak and no other songs are present in the album, we classify this track as a single. On top of that, United Kingdom appears to be the country where this track was created. My First Heartbreak is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. "},
#  {'table_name': 'Learn The Hard Way',
#   'table_artist': 'Jordan Davis',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '77',
#   'table_energy': '9',
#   'table_link': '/track/3xB2R2tf0T2TXaB4AWoPjT/Learn-The-Hard-Way-by-Jordan-Davis',
#   'table_descr': 'On April 25, 2025, the song "Learn The Hard Way" was released by Jordan Davis. The duration of This song is about two minutes long, specifically at 2:48. This song does not appear to have any foul language. Learn The Hard Way\'s duration is considered a little bit shorter than the average duration of a typical track. The track order of this song in Jordan Davis\'s "Learn The Hard Way" album is number 1 out of 3. On top of that, United States appears to be the country where this track was created. Learn The Hard Way is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Unshatter',
#   'table_artist': 'Linkin Park',
#   'table_data': '2025-04-25',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '107',
#   'table_energy': '9',
#   'table_link': '/track/0D7RVmTlKkmRchqKA4zJht/Unshatter-by-Linkin-Park',
#   'table_descr': 'Linkin Park\'s \' "Unshatter" was released on its scheduled release date, April 25, 2025. The duration of This song is about 3 minutes long, at 3:16. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. There are a total of 2 in the song\'s album "Unshatter". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United States. In terms of popularity, Unshatter is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'T.H.',
#   'table_artist': 'SAULT',
#   'table_data': '2025-04-18',
#   'table_key': 'E♭ Minor',
#   'table_camelot': '2A',
#   'table_bpm': '134',
#   'table_energy': '6',
#   'table_link': '/track/7Cj2Buxud8yjgRCdRW6VUs/TH-by-SAULT',
#   'table_descr': 'SAULT\'s \' "T.H." was released on its scheduled release date, April 18, 2025. With this song being about 5 minutes long, at This song is fairly a long song compared to the average song length. This song does not have an "Explicit" tag, making it safe for all ages. There is only one song in 10, so we believe that "T.H." is a single. Based on our statistics, T.H.\'s popularity is below average in popularity right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Poplife',
#   'table_artist': 'umru, underscores',
#   'table_data': '2025-04-24',
#   'table_key': 'A Minor',
#   'table_camelot': '8A',
#   'table_bpm': '142',
#   'table_energy': '8',
#   'table_link': '/track/2cClnOEBnNJWxbLuTFVIgK/Poplife-by-umru-underscores',
#   'table_descr': 'umru, underscores\'s \' "Poplife" was released on its scheduled release date, April 24, 2025. The duration of This song is about two minutes long, specifically at 2:43. This song does not appear to have any foul language. Poplife\'s duration is considered a little bit shorter than the average duration of a typical track. Since Poplife only contains only one song in the album, we like to consider this song as a single. Based on our statistics, Poplife\'s popularity is average in popularity right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Tell Me Where U Go',
#   'table_artist': 'Clean Bandit, Tiësto, Leony',
#   'table_data': '2025-04-25',
#   'table_key': 'G Minor',
#   'table_camelot': '6A',
#   'table_bpm': '142',
#   'table_energy': '8',
#   'table_link': '/track/4NuksWELZ9lBY9aazhZG16/Tell-Me-Where-U-Go-by-Clean-Bandit-Tisto-Leony',
#   'table_descr': "Clean Bandit, Tiësto, Leony's 'Tell Me Where U Go' had a release date set for April 25, 2025. Tell Me Where U Go is considered explicit and may contain foul language. This song is about 3 minutes and 2 seconds, which is about the average length of a typical song. Since Tell Me Where U Go only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United Kingdom. Based on our statistics, Tell Me Where U Go's popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_name': 'AMISTAD',
#   'table_artist': 'Blessd, Ovy On The Drums',
#   'table_data': '2025-04-24',
#   'table_key': 'F Major',
#   'table_camelot': '7B',
#   'table_bpm': '170',
#   'table_energy': '6',
#   'table_link': '/track/1TzQqJ4hme55ZKnM86Xyw0/AMISTAD-by-Blessd-Ovy-On-The-Drums',
#   'table_descr': 'Blessd, Ovy On The Drums\'s \' "AMISTAD" was released on its scheduled release date, April 24, 2025. AMISTAD is 2 minutes and 57 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in AMISTAD and no other songs are present in the album, we classify this track as a single. The popularity of AMISTAD is currently unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Gimme Dat (feat. Wizkid)',
#   'table_artist': 'Ayra Starr, Wizkid',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Major',
#   'table_camelot': '6B',
#   'table_bpm': '95',
#   'table_energy': '8',
#   'table_link': '/track/1k51Q6GFWBbsaWlBB2gnzo/Gimme-Dat-feat-Wizkid-by-Ayra-Starr-Wizkid',
#   'table_descr': 'Ayra Starr, Wizkid\'s \' "Gimme Dat (feat. Wizkid)" was released on its scheduled release date, April 25, 2025. With this song being around four minutes long, at 3:45, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Gimme Dat and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. In terms of popularity, Gimme Dat (feat. Wizkid) is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Rich Guys (Feat. Babyfxce E)',
#   'table_artist': 'BabyChiefDoit, Babyfxce E',
#   'table_data': '2025-04-23',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '157',
#   'table_energy': '5',
#   'table_link': '/track/7a1Iw4S1eNozL4C4gv5xSg/Rich-Guys-Feat-Babyfxce-E-by-BabyChiefDoit-Babyfxce-E',
#   'table_descr': '"Rich Guys (Feat. Babyfxce E)" by BabyChiefDoit, Babyfxce E had its release date on April 23, 2025. Rich Guys (Feat. Babyfxce E) is 2 minutes and 58 seconds long and may contain bad words that may be unsuitable for children. This song is part of ZOO LIFE by BabyChiefDoit. The song\'s track number on the album is #2 out of 13 tracks. Based on our statistics, Rich Guys (Feat. Babyfxce E)\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'What Da Fuk',
#   'table_artist': 'PLUTO',
#   'table_data': '2025-04-24',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '156',
#   'table_energy': '8',
#   'table_link': '/track/46e5RkqWEBRLebmdCK9t7o/What-Da-Fuk-by-PLUTO',
#   'table_descr': "PLUTO's 'What Da Fuk' had a release date set for April 24, 2025. What Da Fuk is 2 minutes and 36 seconds long and may contain bad words that may be unsuitable for children. This song is part of What Da Fuk by PLUTO. The song's track number on the album is #1 out of 2 tracks. Based on our data, United States was the country where this track was produced or recorded. Based on our statistics, What Da Fuk's popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_name': 'Pretty Ugly',
#   'table_artist': 'Zara Larsson',
#   'table_data': '2025-04-25',
#   'table_key': 'C Minor',
#   'table_camelot': '5A',
#   'table_bpm': '111',
#   'table_energy': '7',
#   'table_link': '/track/0lWcOHxfnxj1GlVr4zpnyD/Pretty-Ugly-by-Zara-Larsson',
#   'table_descr': 'Zara Larsson\'s \' "Pretty Ugly" was released on its scheduled release date, April 25, 2025. Pretty Ugly is 2 minutes and 38 seconds long and may contain bad words that may be unsuitable for children. Since Pretty Ugly only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. In terms of popularity, Pretty Ugly is currently unknown. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'I could',
#   'table_artist': 'Fine',
#   'table_data': '2025-04-23',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '147',
#   'table_energy': '6',
#   'table_link': '/track/5EmtveGyjsE023P8atahBQ/I-could-by-Fine',
#   'table_descr': 'Fine\'s \' "I could" was released on its scheduled release date, April 23, 2025. The duration of This song is about two minutes long, specifically at 2:36. This song does not appear to have any foul language. I could\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in I could and no other songs are present in the album, we classify this track as a single. On top of that, France appears to be the country where this track was created. Based on our statistics, I could\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'buzzkill',
#   'table_artist': 'Lyn Lapid',
#   'table_data': '2025-04-25',
#   'table_key': 'D Major',
#   'table_camelot': '10B',
#   'table_bpm': '144',
#   'table_energy': '7',
#   'table_link': '/track/1xo0olV5DcTUQX9cpoUv5m/buzzkill-by-Lyn-Lapid',
#   'table_descr': 'Lyn Lapid\'s \' "buzzkill" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:35. This song does not appear to have any foul language. buzzkill\'s duration is considered a little bit shorter than the average duration of a typical track. The song is number 1 out of 12 in BUZZKILL by Lyn Lapid. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, buzzkill\'s popularity is unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'Alē',
#   'table_artist': 'Chezile',
#   'table_data': '2025-04-25',
#   'table_key': 'G Minor',
#   'table_camelot': '6A',
#   'table_bpm': '89',
#   'table_energy': '6',
#   'table_link': '/track/5xkWnuF0eA5ODVKiTJaQXZ/Al-by-Chezile',
#   'table_descr': "Chezile's 'Alē' had a release date set for April 25, 2025. The duration of This song is about two minutes long, specifically at 2:51. This song does not appear to have any foul language. Alē's duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in Alē and no other songs are present in the album, we classify this track as a single. Alē is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_name': 'Let Me Be Wrong',
#   'table_artist': 'Jensen McRae',
#   'table_data': '2025-04-25',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '203',
#   'table_energy': '5',
#   'table_link': '/track/7iueQDyeYZRXZc4DYYAwDw/Let-Me-Be-Wrong-by-Jensen-McRae',
#   'table_descr': 'Jensen McRae\'s \' "Let Me Be Wrong" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:36. This song does not appear to have any foul language. Let Me Be Wrong\'s duration is considered a little bit shorter than the average duration of a typical track. The track order of this song in Jensen McRae\'s "I Don\'t Know How But They Found Me!" album is number 5 out of 11. On top of that, United States appears to be the country where this track was created. The popularity of Let Me Be Wrong is currently unknown right now. Based on the vibe, this track doesn\'t seem to be that danceable, however its valence properties can make this some somewhat danceable. '},
#  {'table_name': 'Sungazing - Electronic Mix',
#   'table_artist': 'Michael Bibi, Alexa Sunshine Rose',
#   'table_data': '2025-04-25',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '130',
#   'table_energy': '8',
#   'table_link': '/track/0H72o8QdyYc57jNkvYwfAX/Sungazing-Electronic-Mix-by-Michael-Bibi-Alexa-Sunshine-Rose',
#   'table_descr': 'Michael Bibi, Alexa Sunshine Rose\'s \' "Sungazing - Electronic Mix" was released on its scheduled release date, April 25, 2025. With this song being around four minutes long, at 4:07, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Since Sungazing (Electronic Mix) only contains only one song in the album, we like to consider this song as a single. Based on our statistics, Sungazing - Electronic Mix\'s popularity is unknown right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'WASSUP',
#   'table_artist': 'Young Miko',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '145',
#   'table_energy': '7',
#   'table_link': '/track/32SJM4tQyJHsB8rgVtZURn/WASSUP-by-Young-Miko',
#   'table_descr': 'Young Miko\'s \' "WASSUP" was released on its scheduled release date, April 25, 2025. WASSUP is 2 minutes and 42 seconds long and may contain bad words that may be unsuitable for children. Since WASSUP only contains only one song in the album, we like to consider this song as a single. Based on our statistics, WASSUP\'s popularity is unknown right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'IMMA RIDE 4 YOU',
#   'table_artist': '$NOT',
#   'table_data': '2025-04-20',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '139',
#   'table_energy': '5',
#   'table_link': '/track/1JPKeahg89aOPJYGa0JDFC/IMMA-RIDE-4-YOU-by-NOT',
#   'table_descr': '$NOT\'s \' "IMMA RIDE 4 YOU" was released on its scheduled release date, April 20, 2025. IMMA RIDE 4 YOU is 2 minutes and 26 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in IMMA RIDE 4 YOU and no other songs are present in the album, we classify this track as a single. Based on our statistics, IMMA RIDE 4 YOU\'s popularity is average in popularity right now. The overall mood can be danceable to some, especially with it\'s high amount of postive energy. '},
#  {'table_name': 'Dead Body',
#   'table_artist': 'MAF Teeski, Skrilla',
#   'table_data': '2025-04-23',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '88',
#   'table_energy': '5',
#   'table_link': '/track/7yT8OCnOJ9oFajVE6RVPm4/Dead-Body-by-MAF-Teeski-Skrilla',
#   'table_descr': "MAF Teeski, Skrilla's 'Dead Body' had a release date set for April 23, 2025. Dead Body is 2 minutes and 42 seconds long and may contain bad words that may be unsuitable for children. Because this song is the only song in Dead Body and no other songs are present in the album, we classify this track as a single. Dead Body is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. "},
#  {'table_name': 'What I Used To Get Into',
#   'table_artist': 'Roy Woods',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '84',
#   'table_energy': '6',
#   'table_link': '/track/4GEAQAtCQ50j0lZP9k4SMT/What-I-Used-To-Get-Into-by-Roy-Woods',
#   'table_descr': 'Roy Woods\'s \' "What I Used To Get Into" was released on its scheduled release date, April 25, 2025. What I Used To Get Into is considered explicit and may contain foul language. This song is about 3 minutes and 12 seconds, which is about the average length of a typical song. The song is number 5 out of 9 in Dark Nights by Roy Woods. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. What I Used To Get Into is unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'Darkness Always Wins',
#   'table_artist': 'Halestorm',
#   'table_data': '2025-04-22',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '170',
#   'table_energy': '6',
#   'table_link': '/track/7wBKXbleeJQuQDnfKlOOGe/Darkness-Always-Wins-by-Halestorm',
#   'table_descr': '"Darkness Always Wins" by Halestorm had its release date on April 22, 2025. With this song being about 5 minutes long, at This song is fairly a long song compared to the average song length. This song does not have an "Explicit" tag, making it safe for all ages. Because this song is the only song in Darkness Always Wins and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. The popularity of Darkness Always Wins is currently unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_name': "I Don't Know Why (I Just Do)",
#   'table_artist': 'Jeff Goldblum & The Mildred Snitzer Orchestra, Ariana Grande',
#   'table_data': '2025-04-25',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '95',
#   'table_energy': '4',
#   'table_link': '/track/0WiIGxBzkA2SvE8clbz3X0/I-Dont-Know-Why-I-Just-Do-by-Jeff-Goldblum-The-Mildred-Snitzer-Orchest',
#   'table_descr': '"I Don\'t Know Why (I Just Do)" by Jeff Goldblum & The Mildred Snitzer Orchestra, Ariana Grande had its release date on April 25, 2025. With this song being around four minutes long, at 3:44, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. There are a total of 9 in the song\'s album "Still Blooming". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United Kingdom. In terms of popularity, I Don\'t Know Why (I Just Do) is currently unknown. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_name': 'Hitch Hiking',
#   'table_artist': 'Jenna Raine',
#   'table_data': '2025-04-25',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '170',
#   'table_energy': '6',
#   'table_link': '/track/5nkg0pxD5dN91JBzlvI90W/Hitch-Hiking-by-Jenna-Raine',
#   'table_descr': 'Jenna Raine\'s \' "Hitch Hiking" was released on its scheduled release date, April 25, 2025. The duration of This song is about two minutes long, specifically at 2:50. This song does not appear to have any foul language. Hitch Hiking\'s duration is considered a little bit shorter than the average duration of a typical track. There are a total of 6 in the song\'s album "Only Started Growing". In this album, this song\'s track order is #3. Furthermore, we believe that the track originated from United States. The popularity of Hitch Hiking is currently unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'Dreamin',
#   'table_artist': 'BRONCHO',
#   'table_data': '2025-04-25',
#   'table_key': 'F Major',
#   'table_camelot': '7B',
#   'table_bpm': '110',
#   'table_energy': '3',
#   'table_link': '/track/4cYvM8q9V6HTEayIBHuP1W/Dreamin-by-BRONCHO',
#   'table_descr': 'BRONCHO\'s \' "Dreamin" was released on its scheduled release date, April 25, 2025. The duration of This song is about 3 minutes long, at 3:26. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. There are a total of 12 in the song\'s album "Natural Pleasure". In this album, this song\'s track order is #12. Furthermore, we believe that the track originated from Turks and Caicos Islands. In terms of popularity, Dreamin is currently unknown. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'No Enemies (feat. Namasenda)',
#   'table_artist': 'Sebastian Ingrosso, Steve Angello, Namasenda',
#   'table_data': '2025-04-24',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '134',
#   'table_energy': '6',
#   'table_link': '/track/55gp7v87CYS1lxWQ5ho5nK/No-Enemies-feat-Namasenda-by-Sebastian-Ingrosso-Steve-Angello-Namasend',
#   'table_descr': "Sebastian Ingrosso, Steve Angello, Namasenda's 'No Enemies (feat. Namasenda)' had a release date set for April 24, 2025. The duration of This song is about two minutes long, specifically at 2:40. This song does not appear to have any foul language. No Enemies (feat. Namasenda)'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in No Enemies (feat. Namasenda) and no other songs are present in the album, we classify this track as a single. Furthermore, we believe that the track originated from United States. Based on our statistics, No Enemies (feat. Namasenda)'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_name': "Roar of the Lion (The Lion's Pit)",
#   'table_artist': 'Wu-Tang Clan, U-God, Kool G Rap, RZA',
#   'table_data': '2025-04-25',
#   'table_key': 'B Minor',
#   'table_camelot': '10A',
#   'table_bpm': '90',
#   'table_energy': '4',
#   'table_link': '/track/6xX6NoYPtEgDWA95cIqUK8/Roar-of-the-Lion-The-Lions-Pit-by-Wu-Tang-Clan-U-God-Kool-G-Rap-RZA',
#   'table_descr': "Wu-Tang Clan, U-God, Kool G Rap, RZA's 'Roar of the Lion (The Lion's Pit)' had a release date set for April 25, 2025. Roar of the Lion (The Lion's Pit) is explicit and may not be suitable for children. With the duration being about 4:09, this song is close to the average duration of a typical track. The song is number 3 out of 12 in Black Samson, the Bastard Swordsman by Wu-Tang Clan, Mathematics. Going off of the ISRC code of this track, we detected that the origin of this track is from Switzerland. In terms of popularity, Roar of the Lion (The Lion's Pit) is currently unknown. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_name': 'Phone Ring (with Benny The Butcher and Maxo Kream)',
#   'table_artist': 'Anwar Carrots, Benny The Butcher, Maxo Kream',
#   'table_data': '2025-04-22',
#   'table_key': 'E Minor',
#   'table_camelot': '9A',
#   'table_bpm': '180',
#   'table_energy': '8',
#   'table_link': '/track/0ypqbEoW7tEKMCwZnSq079/Phone-Ring-with-Benny-The-Butcher-and-Maxo-Kream-by-Anwar-Carrots-Benn',
#   'table_descr': "Anwar Carrots, Benny The Butcher, Maxo Kream's 'Phone Ring (with Benny The Butcher and Maxo Kream)' had a release date set for April 22, 2025. Phone Ring (with Benny The Butcher and Maxo Kream) is 2 minutes and 31 seconds long and may contain bad words that may be unsuitable for children. Since Phone Ring only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. The popularity of Phone Ring (with Benny The Butcher and Maxo Kream) is currently not that popular right now. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_name': 'MONDAY',
#   'table_artist': 'Quadeca',
#   'table_data': '2025-04-22',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '153',
#   'table_energy': '8',
#   'table_link': '/track/13VNbW9gblZQVVM2a7ZQf5/MONDAY-by-Quadeca',
#   'table_descr': 'Quadeca\'s \'MONDAY\' had a release date set for April 22, 2025. With this song being around four minutes long, at 4:03, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The track order of this song in Quadeca\'s "MONDAY" album is number 1 out of 2. Based on our statistics, MONDAY\'s popularity is average in popularity right now. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_name': 'Heart By Heart',
#   'table_artist': 'Joe Jonas',
#   'table_data': '2025-04-25',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '148',
#   'table_energy': '8',
#   'table_link': '/track/6NUoW7RwcO1jcrSvJ2V6od/Heart-By-Heart-by-Joe-Jonas',
#   'table_descr': 'Joe Jonas\'s \' "Heart By Heart" was released on its scheduled release date, April 25, 2025. The duration of This song is about 3 minutes long, at 3:10. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in Heart By Heart and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. Based on our statistics, Heart By Heart\'s popularity is below average in popularity right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'Act Right',
#   'table_artist': 'Sasha Keable',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '90',
#   'table_energy': '6',
#   'table_link': '/track/1z0gNe6DiusPKN55RBAvRO/Act-Right-by-Sasha-Keable',
#   'table_descr': "Sasha Keable's 'Act Right' had a release date set for April 25, 2025. Act Right is 2 minutes and 53 seconds long and may contain bad words that may be unsuitable for children. The song is number 1 out of 2 in Act Right by Sasha Keable. Going off of the ISRC code of this track, we detected that the origin of this track is from United Kingdom. In terms of popularity, Act Right is currently unknown. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_name': 'Lovesick Lullaby',
#   'table_artist': 'YUNGBLUD',
#   'table_data': '2025-04-25',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '118',
#   'table_energy': '7',
#   'table_link': '/track/2LRSQhv3Vi8SkEllnvUhEK/Lovesick-Lullaby-by-YUNGBLUD',
#   'table_descr': 'YUNGBLUD\'s \' "Lovesick Lullaby" was released on its scheduled release date, April 25, 2025. Lovesick Lullaby is 2 minutes and 55 seconds long and may contain bad words that may be unsuitable for children. The track order of this song in YUNGBLUD\'s "Lovesick Lullaby" album is number 1 out of 2. On top of that, United States appears to be the country where this track was created. In terms of popularity, Lovesick Lullaby is currently unknown. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'On One',
# ...
#  {'table_name': 'Morena',
#   'table_artist': 'Neton Vega, Peso Pluma',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '122',
#   'table_link': '/track/4oB8Xd7gMlUEtWoD8bmCXW/Morena-by-Neton-Vega-Peso-Pluma',
#   'table_descr': '"Morena" by Neton Vega, Peso Pluma had its release date on February 14, 2025. The duration of This song is about 3 minutes long, at 3:13. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. The track order of this song in Neton Vega\'s "Mi Vida Mi Muerte" album is number 4 out of 21. On top of that, United States appears to be the country where this track was created. Based on our statistics, Morena\'s popularity is very popular right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'Feel It (From “Invincible”)',
#   'table_artist': 'd4vd',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '120',
#   'table_link': '/track/3SAga35lAPYdjj3qyfEsCF/Feel-It-From-Invincible-by-d4vd',
#   'table_descr': 'd4vd\'s \' "Feel It (From “Invincible”)" was released on its scheduled release date, March 28, 2024. The duration of This song is about two minutes long, specifically at 2:37. This song does not appear to have any foul language. Feel It (From “Invincible”)\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in Feel It (From “Invincible”) and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, Feel It (From “Invincible”)\'s popularity is very popular right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Qué Pasaría...',
#   'table_artist': 'Rauw Alejandro, Bad Bunny',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '156',
#   'table_link': '/track/0OxKf18dUo2G5dFOQYCvBN/Qu-Pasara-by-Rauw-Alejandro-Bad-Bunny',
#   'table_descr': 'Rauw Alejandro, Bad Bunny\'s \' "Qué Pasaría..." was released on its scheduled release date, November 14, 2024. Qué Pasaría... is considered explicit and may contain foul language. This song is about 3 minutes and 11 seconds, which is about the average length of a typical song. Since Qué Pasaría... only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. Based on our statistics, Qué Pasaría...\'s popularity is fairly popular right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Back To Me',
#   'table_artist': 'The Marías',
#   'table_key': 'A Major',
#   'table_camelot': '11B',
#   'table_bpm': '144',
#   'table_link': '/track/4E0P1xs3JNmsNr5c5nFTZJ/Back-To-Me-by-The-Maras',
#   'table_descr': 'The Marías\'s \'Back To Me\' had a release date set for April 4, 2025. With this song being around four minutes long, at 3:34, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The song is number 1 out of 2 in Back To Me by The Marías. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, Back To Me\'s popularity is pretty popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_name': "Fix What You Didn't Break",
#   'table_artist': 'Nate Smith',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '156',
#   'table_link': '/track/0GJ8peTqHq9pu5Yf2vHjjX/Fix-What-You-Didnt-Break-by-Nate-Smith',
#   'table_descr': 'Nate Smith\'s \' "Fix What You Didn\'t Break" was released on its scheduled release date, August 23, 2024. The duration of This song is about 3 minutes long, at 3:21. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in Fix What You Didn\'t Break and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, Fix What You Didn\'t Break\'s popularity is unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'Emergence',
#   'table_artist': 'Sleep Token',
#   'table_key': 'E Minor',
#   'table_camelot': '9A',
#   'table_bpm': '126',
#   'table_link': '/track/5NRpxJxtR6JkUhQS4F0um6/Emergence-by-Sleep-Token',
#   'table_descr': '"Emergence" by Sleep Token had its release date on March 13, 2025. This song is about six minutes long, preciously at 6:26, making this song fairly long compared to other songs. Because this song is the only song in Emergence and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, Emergence\'s popularity is pretty popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_name': 'intro (end of the world) - extended',
#   'table_artist': 'Ariana Grande',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '170',
#   'table_link': '/track/5BBkvXH2jYROUzKIB7WX7S/intro-end-of-the-world-extended-by-Ariana-Grande',
#   'table_descr': "Ariana Grande's 'intro (end of the world) - extended' had a release date set for March 28, 2025. intro (end of the world) - extended is 2 minutes and 41 seconds long and may contain bad words that may be unsuitable for children. The song is number 14 out of 19 in eternal sunshine deluxe: brighter days ahead by Ariana Grande. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. The popularity of intro (end of the world) - extended is currently unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. "},
#  {'table_name': 'NUEVAYoL',
#   'table_artist': 'Bad Bunny',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '98',
#   'table_link': '/track/5TFD2bmFKGhoCRbX61nXY5/NUEVAYoL-by-Bad-Bunny',
#   'table_descr': 'Bad Bunny\'s \' "NUEVAYoL" was released on its scheduled release date, January 5, 2025. The duration of This song is about 3 minutes long, at 3:03. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. The song is number 1 out of 17 in DeBÍ TiRAR MáS FOToS by Bad Bunny. In terms of popularity, NUEVAYoL is currently very popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Hometown Home',
#   'table_artist': 'LOCASH',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '142',
#   'table_link': '/track/3L7OAEmomAi443kywQPGJD/Hometown-Home-by-LOCASH',
#   'table_descr': 'LOCASH\'s \' "Hometown Home" was released on its scheduled release date, April 19, 2024. The duration of This song is about 3 minutes long, at 3:28. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in Hometown Home and no other songs are present in the album, we classify this track as a single. Based on our statistics, Hometown Home\'s popularity is average in popularity right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'The Largest',
#   'table_artist': 'BigXthaPlug',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '123',
#   'table_link': '/track/1F5Qp0SJS0QUfqIoQggrLz/The-Largest-by-BigXthaPlug',
#   'table_descr': 'BigXthaPlug\'s \' "The Largest" was released on its scheduled release date, August 9, 2024. The Largest is 2 minutes and 12 seconds long and may contain bad words that may be unsuitable for children. Since The Largest only contains only one song in the album, we like to consider this song as a single. Based on our statistics, The Largest\'s popularity is unknown right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Headlock',
#   'table_artist': 'Imogen Heap',
#   'table_key': 'G Minor',
#   'table_camelot': '6A',
#   'table_bpm': '120',
#   'table_link': '/track/63Pi2NAx5yCgeLhCTOrEou/Headlock-by-Imogen-Heap',
#   'table_descr': 'Imogen Heap\'s \' "Headlock" was released on its scheduled release date, 2005. With this song being around four minutes long, at 3:35, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. There are a total of 24 in the song\'s album "Speak for Yourself (Deluxe Version)". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United Kingdom. Based on our statistics, Headlock\'s popularity is pretty popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'TATTOO',
#   'table_artist': 'Tito Double P',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '110',
#   'table_link': '/track/3KgHiAVuP88QoQs9CO4z1P/TATTOO-by-Tito-Double-P',
#   'table_descr': 'Tito Double P\'s \' "TATTOO" was released on its scheduled release date, February 27, 2025. TATTOO is 2 minutes and 47 seconds long and may contain bad words that may be unsuitable for children. Since TATTOO only contains only one song in the album, we like to consider this song as a single. In terms of popularity, TATTOO is currently very popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Backseat Driver',
#   'table_artist': 'Kane Brown',
#   'table_key': 'F♯ Major',
#   'table_camelot': '2B',
#   'table_bpm': '76',
#   'table_link': '/track/68SYsp6XfIEnlDYMgMyxUv/Backseat-Driver-by-Kane-Brown',
#   'table_descr': 'Kane Brown\'s \' "Backseat Driver" was released on its scheduled release date, October 11, 2024. With this song being around four minutes long, at 3:48, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Backseat Driver and no other songs are present in the album, we classify this track as a single. Backseat Driver is unknown right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'undressed',
#   'table_artist': 'sombr',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '116',
#   'table_link': '/track/4AajxCEwGEsmHmT4H1TwjY/undressed-by-sombr',
#   'table_descr': 'On March 21, 2025, the song "undressed" was released by sombr. The duration of This song is about 3 minutes long, at 3:02. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Since undressed only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. In terms of popularity, undressed is currently very popular. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Little Things',
#   'table_artist': 'Ella Mai',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '136',
#   'table_link': '/track/2HA4tNLIXY1dGvDVCLeslk/Little-Things-by-Ella-Mai',
#   'table_descr': 'Ella Mai\'s \'Little Things\' had a release date set for November 3, 2024. The duration of This song is about two minutes long, specifically at 2:52. This song does not appear to have any foul language. Little Things\'s duration is considered a little bit shorter than the average duration of a typical track. There is only one song in 3, so we believe that "Little Things" is a single. Based on our statistics, Little Things\'s popularity is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'Por Esos Ojos',
#   'table_artist': 'Fuerza Regida',
#   'table_key': 'F Major',
#   'table_camelot': '7B',
#   'table_bpm': '76',
#   'table_link': '/track/5jHozZMWbrExAFni95mvvH/Por-Esos-Ojos-by-Fuerza-Regida',
#   'table_descr': "Fuerza Regida's 'Por Esos Ojos' had a release date set for February 11, 2025. Por Esos Ojos is considered explicit and may contain foul language. This song is about 3 minutes and 8 seconds, which is about the average length of a typical song. Since Por Esos Ojos only contains only one song in the album, we like to consider this song as a single. Por Esos Ojos is unknown right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. "},
#  {'table_name': 'Haunted',
#   'table_artist': 'Kane Brown, Jelly Roll',
#   'table_key': 'E♭ Major',
#   'table_camelot': '5B',
#   'table_bpm': '89',
#   'table_link': '/track/0Gz45mObitRRxd5EtFkHuh/Haunted-by-Kane-Brown-Jelly-Roll',
#   'table_descr': 'Kane Brown, Jelly Roll\'s \'Haunted\' had a release date set for January 24, 2025. With this song being around four minutes long, at 4:24, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. There are a total of 18 in the song\'s album "The High Road". In this album, this song\'s track order is #8. Haunted is unknown right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'Khé?',
#   'table_artist': 'Rauw Alejandro, Romeo Santos',
#   'table_key': 'D Major',
#   'table_camelot': '10B',
#   'table_bpm': '115',
#   'table_link': '/track/1YYfyJ2yCvGFCxwjsIqEK9/Kh-by-Rauw-Alejandro-Romeo-Santos',
#   'table_descr': 'Rauw Alejandro, Romeo Santos\'s \' "Khé?" was released on its scheduled release date, November 15, 2024. The duration of This song is about 3 minutes long, at 3:26. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. The song is number 12 out of 18 in Cosa Nuestra by Rauw Alejandro. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. In terms of popularity, Khé? is currently pretty popular. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '}]

# %%
for song in td:
    scrape_descriptions(song) #do this for all songs

# %%
import pandas as pd

df = pd.DataFrame(td) 
df.to_csv('Recent_Songs.csv')

# %%
top_2024 = scrape_links('https://songdata.io/charts/2024')

# %%
for song in top_2024:
    scrape_descriptions(song) #do this for all songs
    song.pop('table_img',None)
    song.pop('table_play',None)

top_2024
# Out:
# [{'table_name': 'BIRDS OF A FEATHER',
#   'table_artist': 'Billie Eilish',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '110',
#   'table_link': '/track/6dOtVTDdiauQNBQEDOtlAB/BIRDS-OF-A-FEATHER-by-Billie-Eilish',
#   'table_descr': 'Billie Eilish\'s \' "BIRDS OF A FEATHER" was released on its scheduled release date, May 17, 2024. With this song being around four minutes long, at 3:30, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The track order of this song in Billie Eilish\'s "HIT ME HARD AND SOFT" album is number 4 out of 10. On top of that, United States appears to be the country where this track was created. In terms of popularity, BIRDS OF A FEATHER is currently one of the hottest tracks right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Die With A Smile',
#   'table_artist': 'Lady Gaga, Bruno Mars',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '158',
#   'table_link': '/track/2plbrEY59IikOBgBGLjaoe/Die-With-A-Smile-by-Lady-Gaga-Bruno-Mars',
#   'table_descr': 'Lady Gaga, Bruno Mars\'s \' "Die With A Smile" was released on its scheduled release date, August 16, 2024. With this song being around four minutes long, at 4:11, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Die With A Smile and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, Die With A Smile\'s popularity is very popular right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'That’s So True',
#   'table_artist': 'Gracie Abrams',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '150',
#   'table_link': '/track/7ne4VBA60CxGM75vw0EYad/Thats-So-True-by-Gracie-Abrams',
#   'table_descr': 'Gracie Abrams\'s \'That’s So True\' had a release date set for October 18, 2024. That’s So True is 2 minutes and 46 seconds long and may contain bad words that may be unsuitable for children. There are a total of 20 in the song\'s album "The Secret of Us (Deluxe)". In this album, this song\'s track order is #15. Furthermore, we believe that the track originated from United States. Based on our statistics, That’s So True\'s popularity is very popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_name': 'Sailor Song',
#   'table_artist': 'Gigi Perez',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '95',
#   'table_link': '/track/2262bWmqomIaJXwCRHr13j/Sailor-Song-by-Gigi-Perez',
#   'table_descr': 'Gigi Perez\'s \'Sailor Song\' had a release date set for July 26, 2024. With this song being around four minutes long, at 3:31, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Since Sailor Song only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. In terms of popularity, Sailor Song is currently very popular. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_name': 'love hotel',
#   'table_artist': 'leftovermax',
#   'table_key': 'F♯ Major',
#   'table_camelot': '2B',
#   'table_bpm': '126',
#   'table_link': '/track/6IwmDRpswDujeciIBTiEOL/love-hotel-by-leftovermax',
#   'table_descr': "leftovermax's 'love hotel' had a release date set for May 3, 2024. The duration of This song is about two minutes long, specifically at 2:32. This song does not appear to have any foul language. love hotel's duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in love hotel and no other songs are present in the album, we classify this track as a single. Based on our statistics, love hotel's popularity is very popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. "},
#  {'table_name': 'Not Like Us',
#   'table_artist': 'Kendrick Lamar',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '101',
#   'table_link': '/track/6AI3ezQ4o3HUoP6Dhudph3/Not-Like-Us-by-Kendrick-Lamar',
#   'table_descr': "Kendrick Lamar's 'Not Like Us' had a release date set for May 4, 2024. This song is quite longer than the average track at 4 minutes and 34 seconds. With that being said, this track is also considered explicit and may be offensive to some people. Because this song is the only song in Not Like Us and no other songs are present in the album, we classify this track as a single. Furthermore, we believe that the track originated from United States. In terms of popularity, Not Like Us is currently very popular. Although the overall vibe is very danceable, it does project more negative sounds. "},
#  {'table_name': 'APT.',
#   'table_artist': 'ROSÉ, Bruno Mars',
#   'table_key': 'C Minor',
#   'table_camelot': '5A',
#   'table_bpm': '149',
#   'table_link': '/track/4wJ5Qq0jBN4ajy7ouZIV1c/APT-by-ROS-Bruno-Mars',
#   'table_descr': 'On December 6, 2024, the song "APT." was released by ROSÉ, Bruno Mars. The duration of This song is about two minutes long, specifically at 2:49. This song does not appear to have any foul language. APT.\'s duration is considered a little bit shorter than the average duration of a typical track. There are a total of 12 in the song\'s album "rosie". In this album, this song\'s track order is #6. Furthermore, we believe that the track originated from United States. Based on our statistics, APT.\'s popularity is very popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'WILDFLOWER',
#   'table_artist': 'Billie Eilish',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '148',
#   'table_link': '/track/3QaPy1KgI7nu9FJEQUgn6h/WILDFLOWER-by-Billie-Eilish',
#   'table_descr': '"WILDFLOWER" by Billie Eilish had its release date on May 17, 2024. With this song being around four minutes long, at 4:21, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The track order of this song in Billie Eilish\'s "HIT ME HARD AND SOFT" album is number 5 out of 10. On top of that, United States appears to be the country where this track was created. Based on our statistics, WILDFLOWER\'s popularity is very popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_name': 'Good Luck, Babe!',
#   'table_artist': 'Chappell Roan',
#   'table_key': 'B Minor',
#   'table_camelot': '10A',
#   'table_bpm': '117',
#   'table_link': '/track/0WbMK4wrZ1wFSty9F7FCgu/Good-Luck-Babe-by-Chappell-Roan',
#   'table_descr': 'Chappell Roan\'s \' "Good Luck, Babe!" was released on its scheduled release date, April 5, 2024. With this song being around four minutes long, at 3:38, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in Good Luck, Babe! and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. In terms of popularity, Good Luck, Babe! is currently very popular. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Si Antes Te Hubiera Conocido',
#   'table_artist': 'KAROL G',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '128',
#   'table_link': '/track/6WatFBLVB0x077xWeoVc2k/Si-Antes-Te-Hubiera-Conocido-by-KAROL-G',
#   'table_descr': 'KAROL G\'s \' "Si Antes Te Hubiera Conocido" was released on its scheduled release date, June 21, 2024. The duration of This song is about 3 minutes long, at 3:15. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Since Si Antes Te Hubiera Conocido only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. Based on our statistics, Si Antes Te Hubiera Conocido\'s popularity is very popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'luther (with sza)',
#   'table_artist': 'Kendrick Lamar, SZA',
#   'table_key': 'D Major',
#   'table_camelot': '10B',
#   'table_bpm': '200',
#   'table_link': '/track/45J4avUb9Ni0bnETYaYFVJ/luther-with-sza-by-Kendrick-Lamar-SZA',
#   'table_descr': 'Kendrick Lamar, SZA\'s \' "luther (with sza)" was released on its scheduled release date, November 22, 2024. The duration of This song is about two minutes long, specifically at 2:57. This song does not appear to have any foul language. luther (with sza)\'s duration is considered a little bit shorter than the average duration of a typical track. The track order of this song in Kendrick Lamar\'s "GNX" album is number 3 out of 12. On top of that, United States appears to be the country where this track was created. Based on our statistics, luther (with sza)\'s popularity is very popular right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'tv off (feat. lefty gunplay)',
#   'table_artist': 'Kendrick Lamar, Lefty Gunplay',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '100',
#   'table_link': '/track/0aB0v4027ukVziUGwVGYpG/tv-off-feat-lefty-gunplay-by-Kendrick-Lamar-Lefty-Gunplay',
#   'table_descr': 'Kendrick Lamar, Lefty Gunplay\'s \' "tv off (feat. lefty gunplay)" was released on its scheduled release date, November 22, 2024. tv off (feat. lefty gunplay) is explicit and may not be suitable for children. With the duration being about 3:40, this song is close to the average duration of a typical track. The track order of this song in Kendrick Lamar\'s "GNX" album is number 7 out of 12. On top of that, United States appears to be the country where this track was created. In terms of popularity, tv off (feat. lefty gunplay) is currently very popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'luther (with sza)',
#   'table_artist': 'Kendrick Lamar, SZA',
#   'table_key': 'D Major',
#   'table_camelot': '10B',
#   'table_bpm': '138',
#   'table_link': '/track/45J4avUb9Ni0bnETYaYFVJ/luther-with-sza-by-Kendrick-Lamar-SZA',
#   'table_descr': 'Kendrick Lamar, SZA\'s \' "luther (with sza)" was released on its scheduled release date, November 22, 2024. The duration of This song is about two minutes long, specifically at 2:57. This song does not appear to have any foul language. luther (with sza)\'s duration is considered a little bit shorter than the average duration of a typical track. The track order of this song in Kendrick Lamar\'s "GNX" album is number 3 out of 12. On top of that, United States appears to be the country where this track was created. Based on our statistics, luther (with sza)\'s popularity is very popular right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'blue',
#   'table_artist': 'yung kai',
#   'table_key': 'E Major',
#   'table_camelot': '12B',
#   'table_bpm': '97',
#   'table_link': '/track/3be9ACTxtcL6Zm4vJRUiPG/blue-by-yung-kai',
#   'table_descr': 'yung kai\'s \' "blue" was released on its scheduled release date, August 2, 2024. With this song being around four minutes long, at 3:34, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in blue and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from Timor-Leste. In terms of popularity, blue is currently very popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Taste',
#   'table_artist': 'Sabrina Carpenter',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '90',
#   'table_link': '/track/5G2f63n7IPVPPjfNIGih7Q/Taste-by-Sabrina-Carpenter',
#   'table_descr': 'Sabrina Carpenter\'s \'Taste\' had a release date set for August 23, 2024. The duration of This song is about two minutes long, specifically at 2:37. This song does not appear to have any foul language. Taste\'s duration is considered a little bit shorter than the average duration of a typical track. There are a total of 12 in the song\'s album "Short n\' Sweet". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United States. In terms of popularity, Taste is currently very popular. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'APT.',
#   'table_artist': 'ROSÉ, Bruno Mars',
#   'table_key': 'C Minor',
#   'table_camelot': '5A',
#   'table_bpm': '149',
#   'table_link': '/track/4wJ5Qq0jBN4ajy7ouZIV1c/APT-by-ROS-Bruno-Mars',
#   'table_descr': 'On December 6, 2024, the song "APT." was released by ROSÉ, Bruno Mars. The duration of This song is about two minutes long, specifically at 2:49. This song does not appear to have any foul language. APT.\'s duration is considered a little bit shorter than the average duration of a typical track. There are a total of 12 in the song\'s album "rosie". In this album, this song\'s track order is #6. Furthermore, we believe that the track originated from United States. Based on our statistics, APT.\'s popularity is very popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Messy',
#   'table_artist': 'Lola Young',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '117',
#   'table_link': '/track/35ISBknsCeZQtq66xABI9g/Messy-by-Lola-Young',
#   'table_descr': 'Lola Young\'s \' "Messy" was released on its scheduled release date, June 21, 2024. This song is quite longer than the average track at 4 minutes and 44 seconds. With that being said, this track is also considered explicit and may be offensive to some people. There are a total of 11 in the song\'s album "This Wasn\'t Meant For You Anyway". In this album, this song\'s track order is #5. Furthermore, we believe that the track originated from United Kingdom. In terms of popularity, Messy is currently pretty popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Feel It (From “Invincible”)',
#   'table_artist': 'd4vd',
#   'table_key': 'A♭ Major',
#   'table_camelot': '4B',
#   'table_bpm': '120',
#   'table_link': '/track/3SAga35lAPYdjj3qyfEsCF/Feel-It-From-Invincible-by-d4vd',
#   'table_descr': 'd4vd\'s \' "Feel It (From “Invincible”)" was released on its scheduled release date, March 28, 2024. The duration of This song is about two minutes long, specifically at 2:37. This song does not appear to have any foul language. Feel It (From “Invincible”)\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in Feel It (From “Invincible”) and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, Feel It (From “Invincible”)\'s popularity is very popular right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'ME JALO',
#   'table_artist': 'Fuerza Regida, Grupo Frontera',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '158',
#   'table_link': '/track/3D24ErT1MMmUfXWotSj2A2/ME-JALO-by-Fuerza-Regida-Grupo-Frontera',
#   'table_descr': 'Fuerza Regida, Grupo Frontera\'s \' "ME JALO" was released on its scheduled release date, December 19, 2024. ME JALO is explicit and may not be suitable for children. With the duration being about 3:32, this song is close to the average duration of a typical track. The track order of this song in Fuerza Regida, Grupo Frontera\'s "MALA MÍA" album is number 1 out of 5. Based on our statistics, ME JALO\'s popularity is very popular right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'mi refe',
#   'table_artist': 'Beéle, Ovy On The Drums',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '100',
#   'table_link': '/track/7ricDBUakN3N0YkkKE8Obu/mi-refe-by-Bele-Ovy-On-The-Drums',
#   'table_descr': 'Beéle, Ovy On The Drums\'s \' "mi refe" was released on its scheduled release date, December 5, 2024. The duration of This song is about two minutes long, specifically at 2:39. This song does not appear to have any foul language. mi refe\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in mi refe and no other songs are present in the album, we classify this track as a single. In terms of popularity, mi refe is currently very popular. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'CHIHIRO',
#   'table_artist': 'Billie Eilish',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '110',
#   'table_link': '/track/7BRD7x5pt8Lqa1eGYC4dzj/CHIHIRO-by-Billie-Eilish',
#   'table_descr': 'Billie Eilish\'s \' "CHIHIRO" was released on its scheduled release date, May 17, 2024. With this song being about 5 minutes long, at This song is fairly a long song compared to the average song length. This song does not have an "Explicit" tag, making it safe for all ages. The track order of this song in Billie Eilish\'s "HIT ME HARD AND SOFT" album is number 3 out of 10. On top of that, United States appears to be the country where this track was created. In terms of popularity, CHIHIRO is currently very popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Like Him (feat. Lola Young)',
#   'table_artist': 'Tyler, The Creator, Lola Young',
#   'table_key': 'E Minor',
#   'table_camelot': '9A',
#   'table_bpm': '96',
#   'table_link': '/track/6jbYpRPTEFl1HFKHk1IC0m/Like-Him-feat-Lola-Young-by-Tyler-The-Creator-Lola-Young',
#   'table_descr': '"Like Him (feat. Lola Young)" by Tyler, The Creator, Lola Young had its release date on October 28, 2024. This song is quite longer than the average track at 4 minutes and 38 seconds. With that being said, this track is also considered explicit and may be offensive to some people. The song is number 12 out of 14 in CHROMAKOPIA by Tyler, The Creator. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. In terms of popularity, Like Him (feat. Lola Young) is currently very popular. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_name': "I Love You, I'm Sorry",
#   'table_artist': 'Gracie Abrams',
#   'table_key': 'E♭ Major',
#   'table_camelot': '5B',
#   'table_bpm': '81',
#   'table_link': '/track/51rfRCiUSvxXlCSCfIztBy/I-Love-You-Im-Sorry-by-Gracie-Abrams',
#   'table_descr': 'Gracie Abrams\'s \'I Love You, I\'m Sorry\' had a release date set for June 21, 2024. I Love You, I\'m Sorry is 2 minutes and 37 seconds long and may contain bad words that may be unsuitable for children. There are a total of 13 in the song\'s album "The Secret of Us". In this album, this song\'s track order is #4. Furthermore, we believe that the track originated from United States. I Love You, I\'m Sorry is very popular right now. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. '},
#  {'table_name': 'The Days - NOTION Remix',
#   'table_artist': 'Chrystal, NOTION',
#   'table_key': 'F♯ Minor',
#   'table_camelot': '11A',
#   'table_bpm': '138',
#   'table_link': '/track/2FAZskT9yRjp2Oow9szJD8/The-Days-NOTION-Remix-by-Chrystal-NOTION',
#   'table_descr': 'Chrystal, NOTION\'s \'The Days - NOTION Remix\' had a release date set for November 8, 2024. With this song being around four minutes long, at 3:53, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. There are a total of 2 in the song\'s album "The Days (NOTION Remix)". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from United Kingdom. Based on our statistics, The Days - NOTION Remix\'s popularity is very popular right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'DENIAL IS A RIVER',
#   'table_artist': 'Doechii',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '113',
#   'table_link': '/track/1eTaznNW4Xxtx9za2SMTXB/DENIAL-IS-A-RIVER-by-Doechii',
#   'table_descr': 'Doechii\'s \' "DENIAL IS A RIVER" was released on its scheduled release date, August 30, 2024. DENIAL IS A RIVER is 2 minutes and 39 seconds long and may contain bad words that may be unsuitable for children. The song is number 4 out of 19 in Alligator Bites Never Heal by Doechii. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. In terms of popularity, DENIAL IS A RIVER is currently very popular. The overall mood can be danceable to some, especially with it\'s high amount of postive energy. '},
#  {'table_name': 'Who',
#   'table_artist': 'Jimin',
#   'table_key': 'A Major',
#   'table_camelot': '11B',
#   'table_bpm': '128',
#   'table_link': '/track/7tI8dRuH2Yc6RuoTjxo4dU/Who-by-Jimin',
#   'table_descr': '"Who" by Jimin had its release date on July 19, 2024. The duration of This song is about two minutes long, specifically at 2:50. This song does not appear to have any foul language. Who\'s duration is considered a little bit shorter than the average duration of a typical track. The track order of this song in Jimin\'s "MUSE" album is number 6 out of 7. On top of that, United States appears to be the country where this track was created. Based on our statistics, Who\'s popularity is very popular right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'NADIE',
#   'table_artist': 'Tito Double P',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '93',
#   'table_link': '/track/7sd6zMrgGpEa7NkQm9TRrg/NADIE-by-Tito-Double-P',
#   'table_descr': 'Tito Double P\'s \' "NADIE" was released on its scheduled release date, November 21, 2024. NADIE is considered explicit and may contain foul language. This song is about 3 minutes and 17 seconds, which is about the average length of a typical song. Because this song is the only song in NADIE and no other songs are present in the album, we classify this track as a single. In terms of popularity, NADIE is currently very popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Beautiful Things',
#   'table_artist': 'Benson Boone',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '99',
#   'table_link': '/track/6tNQ70jh4OwmPGpYy6R2o9/Beautiful-Things-by-Benson-Boone',
#   'table_descr': 'Benson Boone\'s \' "Beautiful Things" was released on its scheduled release date, January 18, 2024. The duration of This song is about 3 minutes long, at 3:00. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in Beautiful Things and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Beautiful Things is pretty popular right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'No One Noticed',
#   'table_artist': 'The Marías',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '98',
#   'table_link': '/track/3siwsiaEoU4Kuuc9WKMUy5/No-One-Noticed-by-The-Maras',
#   'table_descr': 'The Marías\'s \' "No One Noticed" was released on its scheduled release date, May 31, 2024. With this song being around four minutes long, at 3:56, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. There are a total of 14 in the song\'s album "Submarine". In this album, this song\'s track order is #11. Furthermore, we believe that the track originated from United States. In terms of popularity, No One Noticed is currently very popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Espresso',
#   'table_artist': 'Sabrina Carpenter',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '104',
#   'table_link': '/track/2HRqTpkrJO5ggZyyK6NPWz/Espresso-by-Sabrina-Carpenter',
#   'table_descr': 'Sabrina Carpenter\'s \'Espresso\' had a release date set for August 23, 2024. Espresso is 2 minutes and 55 seconds long and may contain bad words that may be unsuitable for children. There are a total of 12 in the song\'s album "Short n\' Sweet". In this album, this song\'s track order is #7. Furthermore, we believe that the track originated from United States. In terms of popularity, Espresso is currently very popular. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'Espresso',
#   'table_artist': 'Sabrina Carpenter',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '90',
#   'table_link': '/track/2HRqTpkrJO5ggZyyK6NPWz/Espresso-by-Sabrina-Carpenter',
#   'table_descr': 'Sabrina Carpenter\'s \'Espresso\' had a release date set for August 23, 2024. Espresso is 2 minutes and 55 seconds long and may contain bad words that may be unsuitable for children. There are a total of 12 in the song\'s album "Short n\' Sweet". In this album, this song\'s track order is #7. Furthermore, we believe that the track originated from United States. In terms of popularity, Espresso is currently very popular. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'squabble up',
#   'table_artist': 'Kendrick Lamar',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '104',
#   'table_link': '/track/0nj9Bq5sHDiTxSHunhgkFb/squabble-up-by-Kendrick-Lamar',
#   'table_descr': 'Kendrick Lamar\'s \' "squabble up" was released on its scheduled release date, November 22, 2024. squabble up is 2 minutes and 37 seconds long and may contain bad words that may be unsuitable for children. The track order of this song in Kendrick Lamar\'s "GNX" album is number 2 out of 12. On top of that, United States appears to be the country where this track was created. In terms of popularity, squabble up is currently very popular. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'ROSONES',
#   'table_artist': 'Tito Double P',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '120',
#   'table_link': '/track/6x59lSlNU7TvsJZy7134uC/ROSONES-by-Jorsshh-Fuerza-Regida',
#   'table_descr': 'On November 15, 2024, the song "ROSONES" was released by Jorsshh, Fuerza Regida. ROSONES is 2 minutes and 58 seconds long and may contain bad words that may be unsuitable for children. Since ROSONES only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. Based on our statistics, ROSONES\'s popularity is pretty popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Qué Pasaría...',
#   'table_artist': 'Rauw Alejandro, Bad Bunny',
#   'table_key': 'D Major',
#   'table_camelot': '10B',
#   'table_bpm': '115',
#   'table_link': '/track/0l0vcZMU7AOeQmUIREoI2U/Qu-Pasara-by-Rauw-Alejandro-Bad-Bunny',
#   'table_descr': 'Rauw Alejandro, Bad Bunny\'s \' "Qué Pasaría..." was released on its scheduled release date, November 15, 2024. Qué Pasaría... is considered explicit and may contain foul language. This song is about 3 minutes and 11 seconds, which is about the average length of a typical song. The song is number 3 out of 18 in Cosa Nuestra by Rauw Alejandro. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. In terms of popularity, Qué Pasaría... is currently very popular. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'back to friends',
#   'table_artist': 'sombr',
#   'table_key': 'A Minor',
#   'table_camelot': '8A',
#   'table_bpm': '118',
#   'table_link': '/track/0FTmksd2dxiE5e3rWyJXs6/back-to-friends-by-sombr',
#   'table_descr': 'sombr\'s \' "back to friends" was released on its scheduled release date, December 27, 2024. The duration of This song is about 3 minutes long, at 3:19. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in back to friends and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. In terms of popularity, back to friends is currently very popular. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'Gata Only',
#   'table_artist': 'FloyyMenor, Cris Mj',
#   'table_key': 'A♭ Minor',
#   'table_camelot': '1A',
#   'table_bpm': '100',
#   'table_link': '/track/6XjDF6nds4DE2BBbagZol6/Gata-Only-by-FloyyMenor-Cris-Mj',
#   'table_descr': 'FloyyMenor, Cris Mj\'s \' "Gata Only" was released on its scheduled release date, February 2, 2024. Gata Only is explicit and may not be suitable for children. With the duration being about 3:42, this song is close to the average duration of a typical track. Because this song is the only song in Gata Only and no other songs are present in the album, we classify this track as a single. In terms of popularity, Gata Only is currently pretty popular. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Beautiful Things',
#   'table_artist': 'Benson Boone',
#   'table_key': 'E Major',
#   'table_camelot': '12B',
#   'table_bpm': '82',
#   'table_link': '/track/6tNQ70jh4OwmPGpYy6R2o9/Beautiful-Things-by-Benson-Boone',
#   'table_descr': 'Benson Boone\'s \' "Beautiful Things" was released on its scheduled release date, January 18, 2024. The duration of This song is about 3 minutes long, at 3:00. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in Beautiful Things and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Beautiful Things is pretty popular right now. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'Loco',
#   'table_artist': 'Neton Vega',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '92',
#   'table_link': '/track/63EQbNhgaih4yg5412usWG/Loco-by-Neton-Vega',
#   'table_descr': 'Neton Vega\'s \' "Loco" was released on its scheduled release date, December 20, 2024. The duration of This song is about 3 minutes long, at 3:06. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in Loco and no other songs are present in the album, we classify this track as a single. In terms of popularity, Loco is currently pretty popular. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'DOS DÍAS',
#   'table_artist': 'Tito Double P, Peso Pluma',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '122',
#   'table_link': '/track/5lKFO0PrOC9jmOlPEdjHsL/DOS-DAS-by-Tito-Double-P-Peso-Pluma',
#   'table_descr': 'On August 22, 2024, the song "DOS DÍAS" was released by Tito Double P, Peso Pluma. DOS DÍAS is 2 minutes and 33 seconds long and may contain bad words that may be unsuitable for children. The track order of this song in Tito Double P\'s "INCÓMODO" album is number 13 out of 21. Based on our statistics, DOS DÍAS\'s popularity is pretty popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': "we can't be friends (wait for your love)",
#   'table_artist': 'Ariana Grande',
#   'table_key': 'F Major',
#   'table_camelot': '7B',
#   'table_bpm': '116',
#   'table_link': '/track/51ZQ1vr10ffzbwIjDCwqm4/we-cant-be-friends-wait-for-your-love-by-Ariana-Grande',
#   'table_descr': 'Ariana Grande\'s \'we can\'t be friends (wait for your love)\' had a release date set for March 8, 2024. With this song being around four minutes long, at 3:48, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The song is number 10 out of 13 in eternal sunshine by Ariana Grande. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. In terms of popularity, we can\'t be friends (wait for your love) is currently pretty popular. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'BMF',
#   'table_artist': 'SZA',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '128',
#   'table_link': '/track/3U3hFkMr0Q90pD24EkE3Pr/BMF-by-SZA',
#   'table_descr': 'On December 20, 2024, the song "BMF" was released by SZA. BMF is considered explicit and may contain foul language. This song is about 3 minutes and 0 seconds, which is about the average length of a typical song. There are a total of 38 in the song\'s album "SOS Deluxe: LANA". In this album, this song\'s track order is #5. Furthermore, we believe that the track originated from United States. Based on our statistics, BMF\'s popularity is pretty popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Khé?',
#   'table_artist': 'Rauw Alejandro, Romeo Santos',
#   'table_key': 'D Major',
#   'table_camelot': '10B',
#   'table_bpm': '115',
#   'table_link': '/track/1YYfyJ2yCvGFCxwjsIqEK9/Kh-by-Rauw-Alejandro-Romeo-Santos',
#   'table_descr': 'Rauw Alejandro, Romeo Santos\'s \' "Khé?" was released on its scheduled release date, November 15, 2024. The duration of This song is about 3 minutes long, at 3:26. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. The song is number 12 out of 18 in Cosa Nuestra by Rauw Alejandro. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. In terms of popularity, Khé? is currently pretty popular. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Bed Chem',
#   'table_artist': 'Sabrina Carpenter',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '90',
#   'table_link': '/track/1UHS8Rf6h5Ar3CDWRd3wjF/Bed-Chem-by-Sabrina-Carpenter',
#   'table_descr': 'Sabrina Carpenter\'s \'Bed Chem\' had a release date set for August 23, 2024. The duration of This song is about two minutes long, specifically at 2:51. This song does not appear to have any foul language. Bed Chem\'s duration is considered a little bit shorter than the average duration of a typical track. There are a total of 12 in the song\'s album "Short n\' Sweet". In this album, this song\'s track order is #6. Furthermore, we believe that the track originated from United States. In terms of popularity, Bed Chem is currently pretty popular. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'Tu Boda',
#   'table_artist': 'Oscar Maydon, Fuerza Regida',
#   'table_key': 'F♯ Major',
#   'table_camelot': '2B',
#   'table_bpm': '113',
#   'table_link': '/track/1cOboCuWYI2osTOfolMRS6/Tu-Boda-by-Oscar-Maydon-Fuerza-Regida',
#   'table_descr': 'Oscar Maydon, Fuerza Regida\'s \' "Tu Boda" was released on its scheduled release date, September 26, 2024. Tu Boda is explicit and may not be suitable for children. With the duration being about 3:45, this song is close to the average duration of a typical track. Since Tu Boda only contains only one song in the album, we like to consider this song as a single. In terms of popularity, Tu Boda is currently pretty popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Love Somebody',
#   'table_artist': 'Morgan Wallen',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '122',
#   'table_link': '/track/7hR22TOX3RorxJPcsz5Wbo/Love-Somebody-by-Morgan-Wallen',
#   'table_descr': 'Morgan Wallen\'s \' "Love Somebody" was released on its scheduled release date, October 18, 2024. The duration of This song is about 3 minutes long, at 3:24. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Because this song is the only song in Love Somebody and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. Based on our statistics, Love Somebody\'s popularity is pretty popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'I Adore You (feat. Daecolm)',
#   'table_artist': 'HUGEL, Topic, Arash, Daecolm',
#   'table_key': 'A Major',
#   'table_camelot': '11B',
#   'table_bpm': '128',
#   'table_link': '/track/5nPbKG04fhLkIAjcPFaZq7/I-Adore-You-feat-Daecolm-by-HUGEL-Topic-Arash-Daecolm',
#   'table_descr': '"I Adore You (feat. Daecolm)" by HUGEL, Topic, Arash, Daecolm had its release date on July 19, 2024. With this song being around four minutes long, at 3:34, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Because this song is the only song in I Adore You (feat. Daecolm) and no other songs are present in the album, we classify this track as a single. On top of that, Germany appears to be the country where this track was created. Based on our statistics, I Adore You (feat. Daecolm)\'s popularity is pretty popular right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'Pika Pika',
#   'table_artist': 'Chuyin, Fuerza Regida, Jorsshh, Calle 24',
#   'table_key': 'D♭ Major',
#   'table_camelot': '3B',
#   'table_bpm': '127',
#   'table_link': '/track/5LHPcY9yd0hWVFIW4yfOCJ/Pika-Pika-by-Chuyin-Fuerza-Regida-Jorsshh-Calle-24',
#   'table_descr': 'Chuyin, Fuerza Regida, Jorsshh, Calle 24\'s \' "Pika Pika" was released on its scheduled release date, November 29, 2024. Pika Pika is 2 minutes and 27 seconds long and may contain bad words that may be unsuitable for children. Since Pika Pika only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. Based on our statistics, Pika Pika\'s popularity is pretty popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'MILLION DOLLAR BABY',
#   'table_artist': 'Tommy Richman',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '138',
#   'table_link': '/track/5AJ9hqTS2wcFQCELCFRO7A/MILLION-DOLLAR-BABY-by-Tommy-Richman',
#   'table_descr': 'On April 26, 2024, the song "MILLION DOLLAR BABY" was released by Tommy Richman. The duration of This song is about two minutes long, specifically at 2:35. This song does not appear to have any foul language. MILLION DOLLAR BABY\'s duration is considered a little bit shorter than the average duration of a typical track. The track order of this song in Tommy Richman\'s "MILLION DOLLAR BABY" album is number 1 out of 2. Based on our statistics, MILLION DOLLAR BABY\'s popularity is pretty popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Slow It Down',
#   'table_artist': 'Benson Boone',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '99',
#   'table_link': '/track/51eSHglvG1RJXtL3qI5trr/Slow-It-Down-by-Benson-Boone',
#   'table_descr': "Benson Boone's 'Slow It Down' had a release date set for April 5, 2024. The duration of This song is about two minutes long, specifically at 2:41. This song does not appear to have any foul language. Slow It Down's duration is considered a little bit shorter than the average duration of a typical track. The song is number 3 out of 15 in Fireworks & Rollerblades by Benson Boone. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. In terms of popularity, Slow It Down is currently pretty popular. In our opinion, the overall tone is not very danceable and projects negative sounds, such as being sad, depressed, or angry. "},
#  {'table_name': 'Imagínate',
#   'table_artist': 'Danny Ocean, Kapo',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '102',
#   'table_link': '/track/4zbEItKoaRId1vRZkoO0Uh/Imagnate-by-Danny-Ocean-Kapo',
#   'table_descr': 'Danny Ocean, Kapo\'s \' "Imagínate" was released on its scheduled release date, November 7, 2024. The duration of This song is about two minutes long, specifically at 2:50. This song does not appear to have any foul language. Imagínate\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in Imagínate and no other songs are present in the album, we classify this track as a single. On top of that, United States appears to be the country where this track was created. In terms of popularity, Imagínate is currently pretty popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'PASSO BEM SOLTO - Slowed',
#   'table_artist': 'ATLXS',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '116',
#   'table_link': '/track/4sTlQPMyoFMPdhAJvErBN3/PASSO-BEM-SOLTO-Slowed-by-ATLXS',
#   'table_descr': 'ATLXS\'s \' "PASSO BEM SOLTO - Slowed" was released on its scheduled release date, April 23, 2024. For a fairly short song, this song is "PASSO BEM SOLTO - Slowed" is considered an explicit song with a duration of 1:56. There are a total of 5 in the song\'s album "PASSO BEM SOLTO". In this album, this song\'s track order is #3. Furthermore, we believe that the track originated from Australia. In terms of popularity, PASSO BEM SOLTO - Slowed is currently pretty popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Presidente',
#   'table_artist': 'Gabito Ballesteros, Natanael Cano, Luis R Conriquez, Neton Vega',
#   'table_key': 'B Major',
#   'table_camelot': '1B',
#   'table_bpm': '105',
#   'table_link': '/track/4OLT65TRsOx3Iv1TlCcQVb/Presidente-by-Gabito-Ballesteros-Natanael-Cano-Luis-R-Conriquez-Neton-',
#   'table_descr': 'Gabito Ballesteros, Natanael Cano, Luis R Conriquez, Neton Vega\'s \' "Presidente" was released on its scheduled release date, October 21, 2024. Presidente is considered explicit and may contain foul language. This song is about 3 minutes and 1 seconds, which is about the average length of a typical song. Since Presidente only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. In terms of popularity, Presidente is currently pretty popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'capaz (merengueton)',
#   'table_artist': 'Alleh, Yorghaki',
#   'table_key': 'E♭ Minor',
#   'table_camelot': '2A',
#   'table_bpm': '127',
#   'table_link': '/track/3QbfCvCAOCrSGNcGjtOjYM/capaz-merengueton-by-Alleh-Yorghaki',
#   'table_descr': 'Alleh, Yorghaki\'s \' "capaz (merengueton)" was released on its scheduled release date, November 20, 2024. The duration of This song is about two minutes long, specifically at 2:53. This song does not appear to have any foul language. capaz (merengueton)\'s duration is considered a little bit shorter than the average duration of a typical track. Because this song is the only song in capaz (merengueton) and no other songs are present in the album, we classify this track as a single. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, capaz (merengueton)\'s popularity is pretty popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Stargazing',
#   'table_artist': 'Myles Smith',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '124',
#   'table_link': '/track/3Vr3zh0r7ALn8VLqCiRR10/Stargazing-by-Myles-Smith',
# ...
#   'table_descr': 'Don Toliver\'s \'NEW DROP\' had a release date set for June 14, 2024. NEW DROP is explicit and may not be suitable for children. With the duration being about 3:37, this song is close to the average duration of a typical track. The track order of this song in Don Toliver\'s "HARDSTONE PSYCHO" album is number 2 out of 16. On top of that, United States appears to be the country where this track was created. Based on our statistics, NEW DROP\'s popularity is pretty popular right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'Type Shit',
#   'table_artist': 'Future, Metro Boomin, Travis Scott, Playboi Carti',
#   'table_key': 'A Minor',
#   'table_camelot': '8A',
#   'table_bpm': '113',
#   'table_link': '/track/28drn6tQo95MRvO0jQEo5C/Type-Shit-by-Future-Metro-Boomin-Travis-Scott-Playboi-Carti',
#   'table_descr': 'Future, Metro Boomin, Travis Scott, Playboi Carti\'s \' "Type Shit" was released on its scheduled release date, March 22, 2024. Type Shit is explicit and may not be suitable for children. With the duration being about 3:48, this song is close to the average duration of a typical track. This song is part of WE DON\'T TRUST YOU by Future, Metro Boomin. The song\'s track number on the album is #4 out of 17 tracks. Based on our data, United States was the country where this track was produced or recorded. In terms of popularity, Type Shit is currently pretty popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': "I Look in People's Windows",
#   'table_artist': 'Taylor Swift',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '95',
#   'table_link': '/track/1Zai5UJ2di3qEuR2HeT2s8/I-Look-in-Peoples-Windows-by-Taylor-Swift',
#   'table_descr': 'Taylor Swift\'s \' "I Look in People\'s Windows" was released on its scheduled release date, April 19, 2024. The duration of This song is about two minutes long, specifically at 2:11. This song does not appear to have any foul language. I Look in People\'s Windows\'s duration is considered a little bit shorter than the average duration of a typical track. There are a total of 31 in the song\'s album "THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY". In this album, this song\'s track order is #25. Furthermore, we believe that the track originated from United States. In terms of popularity, I Look in People\'s Windows is currently pretty popular. Since there is more of a neutral sound being played, this makes the track somewhat danceable.'},
#  {'table_name': 'M a k e I t T o T h e M o r n i n g',
#   'table_artist': 'PARTYNEXTDOOR',
#   'table_key': 'F Major',
#   'table_camelot': '7B',
#   'table_bpm': '94',
#   'table_link': '/track/12VH4g5pTMZmrUVzfJq7F7/M-a-k-e-I-t-T-o-T-h-e-M-o-r-n-i-n-g-by-PARTYNEXTDOOR',
#   'table_descr': 'PARTYNEXTDOOR\'s \'M a k e I t T o T h e M o r n i n g\' had a release date set for April 26, 2024. M a k e I t T o T h e M o r n i n g is 2 minutes and 48 seconds long and may contain bad words that may be unsuitable for children. There are a total of 14 in the song\'s album "PARTYNEXTDOOR 4 (P4)". In this album, this song\'s track order is #5. Furthermore, we believe that the track originated from United States. In terms of popularity, M a k e I t T o T h e M o r n i n g is currently pretty popular. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. '},
#  {'table_name': 'Parte & Choke',
#   'table_artist': 'Jombriel, Alex Krack, Jøtta',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '117',
#   'table_link': '/track/0STW8nw4lNN4TEQ8KmNer6/Parte-Choke-by-Jombriel-Alex-Krack-Jtta',
#   'table_descr': 'On November 5, 2024, the song "Parte & Choke" was released by Jombriel, Alex Krack, Jøtta. The duration of This song is about 3 minutes long, at 3:25. Based on our data, This song appears to be safe for all ages and is not considered explicit. This track is about the average length of a typical track. Since Parte & Choke only contains only one song in the album, we like to consider this song as a single. In terms of popularity, Parte & Choke is currently pretty popular. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'Guess featuring billie eilish',
#   'table_artist': 'Charli xcx, Billie Eilish',
#   'table_key': 'B♭ Minor',
#   'table_camelot': '3A',
#   'table_bpm': '120',
#   'table_link': '/track/0IsIY8pfu1yaGkPUD7pkDx/Guess-featuring-billie-eilish-by-Charli-xcx-Billie-Eilish',
#   'table_descr': 'Charli xcx, Billie Eilish\'s \' "Guess featuring billie eilish" was released on its scheduled release date, October 11, 2024. The duration of This song is about two minutes long, specifically at 2:23. This song does not appear to have any foul language. Guess featuring billie eilish\'s duration is considered a little bit shorter than the average duration of a typical track. The song is number 16 out of 34 in Brat and it’s completely different but also still brat by Charli xcx. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, Guess featuring billie eilish\'s popularity is pretty popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'I Had Some Help (Feat. Morgan Wallen)',
#   'table_artist': 'Post Malone, Morgan Wallen',
#   'table_key': 'G Major',
#   'table_camelot': '9B',
#   'table_bpm': '128',
#   'table_link': '/track/5IZXB5IKAD2qlvTPJYDCFB/I-Had-Some-Help-Feat-Morgan-Wallen-by-Post-Malone-Morgan-Wallen',
#   'table_descr': "Post Malone, Morgan Wallen's 'I Had Some Help (Feat. Morgan Wallen)' had a release date set for August 15, 2024. I Had Some Help (Feat. Morgan Wallen) is 2 minutes and 58 seconds long and may contain bad words that may be unsuitable for children. The song is number 3 out of 18 in F-1 Trillion by Post Malone. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, I Had Some Help (Feat. Morgan Wallen)'s popularity is pretty popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. "},
#  {'table_name': 'ROSONES',
#   'table_artist': 'Jorsshh, Fuerza Regida',
#   'table_key': 'F♯ Major',
#   'table_camelot': '2B',
#   'table_bpm': '120',
#   'table_link': '/track/6x59lSlNU7TvsJZy7134uC/ROSONES-by-Jorsshh-Fuerza-Regida',
#   'table_descr': 'On November 15, 2024, the song "ROSONES" was released by Jorsshh, Fuerza Regida. ROSONES is 2 minutes and 58 seconds long and may contain bad words that may be unsuitable for children. Since ROSONES only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. Based on our statistics, ROSONES\'s popularity is pretty popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'ESCAPATE',
#   'table_artist': 'Tito Double P, Chino Pacas',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '120',
#   'table_link': '/track/6HrALJOMsfPCCbUo5cJCON/ESCAPATE-by-Tito-Double-P-Chino-Pacas',
#   'table_descr': 'Tito Double P, Chino Pacas\'s \' "ESCAPATE" was released on its scheduled release date, August 22, 2024. ESCAPATE is 2 minutes and 24 seconds long and may contain bad words that may be unsuitable for children. The track order of this song in Tito Double P\'s "INCÓMODO" album is number 15 out of 21. Based on our statistics, ESCAPATE\'s popularity is pretty popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'L’AMOUR DE MA VIE',
#   'table_artist': 'Billie Eilish',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '152',
#   'table_link': '/track/6fPan2saHdFaIHuTSatORv/LAMOUR-DE-MA-VIE-by-Billie-Eilish',
#   'table_descr': 'Billie Eilish\'s \'L’AMOUR DE MA VIE\' had a release date set for May 17, 2024. This song is about six minutes long, preciously at 5:33, making this song fairly long compared to other songs. The track order of this song in Billie Eilish\'s "HIT ME HARD AND SOFT" album is number 7 out of 10. On top of that, United States appears to be the country where this track was created. Based on our statistics, L’AMOUR DE MA VIE\'s popularity is pretty popular right now. Although the overall vibe is very danceable, it does project more negative sounds. '},
#  {'table_name': 'Close To You',
#   'table_artist': 'Gracie Abrams',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '116',
#   'table_link': '/track/5wbg8kepMFoMzHOEuxiI0q/Close-To-You-by-Gracie-Abrams',
#   'table_descr': 'Gracie Abrams\'s \' "Close To You" was released on its scheduled release date, June 20, 2024. With this song being around four minutes long, at 3:45, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. There are a total of 13 in the song\'s album "The Secret of Us". In this album, this song\'s track order is #13. Furthermore, we believe that the track originated from United States. In terms of popularity, Close To You is currently pretty popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'UWAIE',
#   'table_artist': 'Kapo',
#   'table_key': 'A Minor',
#   'table_camelot': '8A',
#   'table_bpm': '103',
#   'table_link': '/track/5QjmUqgpPQgXgg4606DqZF/UWAIE-by-Kapo',
#   'table_descr': 'Kapo\'s \' "UWAIE" was released on its scheduled release date, August 15, 2024. The duration of This song is about two minutes long, specifically at 2:52. This song does not appear to have any foul language. UWAIE\'s duration is considered a little bit shorter than the average duration of a typical track. Since UWAIE only contains only one song in the album, we like to consider this song as a single. In terms of popularity, UWAIE is currently pretty popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Ride Or Die, Pt. 2 (with Villano Antillano & Tokischa)',
#   'table_artist': 'Sevdaliza, Villano Antillano, Tokischa',
#   'table_key': 'F Minor',
#   'table_camelot': '4A',
#   'table_bpm': '140',
#   'table_link': '/track/5oYVxFt2k4SkVp6wzVsFWN/Ride-Or-Die-Pt-2-with-Villano-Antillano-Tokischa-by-Sevdaliza-Villano-',
#   'table_descr': 'Sevdaliza, Villano Antillano, Tokischa\'s \' "Ride Or Die, Pt. 2 (with Villano Antillano & Tokischa)" was released on its scheduled release date, April 18, 2024. Ride Or Die, Pt. 2 (with Villano Antillano & Tokischa) is 2 minutes and 38 seconds long and may contain bad words that may be unsuitable for children. There are a total of 2 in the song\'s album "Ride Or Die, Pt. 2". In this album, this song\'s track order is #1. Furthermore, we believe that the track originated from Netherlands. Based on our statistics, Ride Or Die, Pt. 2 (with Villano Antillano & Tokischa)\'s popularity is pretty popular right now. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Madonna',
#   'table_artist': 'Natanael Cano, Oscar Maydon',
#   'table_key': 'C Major',
#   'table_camelot': '8B',
#   'table_bpm': '128',
#   'table_link': '/track/5LhI8m7n8xlQmNe3b7Rwis/Madonna-by-Natanael-Cano-Oscar-Maydon',
#   'table_descr': 'Natanael Cano, Oscar Maydon\'s \' "Madonna" was released on its scheduled release date, March 8, 2024. Madonna is considered explicit and may contain foul language. This song is about 3 minutes and 7 seconds, which is about the average length of a typical song. Because this song is the only song in Madonna and no other songs are present in the album, we classify this track as a single. Based on our statistics, Madonna\'s popularity is pretty popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'I Had Some Help (Feat. Morgan Wallen)',
#   'table_artist': 'Post Malone, Morgan Wallen',
#   'table_key': 'F Major',
#   'table_camelot': '7B',
#   'table_bpm': '148',
#   'table_link': '/track/5IZXB5IKAD2qlvTPJYDCFB/I-Had-Some-Help-Feat-Morgan-Wallen-by-Post-Malone-Morgan-Wallen',
#   'table_descr': "Post Malone, Morgan Wallen's 'I Had Some Help (Feat. Morgan Wallen)' had a release date set for August 15, 2024. I Had Some Help (Feat. Morgan Wallen) is 2 minutes and 58 seconds long and may contain bad words that may be unsuitable for children. The song is number 3 out of 18 in F-1 Trillion by Post Malone. Going off of the ISRC code of this track, we detected that the origin of this track is from United States. Based on our statistics, I Had Some Help (Feat. Morgan Wallen)'s popularity is pretty popular right now. Although the tone can be danceable to some, this track does projects more of a negative sound rather than a postive one. "},
#  {'table_name': 'HOLLYWOOD',
#   'table_artist': 'Peso Pluma, Estevan Plazola',
#   'table_key': 'D♭ Minor',
#   'table_camelot': '12A',
#   'table_bpm': '126',
#   'table_link': '/track/5GTBdEjZe7zEDp1N0eCZE4/HOLLYWOOD-by-Peso-Pluma-Estevan-Plazola',
#   'table_descr': 'Peso Pluma, Estevan Plazola\'s \' "HOLLYWOOD" was released on its scheduled release date, June 20, 2024. This song is quite longer than the average track at 4 minutes and 44 seconds. With that being said, this track is also considered explicit and may be offensive to some people. There is only one song in ÉXODO, so we believe that "HOLLYWOOD" is a single. Based on our statistics, HOLLYWOOD\'s popularity is pretty popular right now. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '},
#  {'table_name': 'I Never Lie',
#   'table_artist': 'Zach Top',
#   'table_key': 'E♭ Major',
#   'table_camelot': '5B',
#   'table_bpm': '108',
#   'table_link': '/track/3t6gUcGYLrUuqwpXjOFWQc/I-Never-Lie-by-Zach-Top',
#   'table_descr': 'Zach Top\'s \' "I Never Lie" was released on its scheduled release date, April 5, 2024. With this song being around four minutes long, at 3:44, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. The song is number 11 out of 12 in Cold Beer & Country Music by Zach Top. In terms of popularity, I Never Lie is currently pretty popular. Even with the track produces more of a neutral energy, it is pretty danceable compared to others.'},
#  {'table_name': 'Soltera',
#   'table_artist': 'Shakira',
#   'table_key': 'D Major',
#   'table_camelot': '10B',
#   'table_bpm': '100',
#   'table_link': '/track/3OJDtCdYs8QJnui708tEU3/Soltera-by-Shakira',
#   'table_descr': 'Shakira\'s \' "Soltera" was released on its scheduled release date, September 25, 2024. With this song being around four minutes long, at 3:34, the duration of this song is pretty average compared to other songs. This track is safe for children and doesn\'t appear to contain any foul language, since the "Explicit" tag was not present in this track. Since Soltera only contains only one song in the album, we like to consider this song as a single. Furthermore, we believe that the track originated from United States. In terms of popularity, Soltera is currently pretty popular. The overall tone is very danceable, especially with its high energy, which produces more of a euphoric, cheerful, or happy vibe. '}]
